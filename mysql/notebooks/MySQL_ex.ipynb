# %% [markdown]
# # RDBMS - MySQL
#
# ## 00 - Introduction
#
# Among the Relational DBMSs (Database Managment Softwares), the most widely known are Oracle, SQLite, Postgres, MariaDB, and MySQL.
#
# Each one of them is characterized by a different set of "variations" on top of the base SQL language, although usually minor.
#
# We will use **MySQL** to run exercises about Relational DB transactions using the SQL language, as it is *currently* at the top of the list of most widely used RDBMSs.
#
# [DB Engines Ranking Trend](https://db-engines.com/en/ranking_trend/relational+dbms)
#
# [Worldwide Popularity Ranking of Database Management Systems](https://www.statista.com/statistics/809750/worldwide-popularity-ranking-database-management-systems/)
#
# [Stack Overflow 2023 Developer Survey - Most Popular Technologies (Language)](https://survey.stackoverflow.co/2023/#most-popular-technologies-language)
#
# [Stack Overflow 2023 Developer Survey - Most Popular Technologies (Database)](https://survey.stackoverflow.co/2023/#most-popular-technologies-database)

# %% [markdown]
# MySQL programming interfaces exist for many languages, including C, C++, Go, Java, Perl, PHP, Python, etc...
#
# Even simply referring to Python, we can count on several options to connect and interact with the DBs.
#
# Let's explore a couple of them...

# %% [markdown]
# ## 01 - Create a Connection to MySQL
#
# A MySQL server is running within one of your Docker containers.
#
# You can access it using the MySQL server credentials defined in the `docker-compose.yml` file.
#
# By default, a `root` user is created with the following credentials:
# - **Username:** `root`
# - **Password:** `root_pwd`
#
# Additionally, a non-`root` user is created by default with:
# - **Username:** `my_user`
# - **Password:** `my_pwd`

# %% [markdown]
# #### Interactive
#
# To interact with the MySQL server, you can log in interactively to its Docker container.
#
# First, check the `CONTAINER ID` of the container named `mysql_db` by running:
#
# ```bash
# $ docker ps
# ```
#
# Then, initiate an interactive bash session within the container by executing:
#
# ```bash
# $ docker exec -it <YOUR CONTAINER ID> bash
# ```
#
# Once inside the container, you can access the MySQL server as if you were connected to a remote server hosting your databases:
#
# ```bash
# $ mysql -u <EITHER ROOT OR USER> -p
# ```
#
# Replace `<YOUR CONTAINER ID>` with the actual container ID obtained from the `docker ps` command output, and `<EITHER ROOT OR USER>` with either `root` or `my_user`, depending on the user you want to log in as.

# %% [markdown]
# We can then inspect the MySQL server to display all databases by executing the following SQL command:
#
# ```mysql
# SHOW DATABASES;
# ```
#
# **NB**: Remember to end a SQL command with a semicolon `;`.

# %% [markdown]
# #### mysql.connector
#
# A more pythonic way to interact with a MySQL server is by using a dedicated driver such as `mysql.connector`, which is already installed in the Jupyter Notebook container.
#
# This connector offers an interface to establish a connection object to the MySQL server and provides various functionalities for executing transactions and fetching records from databases.
#
# We can start by declaring a connection to our MySQL server.
#
# **NB:** The server is hosted in a different container from the notebook, simulating a connection between two different machines: a client and a server.

# %%
# import the connector
import mysql.connector

# declare a connection to the MySQL server 
# the hostname (or IP) of the server machine should be passed
db = mysql.connector.connect(
  user="root",
  password="root_pwd",
  host="db", # in this case 'db' is the equivalent of the IP address of the server 
             # or 'localhost' if running mysql locally
)

print(db)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x7fac118460d0>

# %% [markdown]
# At this point, a database connection is established.
#
# To interact with the database using Python and `mysql.connector`, we need a "handle" known as a cursor, which must be instantiated.
#
# When using this connector to interact with the database, all SQL statements are executed using the cursor.

# %%
# create our db cursor object
dbc = db.cursor()

# %% [markdown]
# The cursor allows us to execute all SQL transactions on the database as if we were logged into the server.
#
# If a transaction fetches results from the database (returns a set of records), the connector object will retain the results. This feature can be useful for later use in a more "pythonic" way, integrating our database queries with other Python statements.
#
# The syntax for issuing a generic SQL statement is as follows:
#
# ```python
# connector_object.execute(my_sql_query)
# ```
#
# For example, let's execute the same check as before by asking MySQL to show us all available databases...

# %%
# show all available databases
dbc.execute(
"SHOW DATABASES"
)

# %% [markdown]
# No output is printed because the result of this SQL transaction is collected into the cursor as a list of records (tuples).
#
# To retrieve the results, we can simply loop over them.

# %%
# loop over the container to fetch the results
for _ in dbc:
    print(_)
# Out:
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)

# %% [markdown]
# If we are `root` users in this example, we can access the inner structure of the MySQL server, which already contains a few databases by default.
#
# After fetching the output of the transaction, the cursor reaches "the end" of the records and becomes available to perform a new transaction.

# %%
# use fetch to retrieve one, many, or all entries in the cursor
dbc.fetchone()

# dbc.fetchmany(2)

# dbc.fetchall()

# %% [markdown]
# If one wants to perform a new transaction without collecting the output of the previous one from the cursor, a reset must be issued first:
#
# ```python
# connector_object.reset()
# ```

# %% [markdown]
# If a generic user (i.e., not the `root` user) is logged into the database server, they will not have access to certain functionalities and won't be able to see the previous list of all databases.
#
# Some of these databases and tables are protected and used to store additional information about the state of the MySQL server and the connected users.

# %%
# connecto to the database as a non-root user
udb = mysql.connector.connect(
  user="my_user",
  password="my_pwd",
  host="db",
)

# create a cursor
udbc = udb.cursor()

# execute the transaction
udbc.execute(
"SHOW DATABASES"
)

# fetch all results
udbc.fetchall()
# Out:
# [('information_schema',), ('performance_schema',)]

# %% [markdown]
# #### iPython Magic
#
# Another way to execute queries from Python within a Jupyter Notebook is by utilizing notebook "magic" functions, which are based on iPython and SQLAlchemy.
#
# This approach is similar to loading inline figures from Matplotlib using `%matplotlib inline`.
#
# To instruct iPython to interpret SQL commands and connect to the appropriate database, we need to:
#
# 1. Load the extension for the SQL language.
# 2. Set the environment variable to point to the connection to the database.

# %%
# %load_ext sql

# %env DATABASE_URL=mysql+mysqlconnector://root:root_pwd@db
# Out:
# env: DATABASE_URL=mysql+mysqlconnector://root:root_pwd@db

# %% [markdown]
# Now, notebook cells can execute SQL transactions directly in plain SQL by starting the cell with `%%sql`.
#
# By default, the result is also printed using the `pretty` format, similar to the pandas-like format.

# %%
# %%sql
#
# SHOW DATABASES;
# Out:
# 5 rows affected.
# [('IMDb',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',)]

# %% [markdown]
# An additional benefit is that a single `%sql` (not a double `%%sql`) can be used to combine a SQL query with any Python command.

# %%
my_python_var = %sql SHOW DATABASES

print(my_python_var)
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# +--------------------+
# |      Database      |
# +--------------------+
# |        IMDb        |
# | information_schema |
# |       mysql        |
# | performance_schema |
# |        sys         |
# +--------------------+

# %% [markdown]
# The combination of either of the two Pythonic methods can be used to easily redirect the output of database transactions to leverage other well-known Python modules, such as plotting with Matplotlib.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.hist(my_python_var);
plt.xticks(rotation='vertical');

# %% [markdown]
# ## 02 Database and Table creation

# %% [markdown]
# We have already seen how to inspect the server to see which databases are present using the command:
#
# ```mysql
# SHOW DATABASES;
# ```
#
# To start interacting with a specific database, we can select it using `USE`:
#
# ```mysql
# USE <DB_NAME>;
# ```
#
# If the user has been granted the right to access this database, it's possible to start investigating its content.

# %% [markdown]
# If we want to create a new database to work with instead, we can use the command:
#
# ```mysql
# CREATE DATABASE <DB_NAME>;
# ```
#
# A more complex syntax can be used to create a new database only if no other database with the same name already exists:
#
# ```mysql
# CREATE DATABASE IF NOT EXISTS <DB_NAME>;
# ```

# %% [markdown]
# - Check if a DB named `my_db` exists.
# - If not, create one.
# - Then, switch to the new DB to start using it.

# %%
# %%sql
#
# CREATE DATABASE IF NOT EXISTS my_db;
# USE my_db;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
#
# SHOW DATABASES
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('information_schema',),
#  ('my_db',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',)]

# %% [markdown]
# All tables contained in the DB are shown in a similar way to what used to show all DBs on the server:
#
# ```mysql
# SHOW TABLES;
# ```
#
# **NB**: we are inspecting the content of a specific DB (the one selected with `USE <DB_NAME>`)

# %%
# %%sql
#
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %% [markdown]
# The analogous Pythonic way to execute the same list of commands (using the `mysql.connector` driver) is the following:
#
# **NB**: This time we are not retrieving results from the server, but are instead asking the DBMS to _create_ a new database. We are issuing a request that requires us to **commit** a change in the MySQL server

# %%
# defining the sql command line
sql_ = "CREATE DATABASE IF NOT EXISTS my_db;"

# instructing the cursor to execute it
dbc.execute(sql_)

# in this case the result of the sql transaction is not to return a list of items 
# it is instead a change in the DB structure
# therefore, for the change to have an effect, the change is to be committed to the DB
db.commit()

# %% [markdown]
# All other commands discussed so far (`USE` and `SHOW`), do not require any change to be committed, therefore we can simply issue them via the cursor.
#
# Creating new databases, or changing the structure (_schema_) or the content (_instance_) of a database, will instead require a `commit`.

# %%
# use the my_db database
dbc.execute("USE my_db")

# show all tables
dbc.execute("SHOW TABLES")
dbc.fetchall()
# Out:
# []

# %% [markdown]
# So far the `my_db` database is empty, so let's use the same lines presented in the slides to create a dummy `Users` table.
#
# Any table can then be inspected to check its schema by listing all attributes.
#
# 1. Begin by creating a `Users` table. Define the schema by specifying each attribute.
# 2. Verify if it has been successfully created in the database. Use the `SHOW` command for this purpose.
# 3. Inspect the schema of the `Users` table, execute the `DESCRIBE <TABLE_NAME>` command.

# %%
# %%sql
#
# # create a table following the schema on the slides
# CREATE TABLE Users (
#     UserID    varchar(30),
#     BadgeNum  int(16),
#     FirstName varchar(255),
#     LastName  varchar(255),
#     Age       int,
#     OtherAttr float
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # show the tables in the current database
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('Users',)]

# %%
# %%sql
#
# # describe the table `Users`
# DESCRIBE Users;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 6 rows affected.
# [('UserID', 'varchar(30)', 'YES', '', None, ''),
#  ('BadgeNum', 'int', 'YES', '', None, ''),
#  ('FirstName', 'varchar(255)', 'YES', '', None, ''),
#  ('LastName', 'varchar(255)', 'YES', '', None, ''),
#  ('Age', 'int', 'YES', '', None, ''),
#  ('OtherAttr', 'float', 'YES', '', None, '')]

# %% [markdown]
# Following the previous examples, let's perform the same transactions using the `mysql.connector` driver. Since the `Users` table already exists, we will create a new table called `Users_py`.
#
# Remember the following points:
#
# - Utilize the DB Cursor to execute the transactions.
# - Transactions that change the content of the DB must be _committed_ to the DB.
# - Transactions returning the content of the DB host their results _in the cursor_.

# %%
# create a table following the schema on the slides
sql = 'CREATE TABLE Users_py (\
       UserID    varchar(30),\
       BadgeNum  int(16),\
       FirstName varchar(255),\
       LastName  varchar(255),\
       Age       int,\
       OtherAttr float);'
dbc.execute(sql)
db.commit()

# %%
# show the tables in the current database
dbc.execute("SHOW TABLES")
dbc.fetchall()
# Out:
# [('Users',), ('Users_py',)]

# %%
# describe the table `Users_py`
dbc.execute("DESCRIBE Users_py")
dbc.fetchall()
# Out:
# [('UserID', 'varchar(30)', 'YES', '', None, ''),
#  ('BadgeNum', 'int', 'YES', '', None, ''),
#  ('FirstName', 'varchar(255)', 'YES', '', None, ''),
#  ('LastName', 'varchar(255)', 'YES', '', None, ''),
#  ('Age', 'int', 'YES', '', None, ''),
#  ('OtherAttr', 'float', 'YES', '', None, '')]

# %% [markdown]
# ## 03 Declaring contstraints and altering tables

# %% [markdown]
# Before moving on, let's clean up all existing tables in our database.
#
# To remove an existing table from the database, you can use the following instruction:
#
# ```mysql
# DROP TABLE IF EXISTS <NAME OF YOUR TABLE>;
# ```
#
# **CAUTION**: Dropping a table deletes all records from that table and severs all connections with other tables based on foreign keys. This action can render the entire database unusable. Be extremely careful when executing this command.

# %%
# %%sql
#
# # drop the table Users
# DROP TABLE IF EXISTS Users;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# SHOW TABLES
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('Users_py',)]

# %% [markdown]
# Let's also drop the `Users_py` table using the Python connector.
# This is once again an action that alters the database, thus we must `commit` it.

# %%
# drop the table Users_py
dbc.execute("DROP TABLE IF EXISTS Users_py")
db.commit()

# %%
# inspect the content of the database
dbc.execute("SHOW TABLES")
dbc.fetchall()
# Out:
# []

# %% [markdown]
# Create a new `products` table with the following schema:
#
# | Attribute    | Type    | Extra info | Constraint                |
# |--------------|---------|------------|---------------------------|
# | productID    | Integer |            | NOT NULL AUTO_INCREMENT  |
# | productName  | String  | Max length 30 | DEFAULT ''            |
# | unitPrice    | Float   |            | NOT NULL DEFAULT 99999.99|
# | unitsInStock | Integer | Unsigned   | NOT NULL DEFAULT 0        |
#
#
# The `productID` attribute will be our `PRIMARY KEY`.
#
# This can be declared either inline, or at the end of the table definition:
#
# ```mysql
# productID INT NOT NULL UNIQUE AUTO_INCREMENT PRIMARY KEY
# ```
#
# or
#
# ```mysql
# productID INT NOT NULL UNIQUE AUTO_INCREMENT
# [...]
# PRIMARY KEY (productID)
# ```

# %% [markdown]
# Note: PRIMARY KEYS must contain UNIQUE values (that's why we add the command UNIQUE when creating productID)

# %%
# %%sql
#
# # create the products table
# CREATE TABLE IF NOT EXISTS products (
#          productID    INT          NOT NULL UNIQUE AUTO_INCREMENT PRIMARY KEY,
#          productName  VARCHAR(30)  DEFAULT '' ,
#          unitPrice    FLOAT        NOT NULL DEFAULT 99999.99,
#          unitsInStock INT UNSIGNED NOT NULL DEFAULT 0
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('productID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('productName', 'varchar(30)', 'YES', '', '', ''),
#  ('unitPrice', 'float', 'NO', '', '100000', ''),
#  ('unitsInStock', 'int unsigned', 'NO', '', '0', '')]

# %% [markdown]
# The table does not contain any constraints, default values, or foreign keys. (Secondo me e Jacopo questa è sbagliata).
#
# Note: If an attribute, such as productName, unitPrice,... is not set as a PRIMARY KEY, then it's simply an attribute. For it to be a FOREIGN KEY you must specify it as such.
#
#
# The **schema** of a given table can be altered by adding/removing Attributes, as well as by adding constraints.
#
# Let's first add a new attribute to the table:
#
# | Attribute       | Type    | Extra info     | Constraint                |
# |-----------------|---------|----------------|---------------------------|
# | productID       | Integer |                | NOT NULL AUTO_INCREMENT  |
# | productName     | String  | Max length 30  | DEFAULT ''               |
# | unitPrice       | Float   |                | NOT NULL DEFAULT 99999.99|
# | unitsInStock    | Integer | Unsigned       | NOT NULL DEFAULT 0       |
# | **isDiscontinued** | **Bool** |              | NOT NULL                  |
#
#
# To alter the **schema** of a table and create a new column we can act on it with:
#
# ```mysql
# ALTER TABLE <THE TABLE>
# ADD COLUMN <NEW COL> <THE NEW ATTRIBUTE DECLARATION>;
# ```

# %% [markdown]
# #### Alter the `products` table and add the `isDiscontinued` attribute

# %%
# %%sql
#
# # alter the table
# ALTER TABLE products
# ADD COLUMN isDiscontinued BOOL NOT NULL;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('productID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('productName', 'varchar(30)', 'YES', '', '', ''),
#  ('unitPrice', 'float', 'NO', '', '100000', ''),
#  ('unitsInStock', 'int unsigned', 'NO', '', '0', ''),
#  ('isDiscontinued', 'tinyint(1)', 'NO', '', None, '')]

# %% [markdown]
# The `isDiscontinued` attribute does not contain any meaningful constraint or default value.
# Let's consider `0` as a good default value for this attribute:
#
# | Attribute | Type | Extra info | Constraint |
# | --- | --- | --- |--- |
# | productID   | Integer | | NOT NULL AUTO_INCREMENT |
# | productName | String | Max length 30 | DEFAULT '' |
# | unitPrice   | Float | | NOT NULL DEFAULT 99999.99|
# | unitsInStock | Integer | Unsigned | NOT NULL DEFAULT 0 |
# | isDiscontinued  | Bool | | NOT NULL **DEFAULT 0** |
#
# We can use the same `ALTER TABLE` instruction to do this, and set a new default:
#
# ```mysql
# ALTER TABLE <THE TABLE>
# ALTER <ATTRIBUTE> SET DEFAULT <NEW DEFAULT>;
# ```

# %%
# %%sql
#
# # alter the table
# ALTER TABLE products
# ALTER isDiscontinued SET DEFAULT 0;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('productID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('productName', 'varchar(30)', 'YES', '', '', ''),
#  ('unitPrice', 'float', 'NO', '', '100000', ''),
#  ('unitsInStock', 'int unsigned', 'NO', '', '0', ''),
#  ('isDiscontinued', 'tinyint(1)', 'NO', '', '0', '')]

# %% [markdown]
# We can also impose `productName` to be not-null by altering the table one final time.
#
# | Attribute | Type | Extra info | Constraint |
# | --- | --- | --- |--- |
# | productID   | Integer | | NOT NULL AUTO_INCREMENT |
# | productName | String | Max length 30 | **NOT NULL** DEFAULT '' |
# | unitPrice   | Float | | NOT NULL DEFAULT 99999.99|
# | unitsInStock | Integer | Unsigned | NOT NULL DEFAULT 0 |
# | isDiscontinued  | Bool | | NOT NULL DEFAULT 0 |
#
#
# In MySQL, this implies modifying the entire attribute, thus the Type will have to be re-stated:
#
# ```mysql
# ALTER TABLE <THE TABLE>
# MODIFY <ATTRIBUTE> <ATTRIBUTE TYPE> <CONSTRAINT>;
# ```

# %%
# %%sql
#
# # alter the table
# ALTER TABLE products
# MODIFY productName VARCHAR(30) NOT NULL;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('productID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('productName', 'varchar(30)', 'NO', '', None, ''),
#  ('unitPrice', 'float', 'NO', '', '100000', ''),
#  ('unitsInStock', 'int unsigned', 'NO', '', '0', ''),
#  ('isDiscontinued', 'tinyint(1)', 'NO', '', '0', '')]

# %% [markdown]
# Let's now create a `suppliers` table with the following description:
#
# | Attribute | Type | Extra info | Constraint |
# | --- | --- | --- |--- |
# | supplierID   | Integer | | NOT NULL AUTO_INCREMENT |
# | supplierName | String | Max length 30 | NOT NULL DEFAULT "" |
# | countryCode   | Char | Length 3 | NOT NULL |
# | email   | String | Max length 30  | NOT NULL |
#
# `supplierID` is going to act as the table's primary key in this case.

# %%
# %%sql
#
# # create the suppliers table
# CREATE TABLE suppliers (
#     supplierID      INT NOT NULL UNIQUE AUTO_INCREMENT PRIMARY KEY,
#     supplierName    VARCHAR(30) NOT NULL DEFAULT "",
#     countryCode     CHAR(3) NOT NULL,
#     email           VARCHAR(30) NOT NULL
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('supplierID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('supplierName', 'varchar(30)', 'NO', '', '', ''),
#  ('countryCode', 'char(3)', 'NO', '', None, ''),
#  ('email', 'varchar(30)', 'NO', '', None, '')]

# %% [markdown]
# Alter the table to include a default "ITA" for `countryCode`

# %%
# %%sql
#
# # alter the table
# ALTER TABLE suppliers
# ALTER countryCode SET DEFAULT "---";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('supplierID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('supplierName', 'varchar(30)', 'NO', '', '', ''),
#  ('countryCode', 'char(3)', 'NO', '', '---', ''),
#  ('email', 'varchar(30)', 'NO', '', None, '')]

# %% [markdown]
# To establish a relation between the `products` and `suppliers` tables, we have to consider that:
#
# - a supplier can supply multiple products
# - a product can be supplied by multiple suppliers
#
# This is a **many-to-many** relationship, which requires a supporting external table.
#
# To establish a many-to-many relationship between the products and suppliers tables, we create a junction table named `supplier_to_product` with foreign keys referencing the `productID` from the `products` table and the `supplierID` from the `suppliers` table.
#
# Create a new `supplier_to_product` table with the following attributes:
#
# | Attribute | Type | Extra info | Constraint |
# | --- | --- | --- |--- |
# | prodID   | Integer | | NOT NULL |
# | supID    | Integer | | NOT NULL |

# %%
# %%sql
#
# # create the support table
# CREATE TABLE supplier_to_product (
#     prodID     INT NOT NULL,
#     supID      INT NOT NULL
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %% [markdown]
# Neither `prodID` nor `supID` is a good primary key in this case, as we can have both appearing multiple times in the table.
#
# However, a good primary key for this table is the combination `(prodID,supID)` which is unique, and thus, a good key.
#
# We can alter the table to add the primary key statement:
#
# ```mysql
# ALTER TABLE <TABLE>
# ADD PRIMARY KEY (<ATTRIBUTE 1>, <ATTRIBUTE 2>);
# ```

# %%
# %%sql
#
# # alter the table
# ALTER TABLE supplier_to_product
# ADD PRIMARY KEY (prodID, supID);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE supplier_to_product;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('prodID', 'int', 'NO', 'PRI', None, ''),
#  ('supID', 'int', 'NO', 'PRI', None, '')]

# %% [markdown]
# Finally, we can link the 3 tables together by stating which attributes act as the foreign keys in the `supplier_to_product` table, and to which attributes in the parent tables they refer to.
#
# - `prodID` points to the `productID` attribute of `products` table
# - `supID` points to the `supplierID` attribute of `supplier` table
#
# This translates into:
# - `prodID` is a foreign key for `supplier_to_product`
# - `subID` is a foreign key for `supplier_to_product`
# - the combination `(prodID, supID)` is the primary key of `supplier_to_product`
#
# We can declare an attribute as a foreign key by altering the table:
#
# ```mysql
# ALTER TABLE <TABLE>
# ADD FOREIGN KEY (<ATTRIBUTE IN THIS TABLE>) REFERENCES <OTHER TABLE>(<ATTRIBUTE IN OTHER TABLE>);
# ```

# %%
# %%sql
#
# # alter the table
# ALTER TABLE supplier_to_product
# ADD CONSTRAINT FK_prod
# FOREIGN KEY (prodID) REFERENCES products(productID);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # alter the table
# ALTER TABLE supplier_to_product
# ADD CONSTRAINT FK_sup
# FOREIGN KEY (supID) REFERENCES suppliers(supplierID);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE supplier_to_product;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('prodID', 'int', 'NO', 'PRI', None, ''),
#  ('supID', 'int', 'NO', 'PRI', None, '')]

# %% [markdown]
# ## 04 Inserting Updating and Deleting records

# %% [markdown]
# The tables are currently empty.
# We can inspect their content by performing a simple "read" query using `SELECT`.
# We will discuss later the full syntax of the `SELECT` statement... for the time being, it's important to realize that this command will show the entire content of all columns of the table we are inspecting.
#
# ```mysql
# SELECT * FROM <TABLE>;
# ```
#
# To insert a single record into a table we can proceed in either of the two following ways:
#
# 1. By explicitly specifying the names of the columns when passing the tuple containing the values
# ```mysql
# INSERT INTO <TABLE> (<COLUMN1>, <COLUMN2>, <COLUMN3>, ...)
# VALUES (<VALUE1>, <VALUE2>, <VALUE3>, ...);
# ```
# This will work also in the case attributes with a default value will not be explicitly passed
#
#
# 2. By implicitly using all the columns when passing the tuple containing the values
# ```mysql
# INSERT INTO <TABLE>
# VALUES (<VALUE1>, <VALUE2>, ..., <VALUEn>);
# ```
#
# **NB**: 1. is the usually recommended way to perform a data insertion in SQL, as (pretty much always in coding) **explicit is better than implicit**

# %% [markdown]
# Using the `mysql.connector` we can formulate the same data insertion in a more Pythonic way, e.g. to include this statement programmatically into a loop or a function call:
#
# ```python
# sql_ = "INSERT INTO <TABLE> (<COLUMN1>, <COLUMN2>, <COLUMN3>, ...) VALUES (%s, %s, %s, ...)"
# val_ = (<VALUE1>, <VALUE2>, <VALUE3>, ...)
# db_cursor.execute(sql_, val_)
# db.commit()
# ```
#
# Being an active change to the database instance, remember to commit the insert.

# %% [markdown]
# #### Perform a simple data insertion
#
# - Verify that the product table is actually empty.
# - Insert the following list of products into the `products` table.
# - Check the content of the table after the transaction to verify that both the `AUTO_INCREMENT` key and the default values have been taken into account.
#
# | productName | unitPrice | unitsInStock | isDiscontinued |
# | --- | --- | --- |--- |
# | "Founders Porter" | 4.9 | 12 | 0 |

# %%
# %%sql
#
# # retrieve the content of the table
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # insert records into the table
# INSERT INTO products (productName, unitPrice, unitsInStock)
# VALUES ('Founders Porter',4.9 ,12);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# []

# %%
# %%sql
#
# # retrieve the content of the table
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0)]

# %% [markdown]
# Multi-values insert can be performed in a similar way by separating multiple tuples with a comma:
#
# ```mysql
# INSERT INTO <TABLE> (<COLUMN1>, <COLUMN2>, <COLUMN3>, ...)
# VALUES
# (<VALUE11>, <VALUE12>, <VALUE13>, ...),
# (<VALUE21>, <VALUE22>, <VALUE23>, ...),
# (<VALUE31>, <VALUE32>, <VALUE33>, ...);
# ```
# Note: the first tuple is for the first row, second for the second,...
#
# The Python-based command is similar to the previous one, but it drops the `execute` in favor of `executemany`, using a list of tuples as values:
#
# ```python
# sql_ = "INSERT INTO <TABLE> (<COLUMN1>, <COLUMN2>, <COLUMN3>, ...) VALUES (%s, %s, %s, ...)"
# val_ = [
#     (<VALUE11>, <VALUE12>, <VALUE13>, ...),
#     (<VALUE21>, <VALUE22>, <VALUE23>, ...),
#     (<VALUE31>, <VALUE32>, <VALUE33>, ...) ]
# db_cursor.executemany(sql_, val_)
# db.commit()
# ```

# %% [markdown]
# Add a few more products to the `product` table:
#
# | productName | unitPrice | unitsInStock | isDiscontinued |
# | --- | --- | --- |--- |
# | "Punk IPA" | 5.2 | 45 |  |
# | "HB Dunkel" | 4.5 | 250 |  |
# | "Forst Xmas " | 8.0 | 2 |  |
# | "Damm Complot " | 3.7 | 120 |  |

# %%
# insert records into the table
sql_ = "INSERT INTO products (productName, unitPrice, unitsInStock) VALUES (%s, %s, %s)"
val_ = [
    ('Punk IPA',     5.2,  45),
    ('HB Dunkel',    4.5, 250),
    ('Forst Xmas',   8.0,   2),
    ('Damm Complot', 3.7, 120)]
dbc.executemany(sql_, val_)
db.commit()
     
dbc.execute("SELECT * FROM products"); 
dbc.fetchall()
# Out:
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0),
#  (4, 'Forst Xmas', 8.0, 2, 0),
#  (5, 'Damm Complot', 3.7, 120, 0)]

# %% [markdown]
# Updating entries is a delicate issue in databases, as we can potentially modify all records associated with a number of conditions. This makes the update operation quite powerful and possibly error-prone if not performed with extreme caution.
#
# ```mysql
# UPDATE <TABLE>
# SET <ATTRIBUTE> = <NEW VALUE>
# WHERE <CONDITION>;
# ```
#
# or
#
# ```python
# sql_ = "UPDATE <TABLE> SET <ATTRIBUTE> = <NEW VALUE> WHERE <CONDITION>"
# db_cursor.execute(sql)
# db.commit()
#
# ```
#
# #### Let's update a single record with a "very explicit" condition statement:
#
# - Assign `isDiscontinued` equal to `1` to the "Forst Xmas" product.
# - Check if the update has taken place.

# %%
# %%sql
#
# # update the content of the table
# UPDATE products
# SET isDiscontinued = 1
# WHERE productName = "Forst Xmas";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# []

# %%
# %%sql
#
# DESCRIBE products
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('productID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('productName', 'varchar(30)', 'NO', '', None, ''),
#  ('unitPrice', 'float', 'NO', '', '100000', ''),
#  ('unitsInStock', 'int unsigned', 'NO', '', '0', ''),
#  ('isDiscontinued', 'tinyint(1)', 'NO', '', '0', '')]

# %% [markdown]
# Similarly, deleting entries is quite risky if not done with plenty of caution, as a wrong `WHERE` condition might inadvertently lead to the deletion of a large part of your database records.
#
# Remember, with `DELETE`, we remove entire records (i.e., tuples) from the database, not just the content of the `WHERE` conditional statement.
#
# ```mysql
# DELETE FROM <TABLE>
# WHERE <CONDITION>;
# ```
#
# or
#
# ```python
# sql_ = "DELETE FROM <TABLE> WHERE <CONDITION>"
# db_cursor.execute(sql)
# db.commit()
#
# ```
#
# #### Delete all records under a set of conditions:
#
# - Delete all products whose name begins with 'F' and ends with 's'.
# - Check if the deletion has taken place.

# %%
# %%sql
#
# SELECT *
# FROM products
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0),
#  (4, 'Forst Xmas', 8.0, 2, 1),
#  (5, 'Damm Complot', 3.7, 120, 0)]

# %%
# %%sql
#
# # delete records from the table
# DELETE FROM products
# WHERE productID IN (6,7,9);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO products (productName, unitPrice, unitsInStock)
# VALUEs ('Founders Porter',4.9 ,12);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# []

# %% [markdown]
# The cell below shows how to modify a single value. To do that is imperative to use the WHERE statement, otherwise you would modify the whole table.

# %%
# %%sql
#
# UPDATE products
# SET productID = 1
# WHERE productName="Founders Porter";
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.IntegrityError) 1062 (23000): Duplicate entry '1' for key 'products.PRIMARY'
# [SQL: UPDATE products
# SET productID = 1
# WHERE productName="Founders Porter";]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# %%sql
#
# # retrieve the content of the table
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 6 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0),
#  (4, 'Forst Xmas', 8.0, 2, 1),
#  (5, 'Damm Complot', 3.7, 120, 0),
#  (6, 'Founders Porter', 4.9, 12, 0)]

# %% [markdown]
# #### Populate the `suppliers` table according to the following list
#
# | supplierName | countryCode | email|
# | --- | --- | ---|
# | "A hop in the park" | "USA" | "contactme@ahop.com" |
# | "Allez Hops! Cave à bièr" | "FRA" | "itsme@allezhops.com" |
# | "Wild Hops " | "ITA" | "myemail@wildhops.it" |
# |"Beer Paradise"|"ITA"|"beer@beerparadise.it"|

# %%
# %%sql
#
# # insert records into the table
# INSERT INTO suppliers (supplierName, countryCode, email) VALUES
# ("A hop in the park","USA","contactme@ahop.com"),
# ("Allez Hops! Cave à bièr","FRA","itsme@allezhops.com"),
# ("Wild Hops","ITA","myemail@wildhops.it"),
# ("Beer Paradise","ITA","beer@beerparadise.it");
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# []

# %%
# %%sql
#
# # retrieve the content of the table
# SELECT * FROM suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(1, 'A hop in the park', 'USA', 'contactme@ahop.com'),
#  (2, 'Allez Hops! Cave à bièr', 'FRA', 'itsme@allezhops.com'),
#  (3, 'Wild Hops', 'ITA', 'myemail@wildhops.it'),
#  (4, 'Beer Paradise', 'ITA', 'beer@beerparadise.it')]

# %% [markdown]
# Complete the database with the two additional steps:
#
# - Update the "A hop in the park" email address to "anewemail@ahop.com"
# - Populate the table of connections between products and suppliers
#     - Remember that the `supplier_to_product` table is linked to the other two via the respective Foreign Keys
#
# | supplier | products provided |
# | --- | --- |
# | "A hop in the park" | "Punk IPA", "HB Dunkel" |

# %%
sql_ = "UPDATE suppliers SET email = %s WHERE supplierName LIKE %s;"
val_ = ('anewemail@ahop.com', 'A hop%')
dbc.execute(sql_, val_)
db.commit()
     
dbc.execute("SELECT * FROM suppliers"); 
for _ in dbc:
     print(_)
# Out:
# (1, 'A hop in the park', 'USA', 'anewemail@ahop.com')
# (2, 'Allez Hops! Cave à bièr', 'FRA', 'itsme@allezhops.com')
# (3, 'Wild Hops', 'ITA', 'myemail@wildhops.it')
# (4, 'Beer Paradise', 'ITA', 'beer@beerparadise.it')

# %%
# %%sql
#
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 6 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0),
#  (4, 'Forst Xmas', 8.0, 2, 1),
#  (5, 'Damm Complot', 3.7, 120, 0),
#  (6, 'Founders Porter', 4.9, 12, 0)]

# %%
# %%sql
#
# SELECT * FROM suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com'),
#  (2, 'Allez Hops! Cave à bièr', 'FRA', 'itsme@allezhops.com'),
#  (3, 'Wild Hops', 'ITA', 'myemail@wildhops.it'),
#  (4, 'Beer Paradise', 'ITA', 'beer@beerparadise.it')]

# %%
# %%sql
#
# SELECT * FROM supplier_to_product;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO supplier_to_product
# VALUES
# (2,1),
# (3,1);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM supplier_to_product;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(2, 1), (3, 1)]

# %% [markdown]
# Export the DB you have created into a .sql file, and store it for later use.
#
# 1. Connect to the "server" Docker container using bash
# 2. Dump the database using the `mysqldump` command
# ```bash
# $ mysqldump -u <USER> -p <DB NAME>  >  <FULL/PATH/TO/NEW/DB_DUMP.sql>
# ```
# 3. use the folder `/mapd-workspace/dbs` to store the file, as it's the one currently visible from both in- and outside the container

# %% [markdown]
# ## 04 Basic queries

# %% [markdown]
# The `SELECT` statement allows us to perform queries and retrieve data from a DB.
#
# We can perform queries on a single table in the DB, as well as perform complex queries that span multiple interconnected tables, with one-to-one, one-to-many, and many-to-many relationships across records.
#
# Any `SELECT` statement is composed of at least:
#
# ```sql
# SELECT <TABLE1.ATTRIBUTE1>, <TABLE2.ATTRIBUTE2>   --# the list of attributes to show
#                                                   --# the * wildcard symbol means ALL attributes
#
# FROM <TABLE1>, <TABLE2>                           --# the table, or list of tables
#                                                   --# from which to extract the attributes
#
# WHERE <CONDITIONS>                                --# (optional) condition statement
# ```
#
# The same structure applies to Python-based connectors:
#
# ```python
# db_cursor.execute("""
#     SELECT <TABLE1.ATTRIBUTE1>, <TABLE2.ATTRIBUTE2>
#     FROM <TABLE1>, <TABLE2>
#     WHERE <CONDITIONS>
# """)
# res_ = db_cursor.fetchall()
# for _ in res_:
#     print(_)
# ```
#
# As an alternative, `db_cursor.fetchone()` can be used to print out only one of possibly many records.

# %% [markdown]
# #### Get the email of all suppliers from Italy

# %%
# %%sql
#
# SELECT email
# FROM suppliers
# WHERE countryCode="ITA";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('myemail@wildhops.it',), ('beer@beerparadise.it',)]

# %% [markdown]
# #### Get all information for products with unit price greater than 4

# %%
# %%sql
#
# SELECT *
# FROM products
# WHERE unitPrice>4;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0),
#  (4, 'Forst Xmas', 8.0, 2, 1),
#  (6, 'Founders Porter', 4.9, 12, 0)]

# %% [markdown]
# #### Select all products with unit cost less than 5, and list them in descending order of units in stock

# %%
# %%sql
#
# SELECT *
# FROM products
# WHERE unitPrice<5
# ORDER BY unitsInStock DESC;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(3, 'HB Dunkel', 4.5, 250, 0),
#  (5, 'Damm Complot', 3.7, 120, 0),
#  (1, 'Founders Porter', 4.9, 12, 0),
#  (6, 'Founders Porter', 4.9, 12, 0)]

# %% [markdown]
# **Group by** is a common statement that allows us to perform data aggregation.
#
# If you're familiar with `pandas`, this should not be new to you.
#
# Just remember:
# 1. No group by statement is possible without an aggregation function.
# 2. Group by operations can be quite computationally expensive. In the case of large databases, group by operations might require a long time to execute.

# %% [markdown]
# #### Plot the distribution of suppliers by country

# %%
# %%sql
#
# DESCRIBE suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('supplierID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('supplierName', 'varchar(30)', 'NO', '', '', ''),
#  ('countryCode', 'char(3)', 'NO', '', '---', ''),
#  ('email', 'varchar(30)', 'NO', '', None, '')]

# %%
# %%sql
#
# SELECT *
# FROM suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com'),
#  (2, 'Allez Hops! Cave à bièr', 'FRA', 'itsme@allezhops.com'),
#  (3, 'Wild Hops', 'ITA', 'myemail@wildhops.it'),
#  (4, 'Beer Paradise', 'ITA', 'beer@beerparadise.it')]

# %% [markdown]
# We use COUNT(countryCode) to show also the occurrences of each countryCode and we name that variable as count.

# %%
res_ = %sql SELECT COUNT(countryCode) AS count, countryCode FROM suppliers GROUP BY countryCode;

print (res_);

res_.bar();
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# +-------+-------------+
# | count | countryCode |
# +-------+-------------+
# |   1   |     USA     |
# |   1   |     FRA     |
# |   2   |     ITA     |
# +-------+-------------+

# %% [markdown]
# The main strength of Relational DBs is the possibility of matching information from different tables through **Join** operations.
#
# A join, either performed explicitly or implicitly is:
#
# 1. Computationally expensive. In the case of large databases, join operations might require a long time to execute.
# 2. Very easy to be done wrong, thus resulting in non-meaningful results.
#
# Be sure of which attributes (most often keys) you are performing a join operation on.

# %% [markdown]
# #### Join the `supplier_to_product` table with the `suppliers` table

# %%
# %%sql
#
# SELECT *
# FROM suppliers, supplier_to_product
# WHERE supplier_to_product.supID = suppliers.supplierID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1)]

# %%
# %%sql
#
# SELECT *
# FROM suppliers
# INNER JOIN supplier_to_product ON supplier_to_product.supID = suppliers.supplierID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1)]

# %%
# %%sql
#
# SELECT *
# FROM suppliers
# LEFT JOIN supplier_to_product ON supplier_to_product.supID = suppliers.supplierID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1),
#  (2, 'Allez Hops! Cave à bièr', 'FRA', 'itsme@allezhops.com', None, None),
#  (3, 'Wild Hops', 'ITA', 'myemail@wildhops.it', None, None),
#  (4, 'Beer Paradise', 'ITA', 'beer@beerparadise.it', None, None)]

# %%
# %%sql
#
# SELECT *
# FROM suppliers
# RIGHT JOIN supplier_to_product ON supplier_to_product.supID = suppliers.supplierID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1)]

# %% [markdown]
# We can concatenate multiple join operations to extract higher-level information out of the connections stored in the database.
#
# #### Add the corresponding product names to the previous join

# %%
# %%sql
#
# SELECT *
# FROM suppliers
# INNER JOIN supplier_to_product ON supplier_to_product.supID = suppliers.supplierID
# INNER JOIN products ON supplier_to_product.prodID = products.productID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1, 2, 'Punk IPA', 5.2, 45, 0),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1, 3, 'HB Dunkel', 4.5, 250, 0)]

# %% [markdown]
# The conjunction of `SELECT`, `GROUP BY`, and `JOIN` statements will allow us to extract non-trivial information out of any Relational database.
#
# #### Add the following records to the `supplier_to_product` table, and perform the following queries:
#
# | supplier | products provided |
# | --- | --- |
# | "Wild Hops" | "Founders Porter", "Punk IPA", "HB Dunkel", "Damm Complot" |
# | "Beer Paradise" | "Punk IPA", "Damm Complot" |
# | "Allez Hops! Cave à bièr" | "Founders Porter", "HB Dunkel" |
#
# 1. show all suppliers of "Damm Complot"
# 2. retrieve the email address of all possible suppliers of "Punk IPA"
# 3. list the unit price of all products supplied by Italian firms, listed in descending order (of unit price)

# %%
sql_ = "INSERT INTO supplier_to_product (prodID, supID) VALUES (%s, %s)"
val_ = [
    # supplier Allez Hops
    (1, 2),
    (3, 2),

    # supplier Wild Hops
    (1, 3),
    (2, 3),
    (3, 3),
    (5, 3),

    # supplier Beer Paradise
    (2, 4),
    (5, 4),
]


dbc.executemany(sql_, val_)
db.commit()
     
dbc.execute("SELECT * FROM supplier_to_product"); 
for _ in dbc:
     print(_)
# Out:
# (2, 1)
# (3, 1)
# (1, 2)
# (3, 2)
# (1, 3)
# (2, 3)
# (3, 3)
# (5, 3)
# (2, 4)
# (5, 4)

# %%
# %%sql
#
# SELECT suppliers.supplierName
# FROM supplier_to_product
# INNER JOIN suppliers ON supplier_to_product.supID = suppliers.supplierID
# INNER JOIN products ON supplier_to_product.prodID = products.productID
# WHERE products.productName = "Punk IPA";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('A hop in the park',), ('Wild Hops',), ('Beer Paradise',)]

# %%
# %%sql
#
# SELECT suppliers.email
# FROM supplier_to_product
# INNER JOIN suppliers ON supplier_to_product.supID = suppliers.supplierID
# INNER JOIN products ON supplier_to_product.prodID = products.productID
# WHERE products.productName = "Punk IPA";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('anewemail@ahop.com',), ('myemail@wildhops.it',), ('beer@beerparadise.it',)]

# %% [markdown]
# 3) list the unit price of all products supplied by Italian firms, listed in descending order (of unit price)

# %%
# %%sql
#
# SELECT DISTINCT products.unitPrice, products.productName
# FROM supplier_to_product
# INNER JOIN suppliers ON supplier_to_product.supID = suppliers.supplierID
# INNER JOIN products ON supplier_to_product.prodID = products.productID
# WHERE suppliers.countryCode = "ITA"
# ORDER BY unitPrice DESC;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(5.2, 'Punk IPA'),
#  (4.9, 'Founders Porter'),
#  (4.5, 'HB Dunkel'),
#  (3.7, 'Damm Complot')]

# %% [markdown]
# ## 05 Queries on well-formed DBs
#
# In MySQL, we can load entire databases from external files.
#
# The files will contain the full database structure (tables and constraints) and will populate all tables with all records.
#
# To load a database into the MySQL server from the interactive Docker shell, we can simply do the following:
#
# 1. Create a new database named `world`.
# 2. Import the content of the file `/mapd-workspace/dbs/world.sql` into the newly created database via:
#
# ```bash
# $ mysql -u root -p world < /mapd-workspace/dbs/world.sql
# ```
#
# **NB**: The `/mapd-workspace` directory has been defined as a Docker Volume and is a shared location with your computer.

# %% [markdown]
# #### Using the `world` DB, perform queries to answer the following questions.
#
# Additional references can be found here https://dev.mysql.com/doc/world-setup/en/
#
#
# Use a **single query** to answer the questions:
#
# 1. Which country has the largest population?
# 2. Get the total number of cities in Canada.
# 3. Select the country with the most cities.
# 4. List all the languages spoken in the Southeast Asia region.
# 5. Identify the 5 most spoken languages by number of countries.
# 6. What is the total population of the cities in the Caribbean region?
# 7. What Countries have a City named "Kingston"?
# 8. Plot the population density by country, limiting to the 25 with the least density.
# 9. Plot the GNP (Gross Nation Product) of all countries that become independent between 1850 and 1910, limiting to the 10 with the highest GNP.
# 10. Create a scatter plot of the life expectancy vs the GNP of all countries that have Spanish as their Official language.
#
#
# ##### Suggestions:
# - Start by inspecting the database tables' structure
# - When in doubt, check the table content by selecting only a few lines (use `LIMIT` to avoid returning all records)
# - Before finalizing the query, you can always perform "intermediate" queries to check if complex operations (e.g. `GROUP BY` and `JOIN`) are stated correctly

# %%
# %%sql
#
# USE world;
#
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 3 rows affected.
# [('city',), ('country',), ('countrylanguage',)]

# %% [markdown]
# #### 1 - Which country has the largest population?

# %%
# %%sql
#
# DESCRIBE country;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 15 rows affected.
# [('Code', 'char(3)', 'NO', 'PRI', '', ''),
#  ('Name', 'char(52)', 'NO', '', '', ''),
#  ('Continent', "enum('Asia','Europe','North America','Africa','Oceania','Antarctica','South America')", 'NO', '', 'Asia', ''),
#  ('Region', 'char(26)', 'NO', '', '', ''),
#  ('SurfaceArea', 'decimal(10,2)', 'NO', '', '0.00', ''),
#  ('IndepYear', 'smallint', 'YES', '', None, ''),
#  ('Population', 'int', 'NO', '', '0', ''),
#  ('LifeExpectancy', 'decimal(3,1)', 'YES', '', None, ''),
#  ('GNP', 'decimal(10,2)', 'YES', '', None, ''),
#  ('GNPOld', 'decimal(10,2)', 'YES', '', None, ''),
#  ('LocalName', 'char(45)', 'NO', '', '', ''),
#  ('GovernmentForm', 'char(45)', 'NO', '', '', ''),
#  ('HeadOfState', 'char(60)', 'YES', '', None, ''),
#  ('Capital', 'int', 'YES', '', None, ''),
#  ('Code2', 'char(2)', 'NO', '', '', '')]

# %%
# %%sql
#
# SELECT country.Code
# FROM country
# WHERE country.Name = "Canada"
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('CAN',)]

# %%
# %%sql
#
# SELECT  country.Name, country.Population AS Population
# FROM country
# ORDER BY  Population   DESC
# LIMIT 1;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('China', 1277558000)]

# %% [markdown]
# #### 2 - Get the total number of cities in Canada.

# %%
# %%sql
#
# SELECT COUNT(Name) AS CitiesInCanada
# FROM city
# WHERE city.CountryCode = "CAN";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(49,)]

# %%
# %%sql
#
# DESCRIBE country
# Out:
#  * mysql+mysqlconnector://root:***@db
# 15 rows affected.
# [('Code', 'char(3)', 'NO', 'PRI', '', ''),
#  ('Name', 'char(52)', 'NO', '', '', ''),
#  ('Continent', "enum('Asia','Europe','North America','Africa','Oceania','Antarctica','South America')", 'NO', '', 'Asia', ''),
#  ('Region', 'char(26)', 'NO', '', '', ''),
#  ('SurfaceArea', 'decimal(10,2)', 'NO', '', '0.00', ''),
#  ('IndepYear', 'smallint', 'YES', '', None, ''),
#  ('Population', 'int', 'NO', '', '0', ''),
#  ('LifeExpectancy', 'decimal(3,1)', 'YES', '', None, ''),
#  ('GNP', 'decimal(10,2)', 'YES', '', None, ''),
#  ('GNPOld', 'decimal(10,2)', 'YES', '', None, ''),
#  ('LocalName', 'char(45)', 'NO', '', '', ''),
#  ('GovernmentForm', 'char(45)', 'NO', '', '', ''),
#  ('HeadOfState', 'char(60)', 'YES', '', None, ''),
#  ('Capital', 'int', 'YES', '', None, ''),
#  ('Code2', 'char(2)', 'NO', '', '', '')]

# %% [markdown]
# #### 3 - Select the country with the most cities.

# %%
# %%sql
#
# SELECT COUNT(ID) as nCities, CountryCode
# FROM city
# GROUP BY CountryCode
# ORDER BY nCities DESC
# LIMIT 1;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(363, 'CHN')]

# %% [markdown]
# #### 4 - List all the languages spoken in the Southeast Asia region.

# %%
# %%sql
#
# DESCRIBE country
# Out:
#  * mysql+mysqlconnector://root:***@db
# 15 rows affected.
# [('Code', 'char(3)', 'NO', 'PRI', '', ''),
#  ('Name', 'char(52)', 'NO', '', '', ''),
#  ('Continent', "enum('Asia','Europe','North America','Africa','Oceania','Antarctica','South America')", 'NO', '', 'Asia', ''),
#  ('Region', 'char(26)', 'NO', '', '', ''),
#  ('SurfaceArea', 'decimal(10,2)', 'NO', '', '0.00', ''),
#  ('IndepYear', 'smallint', 'YES', '', None, ''),
#  ('Population', 'int', 'NO', '', '0', ''),
#  ('LifeExpectancy', 'decimal(3,1)', 'YES', '', None, ''),
#  ('GNP', 'decimal(10,2)', 'YES', '', None, ''),
#  ('GNPOld', 'decimal(10,2)', 'YES', '', None, ''),
#  ('LocalName', 'char(45)', 'NO', '', '', ''),
#  ('GovernmentForm', 'char(45)', 'NO', '', '', ''),
#  ('HeadOfState', 'char(60)', 'YES', '', None, ''),
#  ('Capital', 'int', 'YES', '', None, ''),
#  ('Code2', 'char(2)', 'NO', '', '', '')]

# %%
# %%sql
#
# SELECT DISTINCT(Region)
# FROM country
# Out:
#  * mysql+mysqlconnector://root:***@db
# 25 rows affected.
# [('Caribbean',),
#  ('Southern and Central Asia',),
#  ('Central Africa',),
#  ('Southern Europe',),
#  ('Middle East',),
#  ('South America',),
#  ('Polynesia',),
#  ('Antarctica',),
#  ('Australia and New Zealand',),
#  ('Western Europe',),
#  ('Eastern Africa',),
#  ('Western Africa',),
#  ('Eastern Europe',),
#  ('Central America',),
#  ('North America',),
#  ('Southeast Asia',),
#  ('Southern Africa',),
#  ('Eastern Asia',),
#  ('Nordic Countries',),
#  ('Northern Africa',),
#  ('Baltic Countries',),
#  ('Melanesia',),
#  ('Micronesia',),
#  ('British Islands',),
#  ('Micronesia/Caribbean',)]

# %%
# %%sql
#
# SELECT DISTINCT Language
# FROM countrylanguage
# INNER JOIN country ON countrylanguage.CountryCode = country.Code
# WHERE country.Region = "Southeast Asia";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 47 rows affected.
# [('Chinese',),
#  ('English',),
#  ('Malay',),
#  ('Malay-English',),
#  ('Bali',),
#  ('Banja',),
#  ('Batakki',),
#  ('Bugi',),
#  ('Javanese',),
#  ('Madura',),
#  ('Minangkabau',),
#  ('Sunda',),
#  ('Khmer',),
#  ('Tšam',),
#  ('Vietnamese',),
#  ('Lao',),
#  ('Lao-Soung',),
#  ('Mon-khmer',),
#  ('Thai',),
#  ('Burmese',),
#  ('Chin',),
#  ('Kachin',),
#  ('Karen',),
#  ('Kayah',),
#  ('Mon',),
#  ('Rakhine',),
#  ('Shan',),
#  ('Dusun',),
#  ('Iban',),
#  ('Tamil',),
#  ('Bicol',),
#  ('Cebuano',),
#  ('Hiligaynon',),
#  ('Ilocano',),
#  ('Maguindanao',),
#  ('Maranao',),
#  ('Pampango',),
#  ('Pangasinan',),
#  ('Pilipino',),
#  ('Waray-waray',),
#  ('Kuy',),
#  ('Portuguese',),
#  ('Man',),
#  ('Miao',),
#  ('Muong',),
#  ('Nung',),
#  ('Tho',)]

# %% [markdown]
# #### 5 - Identify the 5 most spoken languages by number of countries.

# %%
# %%sql
#
# SELECT *
# FROM countrylanguage
# LIMIT 10
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('ABW', 'Dutch', 'T', Decimal('5.3')),
#  ('ABW', 'English', 'F', Decimal('9.5')),
#  ('ABW', 'Papiamento', 'F', Decimal('76.7')),
#  ('ABW', 'Spanish', 'F', Decimal('7.4')),
#  ('AFG', 'Balochi', 'F', Decimal('0.9')),
#  ('AFG', 'Dari', 'T', Decimal('32.1')),
#  ('AFG', 'Pashto', 'T', Decimal('52.4')),
#  ('AFG', 'Turkmenian', 'F', Decimal('1.9')),
#  ('AFG', 'Uzbek', 'F', Decimal('8.8')),
#  ('AGO', 'Ambo', 'F', Decimal('2.4'))]

# %%
# %%sql
#
# SELECT language, COUNT(CountryCode) AS ncountries
# FROM countrylanguage
# GROUP BY Language
# ORDER BY ncountries DESC
# LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('English', 60),
#  ('Arabic', 33),
#  ('Spanish', 28),
#  ('French', 25),
#  ('German', 19),
#  ('Chinese', 19),
#  ('Russian', 17),
#  ('Italian', 15),
#  ('Creole English', 14),
#  ('Portuguese', 12)]

# %% [markdown]
# Show the countries where Italian is spoken.

# %%
# %%sql
#
# SELECT country.Name
# FROM countrylanguage
# INNER JOIN country ON countrylanguage.CountryCode = country.Code
# WHERE language = "Italian"
# Out:
#  * mysql+mysqlconnector://root:***@db
# 15 rows affected.
# [('Argentina',),
#  ('Australia',),
#  ('Belgium',),
#  ('Brazil',),
#  ('Canada',),
#  ('Switzerland',),
#  ('Germany',),
#  ('France',),
#  ('Italy',),
#  ('Liechtenstein',),
#  ('Luxembourg',),
#  ('Monaco',),
#  ('San Marino',),
#  ('United States',),
#  ('Holy See (Vatican City State)',)]

# %% [markdown]
# #### 6 - What is the total population of the cities in the Caribbean region?

# %%
# %%sql
#
# DESCRIBE city
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('ID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('Name', 'char(35)', 'NO', '', '', ''),
#  ('CountryCode', 'char(3)', 'NO', 'MUL', '', ''),
#  ('District', 'char(20)', 'NO', '', '', ''),
#  ('Population', 'int', 'NO', '', '0', '')]

# %%
# %%sql
#
# SELECT *
# FROM country
# JOIN city ON country.Code = city.CountryCode
# WHERE country.Region = "Caribbean";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 58 rows affected.
# [('ABW', 'Aruba', 'North America', 'Caribbean', Decimal('193.00'), None, 103000, Decimal('78.4'), Decimal('828.00'), Decimal('793.00'), 'Aruba', 'Nonmetropolitan Territory of The Netherlands', 'Beatrix', 129, 'AW', 129, 'Oranjestad', 'ABW', '–', 29034),
#  ('AIA', 'Anguilla', 'North America', 'Caribbean', Decimal('96.00'), None, 8000, Decimal('76.1'), Decimal('63.20'), None, 'Anguilla', 'Dependent Territory of the UK', 'Elisabeth II', 62, 'AI', 61, 'South Hill', 'AIA', '–', 961),
#  ('AIA', 'Anguilla', 'North America', 'Caribbean', Decimal('96.00'), None, 8000, Decimal('76.1'), Decimal('63.20'), None, 'Anguilla', 'Dependent Territory of the UK', 'Elisabeth II', 62, 'AI', 62, 'The Valley', 'AIA', '–', 595),
#  ('ANT', 'Netherlands Antilles', 'North America', 'Caribbean', Decimal('800.00'), None, 217000, Decimal('74.7'), Decimal('1941.00'), None, 'Nederlandse Antillen', 'Nonmetropolitan Territory of The Netherlands', 'Beatrix', 33, 'AN', 33, 'Willemstad', 'ANT', 'Curaçao', 2345),
#  ('ATG', 'Antigua and Barbuda', 'North America', 'Caribbean', Decimal('442.00'), 1981, 68000, Decimal('70.5'), Decimal('612.00'), Decimal('584.00'), 'Antigua and Barbuda', 'Constitutional Monarchy', 'Elisabeth II', 63, 'AG', 63, 'Saint John´s', 'ATG', 'St John', 24000),
#  ('BHS', 'Bahamas', 'North America', 'Caribbean', Decimal('13878.00'), 1973, 307000, Decimal('71.1'), Decimal('3527.00'), Decimal('3347.00'), 'The Bahamas', 'Constitutional Monarchy', 'Elisabeth II', 148, 'BS', 148, 'Nassau', 'BHS', 'New Providence', 172000),
#  ('BRB', 'Barbados', 'North America', 'Caribbean', Decimal('430.00'), 1966, 270000, Decimal('73.0'), Decimal('2223.00'), Decimal('2186.00'), 'Barbados', 'Constitutional Monarchy', 'Elisabeth II', 174, 'BB', 174, 'Bridgetown', 'BRB', 'St Michael', 6070),
#  ('CUB', 'Cuba', 'North America', 'Caribbean', Decimal('110861.00'), 1902, 11201000, Decimal('76.2'), Decimal('17843.00'), Decimal('18862.00'), 'Cuba', 'Socialistic Republic', 'Fidel Castro Ruz', 2413, 'CU', 2413, 'La Habana', 'CUB', 'La Habana', 2256000),
#  ('CUB', 'Cuba', 'North America', 'Caribbean', Decimal('110861.00'), 1902, 11201000, Decimal('76.2'), Decimal('17843.00'), Decimal('18862.00'), 'Cuba', 'Socialistic Republic', 'Fidel Castro Ruz', 2413, 'CU', 2414, 'Santiago de Cuba', 'CUB', 'Santiago de Cuba', 433180),
#  ('CUB', 'Cuba', 'North America', 'Caribbean', Decimal('110861.00'), 1902, 11201000, Decimal('76.2'), Decimal('17843.00'), Decimal('18862.00'), 'Cuba', 'Socialistic Republic', 'Fidel Castro Ruz', 2413, 'CU', 2415, 'Camagüey', 'CUB', 'Camagüey', 298726),
#  ('CUB', 'Cuba', 'North America', 'Caribbean', Decimal('110861.00'), 1902, 11201000, Decimal('76.2'), Decimal('17843.00'), Decimal('18862.00'), 'Cuba', 'Socialistic Republic', 'Fidel Castro Ruz', 2413, 'CU', 2416, 'Holguín', 'CUB', 'Holguín', 249492),
#  ('CUB', 'Cuba', 'North America', 'Caribbean', Decimal('110861.00'), 1902, 11201000, Decimal('76.2'), Decimal('17843.00'), Decimal('18862.00'), 'Cuba', 'Socialistic Republic', 'Fidel Castro Ruz', 2413, 'CU', 2417, 'Santa Clara', 'CUB', 'Villa Clara', 207350),
#  ('CUB', 'Cuba', 'North America', 'Caribbean', Decimal('110861.00'), 1902, 11201000, Decimal('76.2'), Decimal('17843.00'), Decimal('18862.00'), 'Cuba', 'Socialistic Republic', 'Fidel Castro Ruz', 2413, 'CU', 2418, 'Guantánamo', 'CUB', 'Guantánamo', 205078),
#  ('CUB', 'Cuba', 'North America', 'Caribbean', Decimal('110861.00'), 1902, 11201000, Decimal('76.2'), Decimal('17843.00'), Decimal('18862.00'), 'Cuba', 'Socialistic Republic', 'Fidel Castro Ruz', 2413, 'CU', 2419, 'Pinar del Río', 'CUB', 'Pinar del Río', 142100),
#  ('CUB', 'Cuba', 'North America', 'Caribbean', Decimal('110861.00'), 1902, 11201000, Decimal('76.2'), Decimal('17843.00'), Decimal('18862.00'), 'Cuba', 'Socialistic Republic', 'Fidel Castro Ruz', 2413, 'CU', 2420, 'Bayamo', 'CUB', 'Granma', 141000),
#  ('CUB', 'Cuba', 'North America', 'Caribbean', Decimal('110861.00'), 1902, 11201000, Decimal('76.2'), Decimal('17843.00'), Decimal('18862.00'), 'Cuba', 'Socialistic Republic', 'Fidel Castro Ruz', 2413, 'CU', 2421, 'Cienfuegos', 'CUB', 'Cienfuegos', 132770),
#  ('CUB', 'Cuba', 'North America', 'Caribbean', Decimal('110861.00'), 1902, 11201000, Decimal('76.2'), Decimal('17843.00'), Decimal('18862.00'), 'Cuba', 'Socialistic Republic', 'Fidel Castro Ruz', 2413, 'CU', 2422, 'Victoria de las Tunas', 'CUB', 'Las Tunas', 132350),
#  ('CUB', 'Cuba', 'North America', 'Caribbean', Decimal('110861.00'), 1902, 11201000, Decimal('76.2'), Decimal('17843.00'), Decimal('18862.00'), 'Cuba', 'Socialistic Republic', 'Fidel Castro Ruz', 2413, 'CU', 2423, 'Matanzas', 'CUB', 'Matanzas', 123273),
#  ('CUB', 'Cuba', 'North America', 'Caribbean', Decimal('110861.00'), 1902, 11201000, Decimal('76.2'), Decimal('17843.00'), Decimal('18862.00'), 'Cuba', 'Socialistic Republic', 'Fidel Castro Ruz', 2413, 'CU', 2424, 'Manzanillo', 'CUB', 'Granma', 109350),
#  ('CUB', 'Cuba', 'North America', 'Caribbean', Decimal('110861.00'), 1902, 11201000, Decimal('76.2'), Decimal('17843.00'), Decimal('18862.00'), 'Cuba', 'Socialistic Republic', 'Fidel Castro Ruz', 2413, 'CU', 2425, 'Sancti-Spíritus', 'CUB', 'Sancti-Spíritus', 100751),
#  ('CUB', 'Cuba', 'North America', 'Caribbean', Decimal('110861.00'), 1902, 11201000, Decimal('76.2'), Decimal('17843.00'), Decimal('18862.00'), 'Cuba', 'Socialistic Republic', 'Fidel Castro Ruz', 2413, 'CU', 2426, 'Ciego de Ávila', 'CUB', 'Ciego de Ávila', 98505),
#  ('CYM', 'Cayman Islands', 'North America', 'Caribbean', Decimal('264.00'), None, 38000, Decimal('78.9'), Decimal('1263.00'), Decimal('1186.00'), 'Cayman Islands', 'Dependent Territory of the UK', 'Elisabeth II', 553, 'KY', 553, 'George Town', 'CYM', 'Grand Cayman', 19600),
#  ('DMA', 'Dominica', 'North America', 'Caribbean', Decimal('751.00'), 1978, 71000, Decimal('73.4'), Decimal('256.00'), Decimal('243.00'), 'Dominica', 'Republic', 'Vernon Shaw', 586, 'DM', 586, 'Roseau', 'DMA', 'St George', 16243),
#  ('DOM', 'Dominican Republic', 'North America', 'Caribbean', Decimal('48511.00'), 1844, 8495000, Decimal('73.2'), Decimal('15846.00'), Decimal('15076.00'), 'República Dominicana', 'Republic', 'Hipólito Mejía Domínguez', 587, 'DO', 587, 'Santo Domingo de Guzmán', 'DOM', 'Distrito Nacional', 1609966),
#  ('DOM', 'Dominican Republic', 'North America', 'Caribbean', Decimal('48511.00'), 1844, 8495000, Decimal('73.2'), Decimal('15846.00'), Decimal('15076.00'), 'República Dominicana', 'Republic', 'Hipólito Mejía Domínguez', 587, 'DO', 588, 'Santiago de los Caballeros', 'DOM', 'Santiago', 365463),
#  ('DOM', 'Dominican Republic', 'North America', 'Caribbean', Decimal('48511.00'), 1844, 8495000, Decimal('73.2'), Decimal('15846.00'), Decimal('15076.00'), 'República Dominicana', 'Republic', 'Hipólito Mejía Domínguez', 587, 'DO', 589, 'La Romana', 'DOM', 'La Romana', 140204),
#  ('DOM', 'Dominican Republic', 'North America', 'Caribbean', Decimal('48511.00'), 1844, 8495000, Decimal('73.2'), Decimal('15846.00'), Decimal('15076.00'), 'República Dominicana', 'Republic', 'Hipólito Mejía Domínguez', 587, 'DO', 590, 'San Pedro de Macorís', 'DOM', 'San Pedro de Macorís', 124735),
#  ('DOM', 'Dominican Republic', 'North America', 'Caribbean', Decimal('48511.00'), 1844, 8495000, Decimal('73.2'), Decimal('15846.00'), Decimal('15076.00'), 'República Dominicana', 'Republic', 'Hipólito Mejía Domínguez', 587, 'DO', 591, 'San Francisco de Macorís', 'DOM', 'Duarte', 108485),
#  ('DOM', 'Dominican Republic', 'North America', 'Caribbean', Decimal('48511.00'), 1844, 8495000, Decimal('73.2'), Decimal('15846.00'), Decimal('15076.00'), 'República Dominicana', 'Republic', 'Hipólito Mejía Domínguez', 587, 'DO', 592, 'San Felipe de Puerto Plata', 'DOM', 'Puerto Plata', 89423),
#  ('GLP', 'Guadeloupe', 'North America', 'Caribbean', Decimal('1705.00'), None, 456000, Decimal('77.0'), Decimal('3501.00'), None, 'Guadeloupe', 'Overseas Department of France', 'Jacques Chirac', 919, 'GP', 918, 'Les Abymes', 'GLP', 'Grande-Terre', 62947),
#  ('GLP', 'Guadeloupe', 'North America', 'Caribbean', Decimal('1705.00'), None, 456000, Decimal('77.0'), Decimal('3501.00'), None, 'Guadeloupe', 'Overseas Department of France', 'Jacques Chirac', 919, 'GP', 919, 'Basse-Terre', 'GLP', 'Basse-Terre', 12433),
#  ('GRD', 'Grenada', 'North America', 'Caribbean', Decimal('344.00'), 1974, 94000, Decimal('64.5'), Decimal('318.00'), None, 'Grenada', 'Constitutional Monarchy', 'Elisabeth II', 916, 'GD', 916, 'Saint George´s', 'GRD', 'St George', 4621),
#  ('HTI', 'Haiti', 'North America', 'Caribbean', Decimal('27750.00'), 1804, 8222000, Decimal('49.2'), Decimal('3459.00'), Decimal('3107.00'), 'Haïti/Dayti', 'Republic', 'Jean-Bertrand Aristide', 929, 'HT', 929, 'Port-au-Prince', 'HTI', 'Ouest', 884472),
#  ('HTI', 'Haiti', 'North America', 'Caribbean', Decimal('27750.00'), 1804, 8222000, Decimal('49.2'), Decimal('3459.00'), Decimal('3107.00'), 'Haïti/Dayti', 'Republic', 'Jean-Bertrand Aristide', 929, 'HT', 930, 'Carrefour', 'HTI', 'Ouest', 290204),
#  ('HTI', 'Haiti', 'North America', 'Caribbean', Decimal('27750.00'), 1804, 8222000, Decimal('49.2'), Decimal('3459.00'), Decimal('3107.00'), 'Haïti/Dayti', 'Republic', 'Jean-Bertrand Aristide', 929, 'HT', 931, 'Delmas', 'HTI', 'Ouest', 240429),
#  ('HTI', 'Haiti', 'North America', 'Caribbean', Decimal('27750.00'), 1804, 8222000, Decimal('49.2'), Decimal('3459.00'), Decimal('3107.00'), 'Haïti/Dayti', 'Republic', 'Jean-Bertrand Aristide', 929, 'HT', 932, 'Le-Cap-Haïtien', 'HTI', 'Nord', 102233),
#  ('JAM', 'Jamaica', 'North America', 'Caribbean', Decimal('10990.00'), 1962, 2583000, Decimal('75.2'), Decimal('6871.00'), Decimal('6722.00'), 'Jamaica', 'Constitutional Monarchy', 'Elisabeth II', 1530, 'JM', 1529, 'Spanish Town', 'JAM', 'St. Catherine', 110379),
#  ('JAM', 'Jamaica', 'North America', 'Caribbean', Decimal('10990.00'), 1962, 2583000, Decimal('75.2'), Decimal('6871.00'), Decimal('6722.00'), 'Jamaica', 'Constitutional Monarchy', 'Elisabeth II', 1530, 'JM', 1530, 'Kingston', 'JAM', 'St. Andrew', 103962),
#  ('JAM', 'Jamaica', 'North America', 'Caribbean', Decimal('10990.00'), 1962, 2583000, Decimal('75.2'), Decimal('6871.00'), Decimal('6722.00'), 'Jamaica', 'Constitutional Monarchy', 'Elisabeth II', 1530, 'JM', 1531, 'Portmore', 'JAM', 'St. Andrew', 99799),
#  ('KNA', 'Saint Kitts and Nevis', 'North America', 'Caribbean', Decimal('261.00'), 1983, 38000, Decimal('70.7'), Decimal('299.00'), None, 'Saint Kitts and Nevis', 'Constitutional Monarchy', 'Elisabeth II', 3064, 'KN', 3064, 'Basseterre', 'KNA', 'St George Basseterre', 11600),
#  ('LCA', 'Saint Lucia', 'North America', 'Caribbean', Decimal('622.00'), 1979, 154000, Decimal('72.3'), Decimal('571.00'), None, 'Saint Lucia', 'Constitutional Monarchy', 'Elisabeth II', 3065, 'LC', 3065, 'Castries', 'LCA', 'Castries', 2301),
#  ('MSR', 'Montserrat', 'North America', 'Caribbean', Decimal('102.00'), None, 11000, Decimal('78.0'), Decimal('109.00'), None, 'Montserrat', 'Dependent Territory of the UK', 'Elisabeth II', 2697, 'MS', 2697, 'Plymouth', 'MSR', 'Plymouth', 2000),
#  ('MTQ', 'Martinique', 'North America', 'Caribbean', Decimal('1102.00'), None, 395000, Decimal('78.3'), Decimal('2731.00'), Decimal('2559.00'), 'Martinique', 'Overseas Department of France', 'Jacques Chirac', 2508, 'MQ', 2508, 'Fort-de-France', 'MTQ', 'Fort-de-France', 94050),
#  ('PRI', 'Puerto Rico', 'North America', 'Caribbean', Decimal('8875.00'), None, 3869000, Decimal('75.6'), Decimal('34100.00'), Decimal('32100.00'), 'Puerto Rico', 'Commonwealth of the US', 'George W. Bush', 2919, 'PR', 2919, 'San Juan', 'PRI', 'San Juan', 434374),
#  ('PRI', 'Puerto Rico', 'North America', 'Caribbean', Decimal('8875.00'), None, 3869000, Decimal('75.6'), Decimal('34100.00'), Decimal('32100.00'), 'Puerto Rico', 'Commonwealth of the US', 'George W. Bush', 2919, 'PR', 2920, 'Bayamón', 'PRI', 'Bayamón', 224044),
#  ('PRI', 'Puerto Rico', 'North America', 'Caribbean', Decimal('8875.00'), None, 3869000, Decimal('75.6'), Decimal('34100.00'), Decimal('32100.00'), 'Puerto Rico', 'Commonwealth of the US', 'George W. Bush', 2919, 'PR', 2921, 'Ponce', 'PRI', 'Ponce', 186475),
#  ('PRI', 'Puerto Rico', 'North America', 'Caribbean', Decimal('8875.00'), None, 3869000, Decimal('75.6'), Decimal('34100.00'), Decimal('32100.00'), 'Puerto Rico', 'Commonwealth of the US', 'George W. Bush', 2919, 'PR', 2922, 'Carolina', 'PRI', 'Carolina', 186076),
#  ('PRI', 'Puerto Rico', 'North America', 'Caribbean', Decimal('8875.00'), None, 3869000, Decimal('75.6'), Decimal('34100.00'), Decimal('32100.00'), 'Puerto Rico', 'Commonwealth of the US', 'George W. Bush', 2919, 'PR', 2923, 'Caguas', 'PRI', 'Caguas', 140502),
#  ('PRI', 'Puerto Rico', 'North America', 'Caribbean', Decimal('8875.00'), None, 3869000, Decimal('75.6'), Decimal('34100.00'), Decimal('32100.00'), 'Puerto Rico', 'Commonwealth of the US', 'George W. Bush', 2919, 'PR', 2924, 'Arecibo', 'PRI', 'Arecibo', 100131),
#  ('PRI', 'Puerto Rico', 'North America', 'Caribbean', Decimal('8875.00'), None, 3869000, Decimal('75.6'), Decimal('34100.00'), Decimal('32100.00'), 'Puerto Rico', 'Commonwealth of the US', 'George W. Bush', 2919, 'PR', 2925, 'Guaynabo', 'PRI', 'Guaynabo', 100053),
#  ('PRI', 'Puerto Rico', 'North America', 'Caribbean', Decimal('8875.00'), None, 3869000, Decimal('75.6'), Decimal('34100.00'), Decimal('32100.00'), 'Puerto Rico', 'Commonwealth of the US', 'George W. Bush', 2919, 'PR', 2926, 'Mayagüez', 'PRI', 'Mayagüez', 98434),
#  ('PRI', 'Puerto Rico', 'North America', 'Caribbean', Decimal('8875.00'), None, 3869000, Decimal('75.6'), Decimal('34100.00'), Decimal('32100.00'), 'Puerto Rico', 'Commonwealth of the US', 'George W. Bush', 2919, 'PR', 2927, 'Toa Baja', 'PRI', 'Toa Baja', 94085),
#  ('TCA', 'Turks and Caicos Islands', 'North America', 'Caribbean', Decimal('430.00'), None, 17000, Decimal('73.3'), Decimal('96.00'), None, 'The Turks and Caicos Islands', 'Dependent Territory of the UK', 'Elisabeth II', 3423, 'TC', 3423, 'Cockburn Town', 'TCA', 'Grand Turk', 4800),
#  ('TTO', 'Trinidad and Tobago', 'North America', 'Caribbean', Decimal('5130.00'), 1962, 1295000, Decimal('68.0'), Decimal('6232.00'), Decimal('5867.00'), 'Trinidad and Tobago', 'Republic', 'Arthur N. R. Robinson', 3336, 'TT', 3335, 'Chaguanas', 'TTO', 'Caroni', 56601),
#  ('TTO', 'Trinidad and Tobago', 'North America', 'Caribbean', Decimal('5130.00'), 1962, 1295000, Decimal('68.0'), Decimal('6232.00'), Decimal('5867.00'), 'Trinidad and Tobago', 'Republic', 'Arthur N. R. Robinson', 3336, 'TT', 3336, 'Port-of-Spain', 'TTO', 'Port-of-Spain', 43396),
#  ('VCT', 'Saint Vincent and the Grenadines', 'North America', 'Caribbean', Decimal('388.00'), 1979, 114000, Decimal('72.3'), Decimal('285.00'), None, 'Saint Vincent and the Grenadines', 'Constitutional Monarchy', 'Elisabeth II', 3066, 'VC', 3066, 'Kingstown', 'VCT', 'St George', 17100),
#  ('VGB', 'Virgin Islands, British', 'North America', 'Caribbean', Decimal('151.00'), None, 21000, Decimal('75.4'), Decimal('612.00'), Decimal('573.00'), 'British Virgin Islands', 'Dependent Territory of the UK', 'Elisabeth II', 537, 'VG', 537, 'Road Town', 'VGB', 'Tortola', 8000),
#  ('VIR', 'Virgin Islands, U.S.', 'North America', 'Caribbean', Decimal('347.00'), None, 93000, Decimal('78.1'), Decimal('0.00'), None, 'Virgin Islands of the United States', 'US Territory', 'George W. Bush', 4067, 'VI', 4067, 'Charlotte Amalie', 'VIR', 'St Thomas', 13000)]

# %%
# %%sql
#
# SELECT SUM(city.Population) as total_population
# FROM country
# JOIN city ON country.Code = city.CountryCode
# WHERE country.Region = "Caribbean";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(Decimal('11067550'),)]

# %% [markdown]
# As it can be seen in the example above, the JOIN command creates a table made from the two joint table and then you refer to it through the FROM statement. The table specified before the LEFT JOIN (in this case, 'country') is considered the left table, and the table specified after the LEFT JOIN (in this case, 'city') is considered the right table.

# %% [markdown]
# #### 7 - What Countries have a City named "Kingston"?

# %%
# %%sql
#
# SELECT *
# FROM city
# WHERE city.Name = "Kingston"
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(1530, 'Kingston', 'JAM', 'St. Andrew', 103962),
#  (2806, 'Kingston', 'NFK', '–', 800)]

# %%
# %%sql
#
# SELECT country.Name
# FROM city
# RIGHT JOIN country ON city.CountryCode = country.Code
# WHERE city.Name = "Kingston";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('Jamaica',), ('Norfolk Island',)]

# %% [markdown]
# #### 8 - Plot the population density by country, limiting to the 25 with the least density.

# %% [markdown]
# The population density is the total `Population` of a country divided by the `SurfaceArea`.
# We can compute this quantity on the fly during a `SELECT` statement and rename it with an `ALIAS` for convenience.

# %%
# %%sql
#
# DESCRIBE country
# Out:
#  * mysql+mysqlconnector://root:***@db
# 15 rows affected.
# [('Code', 'char(3)', 'NO', 'PRI', '', ''),
#  ('Name', 'char(52)', 'NO', '', '', ''),
#  ('Continent', "enum('Asia','Europe','North America','Africa','Oceania','Antarctica','South America')", 'NO', '', 'Asia', ''),
#  ('Region', 'char(26)', 'NO', '', '', ''),
#  ('SurfaceArea', 'decimal(10,2)', 'NO', '', '0.00', ''),
#  ('IndepYear', 'smallint', 'YES', '', None, ''),
#  ('Population', 'int', 'NO', '', '0', ''),
#  ('LifeExpectancy', 'decimal(3,1)', 'YES', '', None, ''),
#  ('GNP', 'decimal(10,2)', 'YES', '', None, ''),
#  ('GNPOld', 'decimal(10,2)', 'YES', '', None, ''),
#  ('LocalName', 'char(45)', 'NO', '', '', ''),
#  ('GovernmentForm', 'char(45)', 'NO', '', '', ''),
#  ('HeadOfState', 'char(60)', 'YES', '', None, ''),
#  ('Capital', 'int', 'YES', '', None, ''),
#  ('Code2', 'char(2)', 'NO', '', '', '')]

# %%
# %%sql
#
# SELECT population/SurfaceArea AS Density, Name, Population, SurfaceArea
# FROM country
# ORDER BY Density ASC
# LIMIT 25
# Out:
#  * mysql+mysqlconnector://root:***@db
# 25 rows affected.
# [(Decimal('0.0000'), 'United States Minor Outlying Islands', 0, Decimal('16.00')),
#  (Decimal('0.0000'), 'British Indian Ocean Territory', 0, Decimal('78.00')),
#  (Decimal('0.0000'), 'Heard Island and McDonald Islands', 0, Decimal('359.00')),
#  (Decimal('0.0000'), 'South Georgia and the South Sandwich Islands', 0, Decimal('3903.00')),
#  (Decimal('0.0000'), 'Bouvet Island', 0, Decimal('59.00')),
#  (Decimal('0.0000'), 'French Southern territories', 0, Decimal('7780.00')),
#  (Decimal('0.0000'), 'Antarctica', 0, Decimal('13120000.00')),
#  (Decimal('0.0259'), 'Greenland', 56000, Decimal('2166090.00')),
#  (Decimal('0.0513'), 'Svalbard and Jan Mayen', 3200, Decimal('62422.00')),
#  (Decimal('0.1643'), 'Falkland Islands', 2000, Decimal('12173.00')),
#  (Decimal('1.0204'), 'Pitcairn', 50, Decimal('49.00')),
#  (Decimal('1.1015'), 'Western Sahara', 293000, Decimal('266000.00')),
#  (Decimal('1.6993'), 'Mongolia', 2662000, Decimal('1566500.00')),
#  (Decimal('2.0111'), 'French Guiana', 181000, Decimal('90000.00')),
#  (Decimal('2.0939'), 'Namibia', 1726000, Decimal('824292.00')),
#  (Decimal('2.4397'), 'Australia', 18886000, Decimal('7741220.00')),
#  (Decimal('2.5541'), 'Suriname', 417000, Decimal('163265.00')),
#  (Decimal('2.6036'), 'Mauritania', 2670000, Decimal('1025520.00')),
#  (Decimal('2.7087'), 'Iceland', 279000, Decimal('103000.00')),
#  (Decimal('2.7882'), 'Botswana', 1622000, Decimal('581730.00')),
#  (Decimal('3.1239'), 'Canada', 31147000, Decimal('9970610.00')),
#  (Decimal('3.1855'), 'Libyan Arab Jamahiriya', 5605000, Decimal('1759540.00')),
#  (Decimal('4.0052'), 'Guyana', 861000, Decimal('214969.00')),
#  (Decimal('4.5803'), 'Gabon', 1226000, Decimal('267668.00')),
#  (Decimal('5.8027'), 'Central African Republic', 3615000, Decimal('622984.00'))]

# %%
res_ = %sql SELECT population/SurfaceArea AS Density, Name FROM country ORDER BY Density ASC LIMIT 25;

print(res_)

plt.figure(figsize=(16,3))
res_.bar();
plt.xticks(rotation='vertical');
# Out:
#  * mysql+mysqlconnector://root:***@db
# 25 rows affected.
# +---------+----------------------------------------------+
# | Density |                     Name                     |
# +---------+----------------------------------------------+
# |  0.0000 |     United States Minor Outlying Islands     |
# |  0.0000 |        British Indian Ocean Territory        |
# |  0.0000 |      Heard Island and McDonald Islands       |
# |  0.0000 | South Georgia and the South Sandwich Islands |
# |  0.0000 |                Bouvet Island                 |
# |  0.0000 |         French Southern territories          |
# |  0.0000 |                  Antarctica                  |
# |  0.0259 |                  Greenland                   |
# |  0.0513 |            Svalbard and Jan Mayen            |
# |  0.1643 |               Falkland Islands               |
# |  1.0204 |                   Pitcairn                   |
# |  1.1015 |                Western Sahara                |
# |  1.6993 |                   Mongolia                   |
# |  2.0111 |                French Guiana                 |
# |  2.0939 |                   Namibia                    |
# |  2.4397 |                  Australia                   |
# |  2.5541 |                   Suriname                   |
# |  2.6036 |                  Mauritania                  |
# |  2.7087 |                   Iceland                    |
# |  2.7882 |                   Botswana                   |
# |  3.1239 |                    Canada                    |
# |  3.1855 |            Libyan Arab Jamahiriya            |
# |  4.0052 |                    Guyana                    |
# |  4.5803 |                    Gabon                     |
# |  5.8027 |           Central African Republic           |
# +---------+----------------------------------------------+

# %% [markdown]
# #### 9 - Plot the GNP (Gross Nation Product) of all countries that become independent between 1850 and 1910, limiting to the 10 with the highest GNP

# %% [markdown]
# We can use `BETWEEN a AND b` to select only those entries between two extremes;

# %%
# %%sql
#
# DESCRIBE country;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 15 rows affected.
# [('Code', 'char(3)', 'NO', 'PRI', '', ''),
#  ('Name', 'char(52)', 'NO', '', '', ''),
#  ('Continent', "enum('Asia','Europe','North America','Africa','Oceania','Antarctica','South America')", 'NO', '', 'Asia', ''),
#  ('Region', 'char(26)', 'NO', '', '', ''),
#  ('SurfaceArea', 'decimal(10,2)', 'NO', '', '0.00', ''),
#  ('IndepYear', 'smallint', 'YES', '', None, ''),
#  ('Population', 'int', 'NO', '', '0', ''),
#  ('LifeExpectancy', 'decimal(3,1)', 'YES', '', None, ''),
#  ('GNP', 'decimal(10,2)', 'YES', '', None, ''),
#  ('GNPOld', 'decimal(10,2)', 'YES', '', None, ''),
#  ('LocalName', 'char(45)', 'NO', '', '', ''),
#  ('GovernmentForm', 'char(45)', 'NO', '', '', ''),
#  ('HeadOfState', 'char(60)', 'YES', '', None, ''),
#  ('Capital', 'int', 'YES', '', None, ''),
#  ('Code2', 'char(2)', 'NO', '', '', '')]

# %%
# %%sql
#
# SELECT  Name, GNP, IndepYear
# FROM country
# WHERE IndepYear
# BETWEEN 1850
# AND 1910
# ORDER BY GNP DESC
# LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('Italy', Decimal('1161755.00'), 1861),
#  ('Canada', Decimal('598862.00'), 1867),
#  ('Australia', Decimal('351182.00'), 1901),
#  ('Iran', Decimal('195746.00'), 1906),
#  ('Norway', Decimal('145895.00'), 1905),
#  ('South Africa', Decimal('116729.00'), 1910),
#  ('New Zealand', Decimal('54669.00'), 1907),
#  ('Romania', Decimal('38158.00'), 1878),
#  ('Cuba', Decimal('17843.00'), 1902),
#  ('Luxembourg', Decimal('16321.00'), 1867)]

# %%
res_ = %sql SELECT  Name, GNP FROM country WHERE IndepYear BETWEEN 1850 AND 1910 ORDER BY GNP DESC LIMIT 10;

print(res_)

plt.figure(figsize=(16,3))
res_.bar();
plt.xticks(rotation='vertical');
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# +--------------+------------+
# |     Name     |    GNP     |
# +--------------+------------+
# |    Italy     | 1161755.00 |
# |    Canada    | 598862.00  |
# |  Australia   | 351182.00  |
# |     Iran     | 195746.00  |
# |    Norway    | 145895.00  |
# | South Africa | 116729.00  |
# | New Zealand  |  54669.00  |
# |   Romania    |  38158.00  |
# |     Cuba     |  17843.00  |
# |  Luxembourg  |  16321.00  |
# +--------------+------------+

# %% [markdown]
# #### 10 - Create a scatter plot of the life expectancy vs the GNP of all countries that have Spanish as their Official language

# %%
# %%sql
#
# DESCRIBE countrylanguage
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('CountryCode', 'char(3)', 'NO', 'PRI', '', ''),
#  ('Language', 'char(30)', 'NO', 'PRI', '', ''),
#  ('IsOfficial', "enum('T','F')", 'NO', '', 'F', ''),
#  ('Percentage', 'decimal(4,1)', 'NO', '', '0.0', '')]

# %%
# %%sql
#
# SELECT LifeExpectancy, GNP
# FROM country
# RIGHT JOIN countrylanguage ON countrylanguage.CountryCode = country.Code
# WHERE Language = "Spanish"
# AND IsOfficial = "T"
# Out:
#  * mysql+mysqlconnector://root:***@db
# 20 rows affected.
# [(Decimal('75.1'), Decimal('340238.00')),
#  (Decimal('63.7'), Decimal('8571.00')),
#  (Decimal('75.7'), Decimal('72949.00')),
#  (Decimal('70.3'), Decimal('102896.00')),
#  (Decimal('75.8'), Decimal('10226.00')),
#  (Decimal('76.2'), Decimal('17843.00')),
#  (Decimal('73.2'), Decimal('15846.00')),
#  (Decimal('71.1'), Decimal('19770.00')),
#  (Decimal('78.8'), Decimal('553233.00')),
#  (Decimal('66.2'), Decimal('19008.00')),
#  (Decimal('69.9'), Decimal('5333.00')),
#  (Decimal('71.5'), Decimal('414972.00')),
#  (Decimal('68.7'), Decimal('1988.00')),
#  (Decimal('75.5'), Decimal('9131.00')),
#  (Decimal('70.0'), Decimal('64140.00')),
#  (Decimal('75.6'), Decimal('34100.00')),
#  (Decimal('73.7'), Decimal('8444.00')),
#  (Decimal('69.7'), Decimal('11863.00')),
#  (Decimal('75.2'), Decimal('20831.00')),
#  (Decimal('73.1'), Decimal('95023.00'))]

# %%
res_ = %sql SELECT LifeExpectancy, GNP, country.Code\
FROM country \
RIGHT JOIN countrylanguage ON countrylanguage.CountryCode = country.Code \
WHERE Language = "Spanish" \
AND IsOfficial = "T" ;

print(res_)

plt.figure(figsize=(8,6))
for _ in res_:
    plt.scatter(_[0],_[1],s=50);
    plt.annotate(_[2], (float(_[0])*1.002,float(_[1])*1.002));
plt.ylabel('GNP')
plt.xlabel('LifeExpectancy')
# Out:
#  * mysql+mysqlconnector://root:***@db
# 20 rows affected.
# +----------------+-----------+------+
# | LifeExpectancy |    GNP    | Code |
# +----------------+-----------+------+
# |      75.1      | 340238.00 | ARG  |
# |      63.7      |  8571.00  | BOL  |
# |      75.7      |  72949.00 | CHL  |
# |      70.3      | 102896.00 | COL  |
# |      75.8      |  10226.00 | CRI  |
# |      76.2      |  17843.00 | CUB  |
# |      73.2      |  15846.00 | DOM  |
# |      71.1      |  19770.00 | ECU  |
# |      78.8      | 553233.00 | ESP  |
# |      66.2      |  19008.00 | GTM  |
# |      69.9      |  5333.00  | HND  |
# |      71.5      | 414972.00 | MEX  |
# |      68.7      |  1988.00  | NIC  |
# |      75.5      |  9131.00  | PAN  |
# |      70.0      |  64140.00 | PER  |
# |      75.6      |  34100.00 | PRI  |
# |      73.7      |  8444.00  | PRY  |
# |      69.7      |  11863.00 | SLV  |
# |      75.2      |  20831.00 | URY  |
# |      73.1      |  95023.00 | VEN  |
# +----------------+-----------+------+
# Text(0.5, 0, 'LifeExpectancy')

# %% [markdown]
# ## 06 More on queries

# %% [markdown]
# Let's import a well-structured database, with several tables and relationships, to be used as a sandbox for further exercises on queries.
#
# The database is freely available and is taken from the IMDb (Internet Movie Database) website (https://www.imdb.com/interfaces/), although severely slimmed down.
#
# This database contains several tables with information about movies, TV shows, people involved in the entertainment industry, and more, spanning from the 1890s to recent years.
#
# To simplify the execution of queries, we will work with a slimmed-down version of the entire database, with still plenty of records for us to extract interesting information.
#
# To start working with the IMDb database, we need to import it into our environment. The database `.sql` file should be downloaded from the link on Moodle and copied into the `/mysql/dbs` folder of the GitHub repository so that it will be found in the mounted volume at the location: `/mapd-workspace/dbs/IMDb_pruned.sql`.

# %% [markdown]
# 1. Create a new DB named `IMDb`
# 2. Import the content of the file `/mapd-workspace/dbs/IMDb_pruned.sql` into the newly created DB
# (this might take a minute or two...)

# %% [markdown]
# ### Check which tables are available

# %%
# %%sql
#
# USE IMDb;
#
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 7 rows affected.
# [('Directors',),
#  ('Episode_belongs_to',),
#  ('Had_role',),
#  ('Names_',),
#  ('Title_genres',),
#  ('Title_ratings',),
#  ('Titles',)]

# %% [markdown]
# The next cell is required to set the Python environment:

# %%
db = mysql.connector.connect(
  user="root",
  password="root_pwd",
  host="db"
)

dbc = db.cursor()

dbc.execute("USE IMDb")

# %% [markdown]
# ### Describe the content of table `Names_`

# %%
# %%sql
#
# DESCRIBE Names_
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('name_id', 'varchar(255)', 'NO', '', None, ''),
#  ('name_', 'varchar(255)', 'NO', '', None, ''),
#  ('birth_year', 'smallint', 'YES', '', None, ''),
#  ('death_year', 'smallint', 'YES', '', None, '')]

# %% [markdown]
# ### Study the distribution of the year of birth of all people included in the database
#
# 1. Start by limiting the query to 1000 entries
#     1. Draw a histogram of the year of birth
#     1. Draw a second histogram with the year of birth of the 1000 youngest people in the list

# %%
import pandas as pd

# %%
# %%sql
#
# SELECT birth_year, COUNT(*) AS Occurences
# FROM Names_
# GROUP BY birth_year
# LIMIT 10
# Out:
#  * mysql+mysqlconnector://root:***@db

# %%
import matplotlib.pyplot as plt

# %%
# 1.A
res_ = %sql SELECT birth_year, COUNT(*) AS Occurrences FROM Names_ GROUP BY birth_year LIMIT 1000;

#print(res_)

plt.figure(figsize=(20,7))
res_.bar();
plt.xticks(rotation='vertical');

# %%
# %%sql
#
# SELECT birth_year, COUNT(*) AS Occurences
# FROM Names_
# GROUP BY birth_year
# ORDER BY birth_year DESC
# LIMIT 10

# %%
# 1.B
res_ = %sql SELECT birth_year, COUNT(*) AS Occurrences FROM Names_ GROUP BY birth_year ORDER BY birth_year DESC LIMIT 1000;

#print(res_)

plt.figure(figsize=(30,7))
res_.bar();
plt.xticks(rotation='vertical');

# %%
## versione di Pazzini
import itertools
dbc.execute("SELECT birth_year FROM Names_ ORDER BY birth_year DESC LIMIT 1000 ")
myresult = dbc.fetchall()  
plt.hist(list(itertools.chain(*myresult)));
plt.xlabel('year');
plt.ylabel('count');

# %% [markdown]
# 2. Extend the query to all records in the table
#     1. Check for outliers (inspect min and max)
#     2. If any outlier is found, limit the query to a reasonable range (say... at least people born after 1850)
#     3. Draw a new histogram with the year of birth
#     4. Compute the mean and standard deviation of the year of birth

# %%
# %%sql
# #2.A: Check for outliers (inspect min and max)
#
# SELECT birth_year, name_
# FROM Names_
# ORDER BY birth_year ASC
# LIMIT 5;

# %%
# %%sql
#
# SELECT birth_year, name_
# FROM Names_
# ORDER BY birth_year DESC
# LIMIT 5;

# %% [markdown]
# As can be seen above, there are two outliers, Karen Abercrombie (birth_year = 13) and Sophie Oliver (birth_year = 1088).

# %%
# %%sql
# # 2.B: If any outlier is found, limit the query to a reasonable range (say... at least people born after 1850)
#
# SELECT birth_year, COUNT(*) AS Occurences
# FROM Names_
# WHERE birth_year
# BETWEEN 1850
# AND 2024
# GROUP BY birth_year
# ORDER BY birth_year DESC
# LIMIT 10

# %%
# 2.C 
# Pazzini way

dbc.execute("SELECT birth_year FROM Names_ WHERE birth_year BETWEEN 1850 AND 2024 ORDER BY birth_year DESC LIMIT 1000")
results = dbc.fetchall()
plt.hist(list(itertools.chain(*myresult)));
plt.xlabel('year');
plt.ylabel('count');

# %%
# 2.C 
# My way
res_ = %sql SELECT birth_year, COUNT(*) AS Occurences FROM Names_ WHERE birth_year BETWEEN 1850 AND 2024 GROUP BY birth_year ORDER BY birth_year DESC LIMIT 1000;

plt.figure(figsize=(30,7))
res_.bar();
plt.xticks(rotation='vertical');

# %%
import numpy as np

# %%
# 2.D
mean = np.mean(results)
print("Mean:",mean)
std = np.std(results)
print("Standard deviation:",std)

# %% [markdown]
# ### Movie stats
#
# 1. Plot the number of titles available in the database for each year over the past 25 years.
# 2. List the names of all actors who have portrayed the character Spider-Man in movies, along with the corresponding movie titles.
# 3. List and count the top 10 people who have appeared the most in movies directed by Wes Anderson.

# %% [markdown]
# #### 1 - Plot the number of titles available in the database for each year over the past 25 years.

# %%
# %%sql
#
# SHOW TABLES

# %%
# %%sql
#
# DESCRIBE Titles
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('title_type', 'varchar(50)', 'YES', '', None, ''),
#  ('primary_title', 'text', 'YES', '', None, ''),
#  ('start_year', 'int', 'YES', '', None, ''),
#  ('runtime_minutes', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# SELECT start_year
# FROM Titles
# ORDER BY start_year DESC
# LIMIT 2

# %%
# %%sql
#
# SELECT start_year AS Year, COUNT(title_id) AS nTitles
# FROM Titles
# WHERE start_year BETWEEN 1999 AND 2024
# GROUP BY Year
# ORDER BY Year DESC

# %% [markdown]
# #### 2 - List the names of all actors who have portrayed the character Spider-Man in movies, along with the corresponding movie titles.

# %%
# %%sql
#
# SELECT N.name_ AS Name, T.primary_title
# FROM Had_role H
# LEFT JOIN Names_ N ON H.name_id = N.name_id
# LEFT JOIN Titles T ON H.title_id = T.title_id
# WHERE H.role_ = "Spider-Man"
# Out:
#  * mysql+mysqlconnector://root:***@db
# 358 rows affected.
# [('Drake Bell', 'Nightmare on Christmas'),
#  ('Robbie Daymond', 'The Living Brain'),
#  ('Robbie Daymond', 'Goblin War Part One'),
#  ('Robbie Daymond', 'Goblin War Part Four'),
#  (None, 'The Avenging Spider-Man'),
#  (None, 'Spider-Man: Excelsior in Purgatory'),
#  (None, 'Once Bitten: A Spider-Man Story'),
#  ('Drake Bell', 'Return to the Spider-Verse: Part 4'),
#  ('Robbie Daymond', 'The Hobgoblin: Part One'),
#  ('Christopher Daniel Barnes', 'Day of the Chameleon'),
#  (None, "Marvel's Spider-Man"),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 10: The Immortal Vampire'),
#  ('Robbie Daymond', 'Sandman'),
#  ('Neil Patrick Harris', 'Spider-Man Dis-Abled'),
#  ('Christopher Daniel Barnes', 'Six Forgotten Warriors Chapter 4: The Six Fight Again'),
#  ('Josh Keaton', 'Nature vs. Nurture'),
#  ('Drake Bell', 'The Venom Within'),
#  ('Drake Bell', 'Contest of the Champions: Part 3'),
#  ('Drake Bell', 'Return to the Spider-Verse: Part 2'),
#  (None, "CF Picture's Spider-Man"),
#  ('Rino Romano', 'Worlds Apart: Part 1'),
#  ('Josh Keaton', 'Persona'),
#  ('Drake Bell', 'New Warriors'),
#  (None, 'Spider-Man: Vengeance'),
#  ('Drake Bell', 'Great Responsibility'),
#  ('Cole Howard', 'Marvel Video Comics'),
#  ('Drake Bell', 'The New Sinister 6: Part 2'),
#  ('Robbie Daymond', 'Symbiotic Relationship'),
#  ('Doug Walker', 'The League of Extraordinary Gentlemen'),
#  ('Neil Patrick Harris', 'Royal Scam'),
#  ('Christopher Daniel Barnes', 'The Return of Hydro-Man: Part 2'),
#  ('Andrew Garfield', 'The Amazing Spider-Man'),
#  ('Robbie Daymond', 'Spider-Island: Part One'),
#  (None, 'Marvel 616'),
#  ('Josh Keaton', 'Natural Selection'),
#  ('Drake Bell', 'Exclusive'),
#  ('Rino Romano', 'Ill-Met by Moonlight'),
#  ('Drake Bell', 'The Lizard'),
#  ('Drake Bell', 'The Spider-Verse: Part 4'),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 3: The Black Cat'),
#  ('Robbie Daymond', 'Brand New Day'),
#  ('Drake Bell', 'Venomous'),
#  ('Drake Bell', 'Hawkeye'),
#  ('Drake Bell', 'Attack of the Synthezoids'),
#  ('Drake Bell', 'Graduation Day: Part 2'),
#  ('Robbie Daymond', 'The Rise of Doc Ock: Part Three'),
#  ('Robbie Daymond', 'Take Two'),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 2: The Cat'),
#  ('Josh Keaton', 'First Steps'),
#  ('Robbie Daymond', 'How I Thwipped My Summer Vacation'),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 1: Doctor Strange'),
#  ('Christopher Daniel Barnes', 'The Sting of the Scorpion'),
#  ('Josh Keaton', 'Subtext'),
#  (None, 'Episode #1.1'),
#  ('Drake Bell', 'For Your Eye Only'),
#  ('Tom Holland', 'Spider-Man: Far from Home'),
#  ('Robbie Daymond', 'Spider-Island: Part Five'),
#  ('Drake Bell', 'Sandman Returns'),
#  ('Robbie Daymond', 'The Rise of Doc Ock: Part Four'),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 7: Enter the Punisher'),
#  (None, 'Avengers: Infinity War Demastered'),
#  ('Drake Bell', 'Halloween Night at the Museum'),
#  ('Robbie Daymond', 'Rise Above It All'),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 5: The Rocket Racer'),
#  ('Robbie Daymond', 'Web of Venom'),
#  ('Shane Dawson', 'The Lego Batman & Spider-Man Movie 2'),
#  ('Drake Bell', 'The Collector'),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 11: The Prowler'),
#  ('Rino Romano', 'Cry Vulture'),
#  ('Josh Keaton', 'Group Therapy'),
#  (None, 'Marvel Knights: Spider-Man'),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 3: Hydro-Man'),
#  ('Rino Romano', 'Worlds Apart: Part 2'),
#  ('Drake Bell', 'Home Sick Hulk'),
#  ('Mikey Day', 'The Amazing Spider-Minaj/Go, Dragon Ball, Go!'),
#  ('Drake Bell', 'Force of Nature'),
#  ('Robbie Daymond', 'Horizon High: Part One'),
#  ('Tom Holland', 'Spider-Man: Homecoming'),
#  ('Drake Bell', 'Ant-Man'),
#  ('Forrest Whaley', 'The Spider-Man Team-Up!'),
#  ('Drake Bell', 'Beetle Mania'),
#  ('Drake Bell', 'Spidey, I Blew Up the Dinosaur'),
#  ('Josh Keaton', 'Catalysts'),
#  (None, 'Spider-Woman, Agent of S.W.O.R.D.'),
#  ('Drake Bell', 'Itsy Bitsy Spider-Man'),
#  ('Neil Patrick Harris', 'Keeping Secrets'),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 10: Lizard King'),
#  ('Christopher Daniel Barnes', 'Secret Wars, Chapter 1: Arrival'),
#  ('Robbie Daymond', 'Generations'),
#  ('Drake Bell', 'Freaky'),
#  ('Drake Bell', 'Journey of the Iron Fist'),
#  ('Robbie Daymond', "Dead Man's Party"),
#  ('Neil Patrick Harris', 'Flash Memory'),
#  ('Tom Holland', 'Spider-Man: No Way Home'),
#  (None, 'The LJN Library'),
#  ('Drake Bell', 'Field Trip'),
#  ('Drake Bell', 'The Return of the Guardians of the Galaxy'),
#  (None, 'Web of the Spider-Man'),
#  ('Robbie Daymond', 'Stark Expo'),
#  ('Christopher Daniel Barnes', 'Six Forgotten Warriors Chapter 3: Secrets of the Six'),
#  ('Christopher Daniel Barnes', 'The Wedding'),
#  ('Drake Bell', 'Attack of the Beetle'),
#  ('Drake Bell', 'Awesome'),
#  (None, 'How Spider-Man 3 Should Have Ended'),
#  (None, 'The Ultimate LEGO Spider-Man (BMCU)'),
#  (None, 'The Ultimate LEGO Spider-Man (BMCU)'),
#  (None, 'How the Amazing Spider-Man Should Have Ended'),
#  ('Forrest Whaley', 'The Robin'),
#  ('Drake Bell', 'Back in Black'),
#  (None, 'SPIDER-MAN PRANK IN REAL LIFE ON FRIENDS!!'),
#  ('Drake Bell', 'The Spider-Verse: Part 1'),
#  ('Robbie Daymond', 'Spider-Island: Part Two'),
#  ('Drake Bell', 'Return of the Sinister Six'),
#  ('Josh Keaton', 'Intervention'),
#  ('Drake Bell', 'Swarm'),
#  ('Robbie Daymond', 'Halloween Moon'),
#  ('Robbie Daymond', 'Goblin War Part Three'),
#  ('Josh Keaton', 'Identity Crisis'),
#  ('Josh Keaton', 'Opening Night'),
#  ('Drake Bell', 'Ultimate Deadpool'),
#  ('Drake Bell', 'Blade'),
#  ('Christopher Daniel Barnes', 'Spider Wars, Chapter 1: I Really, Really Hate Clones'),
#  ('Drake Bell', 'Rise of the Goblin'),
#  ('Drake Bell', 'The Symbiote Saga: Part 1'),
#  (None, 'Japanese Spider-Man'),
#  ('Rino Romano', 'Spider-Man Unlimited'),
#  ('Rino Romano', 'Matters of the Heart'),
#  ('Drake Bell', 'Return to the Spider-Verse: Part 1'),
#  ('Neil Patrick Harris', 'Law of the Jungle'),
#  ('Christopher Daniel Barnes', 'Doctor Octopus: Armed and Dangerous'),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 8: Duel of the Hunters'),
#  ('Christopher Daniel Barnes', 'Kraven the Hunter'),
#  ('Christopher Daniel Barnes', 'The Spider Slayer'),
#  ('Josh Keaton', 'Gangland'),
#  ('Drake Bell', 'The Spider-Verse: Part 2'),
#  (None, 'Marvel Zombies vs. Army of Darkness'),
#  ('Drake Bell', 'Double Agent Venom'),
#  ('Robbie Daymond', 'Between an Ock and a Hard Place'),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 8: The Ultimate Slayer'),
#  ('Drake Bell', 'Burrito Run'),
#  ('Josh Keaton', 'The Invisible Hand'),
#  ('Drake Bell', 'Flight of the Iron Spider'),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 1: The Insidious Six'),
#  ('Drake Bell', 'Kraven the Hunter'),
#  ('Robbie Daymond', 'A Day in the Life'),
#  ('Tobey Maguire', 'Spider-Man 2'),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 7: The Vampire Queen'),
#  ('Aaron Schoenke', 'Spider-Man vs. Darth Maul'),
#  ('Robbie Daymond', 'Venom Returns'),
#  ('Christopher Daniel Barnes', 'The Hobgoblin: Part 1'),
#  ('Robbie Daymond', 'The Cellar'),
#  (None, 'The Lego Batman, Spider-Man, & Superman Movie'),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 2: Make a Wish'),
#  ('Josh Keaton', 'Reaction'),
#  ('Mikey Day', 'iChronicle/Hulk Smash'),
#  ('Josh Keaton', 'Destructive Testing'),
#  ('Josh Keaton', 'Shear Strength'),
#  ('Robbie Daymond', 'School of Hard Knocks'),
#  ('Christopher Daniel Barnes', 'Spider Wars, Chapter 2: Farewell Spider-Man'),
#  ('Rino Romano', 'Deadly Choices'),
#  ('Josh Keaton', 'The Spectacular Spider-Man'),
#  ('Sean Chiplock', 'The Origin of Spider-Man'),
#  (None, "Hi, I'm a Marvel... and I'm a DC"),
#  ('Drake Bell', 'The Spider Slayers: Part 1'),
#  ('Neil Patrick Harris', 'Tight Squeeze'),
#  (None, 'Spider-Man: Balance Act'),
#  ('Christopher Daniel Barnes', 'Secret Wars, Chapter 2: The Gauntlet of the Red Skull'),
#  ('Ian Hecox', 'If Superheroes Were Real'),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 14: The Final Nightmare'),
#  ('Drake Bell', 'Revealed'),
#  ('Drake Bell', 'The Rhino'),
#  ('Drake Bell', 'Contest of the Champions: Part 4'),
#  (None, 'Spider-Man'),
#  ('Drake Bell', 'Iron Vulture'),
#  ('Neil Patrick Harris', 'When Sparks Fly'),
#  ('Robbie Daymond', 'Bring on the Bad Guys: Part Four'),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 12: Ravages of Time'),
#  ('Drake Bell', 'The Incredible Spider-Hulk'),
#  ('Drake Bell', 'The Moon Knight Before Christmas'),
#  (None, 'Spider-Man vs Mysterio: Far From Home'),
#  (None, 'How Iron Man Should Have Ended'),
#  ('Drake Bell', 'House Arrest'),
#  ('Robbie Daymond', 'Bring on the Bad Guys: Part Three'),
#  ('Doug Walker', 'The Amazing Spider-Man 2'),
#  ('Josh Keaton', 'Accomplices'),
#  ('Neil Patrick Harris', 'Sword of Shikata'),
#  (None, 'The Marvelous Spider-Man 3: Empire of Blood'),
#  ('Neil Patrick Harris', 'Heroes and Villains'),
#  ('Josh Keaton', 'Reinforcement'),
#  ('Drake Bell', 'Cloak and Dagger'),
#  ('Drake Bell', 'SHIELD Academy'),
#  ('Rino Romano', 'Sustenance'),
#  ('Josh Keaton', 'Interactions'),
#  (None, 'Spider-Man 4 Fan Film'),
#  (None, 'The Amazing Spider-Man 2 (2014)'),
#  ('Drake Bell', 'Game Over'),
#  ('Christopher Daniel Barnes', 'Night of the Lizard'),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 6: The Awakening'),
#  ('Drake Bell', 'Run Pig Run'),
#  ('Drake Bell', 'Carnage'),
#  ('Drake Bell', 'Stan by Me'),
#  ('Robbie Daymond', 'Spider-Island: Part Four'),
#  (None, 'The Lego Batman & Spider-Man Movie'),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 2: Battle of the Insidious Six'),
#  ('Robbie Daymond', 'Maximum Venom'),
#  (None, 'She Caught Me Kissing Her Best Friend'),
#  ('Drake Bell', 'Venom'),
#  ('Drake Bell', 'New Avengers'),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 9: Blade the Vampire Hunter'),
#  ('Christopher Daniel Barnes', 'The Alien Costume: Part 1'),
#  ('Rino Romano', 'Sins of the Fathers'),
#  ('Robbie Daymond', 'Vengeance of Venom'),
#  ('Drake Bell', 'The Avenging Spider-Man: Part 2'),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 3: Attack of the Octobot'),
#  ('Josh Keaton', 'Probable Cause'),
#  ('Drake Bell', 'Miles from Home'),
#  ('Cole Howard', 'Marvel Super Hero Adventures'),
#  ('Robbie Daymond', 'Venom'),
#  ('Drake Bell', 'Strange Little Halloween'),
#  ('Drake Bell', 'Spidah-Man'),
#  ('Drake Bell', 'Guardians of the Galaxy'),
#  ('Drake Bell', 'The Spider-Verse: Part 3'),
#  ('Robbie Daymond', "Kraven's Amazing Hunt"),
#  (None, 'How Spider-Man Into the Spider-Verse Should Have Ended'),
#  ('Drake Bell', 'I Am Spider-Man'),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 9: Tombstone'),
#  ('Andy Richter', 'Major League of Extraordinary Gentlemen'),
#  ('Drake Bell', 'The Avenging Spider-Man: Part 1'),
#  ('Drake Bell', 'Beached'),
#  ('Robbie Daymond', 'Osborn Academy'),
#  ('Robbie Daymond', 'The Rise of Doc Ock: Part One'),
#  ('Josh Keaton', 'Blueprints'),
#  ('Drake Bell', 'Agent Web'),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 6: Morbius'),
#  ('Josh Keaton', 'Final Curtain'),
#  ('Drake Bell', 'Agent Venom'),
#  ('Drake Bell', 'The Revenge of Arnim Zola'),
#  ('Drake Bell', 'Contest of the Champions: Part 1'),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 10: Venom Returns'),
#  ('Robbie Daymond', 'The Hobgoblin: Part Two'),
#  ('Rino Romano', 'One Is the Loneliest Number'),
#  ('Christopher Daniel Barnes', 'The Alien Costume: Part 3'),
#  ('Drake Bell', 'The Spider Slayers: Part 3'),
#  ('Christopher Daniel Barnes', 'Secret Wars, Chapter 3: Doom'),
#  ('Christopher Daniel Barnes', 'Six Forgotten Warriors Chapter 1'),
#  ('Robbie Daymond', 'Goblin War Part Two'),
#  ('Josh Keaton', 'Competition'),
#  ('Drake Bell', 'The Spider Slayers: Part 2'),
#  ('Drake Bell', 'Strange'),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 13: Shriek of the Vulture'),
#  ('Rino Romano', 'Destiny Unleashed'),
#  ('Robbie Daymond', 'The Road to Goblin War'),
#  ('Drake Bell', 'Ultimate'),
#  ('Drake Bell', 'The Symbiote Saga: Part 2'),
#  ('Tobey Maguire', 'Spider-Man 3'),
#  ('Drake Bell', 'Doomed'),
#  ('Robbie Daymond', 'Spider-Man on Ice'),
#  ('Robbie Daymond', 'Screwball Live'),
#  ('Christopher Daniel Barnes', 'Spider-Man: The Animated Series'),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 4: Enter the Green Goblin'),
#  (None, 'Fear and Loathing in Vegas Stakes'),
#  ('Drake Bell', 'The Man-Wolf'),
#  ('Drake Bell', 'Venom Bomb'),
#  ('Drake Bell', 'The Howling Commandos'),
#  ('Drake Bell', 'Contest of the Champions: Part 2'),
#  (None, "CF Picture's Spider-Man: Dissension"),
#  ('Mikey Day', 'I Love You, Iron Man/Ben 10 Franklin'),
#  ('Drake Bell', 'The Symbiote Saga: Part 3'),
#  ('Robbie Daymond', 'Horizon High: Part Two'),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 4: Return of Kraven'),
#  ('Drake Bell', 'Sinister Six'),
#  ('Robbie Daymond', 'Brain Drain'),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 8: The Return of the Green Goblin'),
#  ('Robbie Daymond', 'Spider-Man Unmasked'),
#  (None, 'How the Avengers Should Have Ended'),
#  ('Drake Bell', 'Lizards'),
#  ('Josh Keaton', 'Survival of the Fittest'),
#  ('Drake Bell', 'The New Sinister 6: Part 1'),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 12: The Spot'),
#  ('Drake Bell', 'Hydra Attacks: Part 2'),
#  ('Robbie Daymond', 'Vibranium Curtain: Part Two'),
#  ('Neil Patrick Harris', 'Spider-Man'),
#  ('Drake Bell', 'Snow Day'),
#  ('Stan Lee', 'Superheroes: A Never-Ending Battle'),
#  ('Drake Bell', 'The Parent Trap'),
#  ('Neil Patrick Harris', 'Head Over Heels'),
#  ('Neil Patrick Harris', 'The Party'),
#  (None, 'GHETTO SPIDER-MAN!'),
#  ('Drake Bell', 'The Vulture'),
#  ('Christopher Daniel Barnes', 'The Hobgoblin: Part 2'),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 5: Partners'),
#  ('Robbie Daymond', 'Amazing Friends'),
#  ('Drake Bell', 'Damage'),
#  ('Drake Bell', 'Inhumanity'),
#  ('Drake Bell', 'Graduation Day: Part 1'),
#  ('Robbie Daymond', 'Bring on the Bad Guys: Part Two'),
#  ('Christopher Daniel Barnes', 'The Alien Costume: Part 2'),
#  (None, 'Watch Movie Free Online'),
#  ('Drake Bell', 'Electro'),
#  (None, 'The Spectacular Lego Spider-Man'),
#  (None, 'The Spectacular Lego Spider-Man'),
#  ('Drake Bell', 'Return to the Spider-Verse: Part 3'),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 13: Goblin War!'),
#  ('Drake Bell', 'Ultimate Spider-Man'),
#  ('JP Karliak', 'Marvel Mash-Up'),
#  (None, 'The Spider-Man 2'),
#  ('Drake Bell', 'Great Power'),
#  ('Drake Bell', 'Not a Toy'),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 5: Mutants Revenge'),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 14: The Turning Point'),
#  ('Josh Keaton', 'The Uncertainty Principle'),
#  (None, 'The Amazing Spider-man Movies'),
#  ('Robbie Daymond', 'Origins'),
#  ('Neil Patrick Harris', 'Mind Games: Part 1'),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 1: Guilty'),
#  ('Christopher Daniel Barnes', 'Six Forgotten Warriors Chapter 5: The Price of Heroism'),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 11: Carnage'),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 6: Framed'),
#  ('Tobey Maguire', 'Top 11 Dumbasses in Distress'),
#  ('Drake Bell', 'Hydra Attacks: Part 1'),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 9: The Haunting of Mary Jane'),
#  ('Drake Bell', 'The Next Iron Spider'),
#  ('Christopher Daniel Barnes', 'The Return of the Spider-Slayers'),
#  ('Rino Romano', 'Steel Cold Heart'),
#  ('Drake Bell', 'Rampaging Rhino'),
#  (None, 'Super Café: And the Reboot Goes To...'),
#  ('Tobey Maguire', 'Spider-Man'),
#  ('Forrest Whaley', 'The Lego Batman, Spider-Man, & Chewbacca Movie'),
#  ('Drake Bell', 'Why I Hate the Gym'),
#  ('Robbie Daymond', 'Spider-Island: Part Three'),
#  (None, 'How Infinity War Should Have Ended'),
#  (None, 'Spider-Man: Identity'),
#  ('Christopher Daniel Barnes', 'Six Forgotten Warriors Chapter 2: Unclaimed Legacy'),
#  ('Christopher Daniel Barnes', 'The Menace of Mysterio'),
#  ('Rino Romano', 'Where Evil Nests'),
#  ('Tobey Maguire', 'Spider-Man 2'),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 7: The Man Without Fear'),
#  ('Andrew Garfield', 'The Amazing Spider-Man 2'),
#  (None, 'How Spider-Man Homecoming Should Have Ended'),
#  ('Josh Keaton', 'Growing Pains'),
#  ('Robbie Daymond', 'Spider-Man'),
#  (None, 'How the Amazing Spider-Man 2 Should Have Ended'),
#  ('Robbie Daymond', 'The Rise of Doc Ock: Part Two'),
#  ('Josh Keaton', 'Market Forces'),
#  ('Robbie Daymond', 'Party Animals'),
#  ('Robbie Daymond', 'Bring on the Bad Guys: Part One'),
#  (None, "Spider-Man Forgets About Aunt May's Milk"),
#  ('Drake Bell', 'The Iron Octopus'),
#  ('Robbie Daymond', 'Ultimate Spider-Man'),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 11: Tablet of Time'),
#  ('Rino Romano', 'Enter the Hunter!'),
#  ('Drake Bell', 'Me Time'),
#  ('Drake Bell', 'Anti-Venom'),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 4: The Mutant Agenda'),
#  ('Drake Bell', 'Second Chance Hero'),
#  ('Drake Bell', 'The Savage Spider-Man'),
#  ('Neil Patrick Harris', 'Mind Games: Part 2'),
#  (None, 'Avengers: Legacy')]

# %%
# %%sql
#
# DESCRIBE Titles
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('title_type', 'varchar(50)', 'YES', '', None, ''),
#  ('primary_title', 'text', 'YES', '', None, ''),
#  ('start_year', 'int', 'YES', '', None, ''),
#  ('runtime_minutes', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# DESCRIBE Names_
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('name_id', 'varchar(255)', 'NO', '', None, ''),
#  ('name_', 'varchar(255)', 'NO', '', None, ''),
#  ('birth_year', 'smallint', 'YES', '', None, ''),
#  ('death_year', 'smallint', 'YES', '', None, '')]

# %%
# %%sql
#
# DESCRIBE Had_role
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('name_id', 'varchar(255)', 'NO', '', None, ''),
#  ('role_', 'text', 'NO', '', None, '')]

# %%
# %%sql
#
# SELECT *
# FROM Had_role
# LIMIT 5

# %%
# %%sql
#
# SELECT name_, primary_title AS Title, start_year
# FROM Had_role
# LEFT JOIN Names_ ON Names_.name_id = Had_role.name_id
# LEFT JOIN Titles ON Titles.title_id = Had_role.title_id
# WHERE role_ = "Spider-Man"
# ORDER BY start_year ASC
# Out:
#  * mysql+mysqlconnector://root:***@db
# 358 rows affected.
# [('Christopher Daniel Barnes', 'Night of the Lizard', 1994),
#  ('Christopher Daniel Barnes', 'Spider-Man: The Animated Series', 1994),
#  ('Christopher Daniel Barnes', 'Day of the Chameleon', 1995),
#  ('Christopher Daniel Barnes', 'The Sting of the Scorpion', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 7: Enter the Punisher', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 3: Hydro-Man', 1995),
#  ('Christopher Daniel Barnes', 'Doctor Octopus: Armed and Dangerous', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 8: Duel of the Hunters', 1995),
#  ('Christopher Daniel Barnes', 'Kraven the Hunter', 1995),
#  ('Christopher Daniel Barnes', 'The Spider Slayer', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 1: The Insidious Six', 1995),
#  ('Christopher Daniel Barnes', 'The Hobgoblin: Part 1', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 12: Ravages of Time', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 2: Battle of the Insidious Six', 1995),
#  ('Christopher Daniel Barnes', 'The Alien Costume: Part 1', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 6: Morbius', 1995),
#  ('Christopher Daniel Barnes', 'The Alien Costume: Part 3', 1995),
#  ('Christopher Daniel Barnes', 'The Hobgoblin: Part 2', 1995),
#  ('Christopher Daniel Barnes', 'The Alien Costume: Part 2', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 5: Mutants Revenge', 1995),
#  ('Christopher Daniel Barnes', 'The Return of the Spider-Slayers', 1995),
#  ('Christopher Daniel Barnes', 'The Menace of Mysterio', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 11: Tablet of Time', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 4: The Mutant Agenda', 1995),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 10: The Immortal Vampire', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 1: Doctor Strange', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 5: The Rocket Racer', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 8: The Ultimate Slayer', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 2: Make a Wish', 1996),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 14: The Final Nightmare', 1996),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 9: Blade the Vampire Hunter', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 3: Attack of the Octobot', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 9: Tombstone', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 10: Venom Returns', 1996),
#  ('Christopher Daniel Barnes', 'Neogenic Nightmare Chapter 13: Shriek of the Vulture', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 4: Enter the Green Goblin', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 12: The Spot', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 13: Goblin War!', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 14: The Turning Point', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 11: Carnage', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 6: Framed', 1996),
#  ('Christopher Daniel Barnes', 'Sins of the Fathers Chapter 7: The Man Without Fear', 1996),
#  ('Christopher Daniel Barnes', 'Six Forgotten Warriors Chapter 4: The Six Fight Again', 1997),
#  ('Christopher Daniel Barnes', 'The Return of Hydro-Man: Part 2', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 3: The Black Cat', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 2: The Cat', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 11: The Prowler', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 10: Lizard King', 1997),
#  ('Christopher Daniel Barnes', 'Secret Wars, Chapter 1: Arrival', 1997),
#  ('Christopher Daniel Barnes', 'Six Forgotten Warriors Chapter 3: Secrets of the Six', 1997),
#  ('Christopher Daniel Barnes', 'The Wedding', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 7: The Vampire Queen', 1997),
#  ('Christopher Daniel Barnes', 'Secret Wars, Chapter 2: The Gauntlet of the Red Skull', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 6: The Awakening', 1997),
#  ('Christopher Daniel Barnes', 'Secret Wars, Chapter 3: Doom', 1997),
#  ('Christopher Daniel Barnes', 'Six Forgotten Warriors Chapter 1', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 4: Return of Kraven', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 8: The Return of the Green Goblin', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 5: Partners', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 1: Guilty', 1997),
#  ('Christopher Daniel Barnes', 'Six Forgotten Warriors Chapter 5: The Price of Heroism', 1997),
#  ('Christopher Daniel Barnes', 'Partners in Danger Chapter 9: The Haunting of Mary Jane', 1997),
#  ('Christopher Daniel Barnes', 'Six Forgotten Warriors Chapter 2: Unclaimed Legacy', 1997),
#  ('Christopher Daniel Barnes', 'Spider Wars, Chapter 1: I Really, Really Hate Clones', 1998),
#  ('Christopher Daniel Barnes', 'Spider Wars, Chapter 2: Farewell Spider-Man', 1998),
#  ('Rino Romano', 'Worlds Apart: Part 1', 1999),
#  ('Rino Romano', 'Worlds Apart: Part 2', 1999),
#  ('Rino Romano', 'Spider-Man Unlimited', 1999),
#  ('Rino Romano', 'Where Evil Nests', 1999),
#  ('Rino Romano', 'Deadly Choices', 2000),
#  ('Rino Romano', 'Ill-Met by Moonlight', 2001),
#  ('Rino Romano', 'Cry Vulture', 2001),
#  ('Rino Romano', 'Matters of the Heart', 2001),
#  ('Rino Romano', 'Sustenance', 2001),
#  ('Rino Romano', 'Sins of the Fathers', 2001),
#  ('Rino Romano', 'One Is the Loneliest Number', 2001),
#  ('Rino Romano', 'Destiny Unleashed', 2001),
#  ('Rino Romano', 'Steel Cold Heart', 2001),
#  ('Rino Romano', 'Enter the Hunter!', 2001),
#  ('Tobey Maguire', 'Spider-Man', 2002),
#  ('Neil Patrick Harris', 'Spider-Man Dis-Abled', 2003),
#  ('Neil Patrick Harris', 'Royal Scam', 2003),
#  ('Neil Patrick Harris', 'Keeping Secrets', 2003),
#  ('Neil Patrick Harris', 'Flash Memory', 2003),
#  ('Neil Patrick Harris', 'Law of the Jungle', 2003),
#  ('Neil Patrick Harris', 'Tight Squeeze', 2003),
#  ('Neil Patrick Harris', 'When Sparks Fly', 2003),
#  ('Neil Patrick Harris', 'Sword of Shikata', 2003),
#  ('Neil Patrick Harris', 'Heroes and Villains', 2003),
#  ('Neil Patrick Harris', 'Spider-Man', 2003),
#  ('Neil Patrick Harris', 'Head Over Heels', 2003),
#  ('Neil Patrick Harris', 'The Party', 2003),
#  ('Neil Patrick Harris', 'Mind Games: Part 1', 2003),
#  ('Neil Patrick Harris', 'Mind Games: Part 2', 2003),
#  ('Tobey Maguire', 'Spider-Man 2', 2004),
#  ('Tobey Maguire', 'Spider-Man 2', 2004),
#  ('Forrest Whaley', 'The Spider-Man Team-Up!', 2007),
#  (None, 'How Spider-Man 3 Should Have Ended', 2007),
#  (None, "Hi, I'm a Marvel... and I'm a DC", 2007),
#  (None, 'Spider-Man', 2007),
#  ('Tobey Maguire', 'Spider-Man 3', 2007),
#  ('Forrest Whaley', 'The Lego Batman, Spider-Man, & Chewbacca Movie', 2007),
#  ('Josh Keaton', 'Nature vs. Nurture', 2008),
#  ('Josh Keaton', 'Persona', 2008),
#  ('Josh Keaton', 'Natural Selection', 2008),
#  ('Josh Keaton', 'Group Therapy', 2008),
#  ('Josh Keaton', 'Catalysts', 2008),
#  ('Forrest Whaley', 'The Robin', 2008),
#  ('Josh Keaton', 'Intervention', 2008),
#  ('Josh Keaton', 'The Invisible Hand', 2008),
#  ('Josh Keaton', 'Reaction', 2008),
#  ('Josh Keaton', 'The Spectacular Spider-Man', 2008),
#  ('Josh Keaton', 'Interactions', 2008),
#  ('Josh Keaton', 'Competition', 2008),
#  ('Josh Keaton', 'Survival of the Fittest', 2008),
#  ('Josh Keaton', 'The Uncertainty Principle', 2008),
#  ('Josh Keaton', 'Market Forces', 2008),
#  ('Josh Keaton', 'First Steps', 2009),
#  ('Josh Keaton', 'Subtext', 2009),
#  (None, 'Episode #1.1', 2009),
#  ('Shane Dawson', 'The Lego Batman & Spider-Man Movie 2', 2009),
#  (None, 'Spider-Woman, Agent of S.W.O.R.D.', 2009),
#  ('Josh Keaton', 'Identity Crisis', 2009),
#  ('Josh Keaton', 'Opening Night', 2009),
#  ('Josh Keaton', 'Gangland', 2009),
#  ('Josh Keaton', 'Destructive Testing', 2009),
#  ('Josh Keaton', 'Shear Strength', 2009),
#  ('Josh Keaton', 'Accomplices', 2009),
#  ('Josh Keaton', 'Reinforcement', 2009),
#  (None, 'The Lego Batman & Spider-Man Movie', 2009),
#  ('Josh Keaton', 'Probable Cause', 2009),
#  ('Josh Keaton', 'Blueprints', 2009),
#  ('Josh Keaton', 'Final Curtain', 2009),
#  ('Josh Keaton', 'Growing Pains', 2009),
#  (None, 'The Lego Batman, Spider-Man, & Superman Movie', 2010),
#  (None, 'How Iron Man Should Have Ended', 2010),
#  ('Mikey Day', 'I Love You, Iron Man/Ben 10 Franklin', 2010),
#  ('Ian Hecox', 'If Superheroes Were Real', 2011),
#  ('Andy Richter', 'Major League of Extraordinary Gentlemen', 2011),
#  ('Tobey Maguire', 'Top 11 Dumbasses in Distress', 2011),
#  ('Drake Bell', 'Great Responsibility', 2012),
#  ('Andrew Garfield', 'The Amazing Spider-Man', 2012),
#  ('Drake Bell', 'Exclusive', 2012),
#  ('Drake Bell', 'Venomous', 2012),
#  ('Drake Bell', 'For Your Eye Only', 2012),
#  ('Drake Bell', 'Home Sick Hulk', 2012),
#  ('Mikey Day', 'The Amazing Spider-Minaj/Go, Dragon Ball, Go!', 2012),
#  ('Drake Bell', 'Beetle Mania', 2012),
#  ('Drake Bell', 'Freaky', 2012),
#  ('Drake Bell', 'Field Trip', 2012),
#  ('Drake Bell', 'Attack of the Beetle', 2012),
#  ('Drake Bell', 'Awesome', 2012),
#  (None, 'How the Amazing Spider-Man Should Have Ended', 2012),
#  ('Drake Bell', 'Back in Black', 2012),
#  ('Drake Bell', 'Rise of the Goblin', 2012),
#  ('Drake Bell', 'Flight of the Iron Spider', 2012),
#  ('Mikey Day', 'iChronicle/Hulk Smash', 2012),
#  ('Drake Bell', 'Revealed', 2012),
#  ('Drake Bell', 'Run Pig Run', 2012),
#  ('Drake Bell', 'Venom', 2012),
#  ('Drake Bell', 'New Avengers', 2012),
#  ('Drake Bell', 'I Am Spider-Man', 2012),
#  ('Drake Bell', 'Strange', 2012),
#  ('Drake Bell', 'Doomed', 2012),
#  (None, 'How the Avengers Should Have Ended', 2012),
#  ('Drake Bell', 'Snow Day', 2012),
#  ('Drake Bell', 'Damage', 2012),
#  ('Drake Bell', 'Ultimate Spider-Man', 2012),
#  ('JP Karliak', 'Marvel Mash-Up', 2012),
#  ('Drake Bell', 'Great Power', 2012),
#  ('Drake Bell', 'Not a Toy', 2012),
#  ('Drake Bell', 'Why I Hate the Gym', 2012),
#  ('Drake Bell', 'The Iron Octopus', 2012),
#  ('Drake Bell', 'Me Time', 2012),
#  ('Drake Bell', 'The Venom Within', 2013),
#  ('Drake Bell', 'The Lizard', 2013),
#  ('Drake Bell', 'Hawkeye', 2013),
#  ('Drake Bell', 'Sandman Returns', 2013),
#  ('Drake Bell', 'The Collector', 2013),
#  ('Drake Bell', 'Itsy Bitsy Spider-Man', 2013),
#  ('Drake Bell', 'Journey of the Iron Fist', 2013),
#  ('Drake Bell', 'Return of the Sinister Six', 2013),
#  ('Drake Bell', 'Swarm', 2013),
#  ('Drake Bell', 'Ultimate Deadpool', 2013),
#  ('Drake Bell', 'Blade', 2013),
#  (None, 'Marvel Zombies vs. Army of Darkness', 2013),
#  ('Drake Bell', 'Kraven the Hunter', 2013),
#  ('Drake Bell', 'The Rhino', 2013),
#  ('Drake Bell', 'The Incredible Spider-Hulk', 2013),
#  ('Drake Bell', 'House Arrest', 2013),
#  ('Drake Bell', 'Game Over', 2013),
#  ('Drake Bell', 'Carnage', 2013),
#  ('Drake Bell', 'Stan by Me', 2013),
#  ('Drake Bell', 'Spidah-Man', 2013),
#  ('Drake Bell', 'Guardians of the Galaxy', 2013),
#  ('Drake Bell', 'Ultimate', 2013),
#  ('Drake Bell', 'The Man-Wolf', 2013),
#  ('Drake Bell', 'Venom Bomb', 2013),
#  ('Drake Bell', 'The Howling Commandos', 2013),
#  ('Drake Bell', 'Sinister Six', 2013),
#  ('Stan Lee', 'Superheroes: A Never-Ending Battle', 2013),
#  ('Drake Bell', 'The Parent Trap', 2013),
#  ('Drake Bell', 'Electro', 2013),
#  (None, 'The Spectacular Lego Spider-Man', 2013),
#  (None, 'The Spectacular Lego Spider-Man', 2013),
#  ('Drake Bell', 'Second Chance Hero', 2013),
#  ('Drake Bell', 'Nightmare on Christmas', 2014),
#  ('Drake Bell', 'New Warriors', 2014),
#  ('Drake Bell', 'Halloween Night at the Museum', 2014),
#  ('Drake Bell', 'The Return of the Guardians of the Galaxy', 2014),
#  ('Drake Bell', 'Cloak and Dagger', 2014),
#  ('Drake Bell', 'The Avenging Spider-Man: Part 2', 2014),
#  ('Drake Bell', 'The Avenging Spider-Man: Part 1', 2014),
#  ('Drake Bell', 'Agent Venom', 2014),
#  ('Drake Bell', 'The Vulture', 2014),
#  ('Drake Bell', 'The Next Iron Spider', 2014),
#  ('Andrew Garfield', 'The Amazing Spider-Man 2', 2014),
#  (None, 'How the Amazing Spider-Man 2 Should Have Ended', 2014),
#  ('Drake Bell', 'The Savage Spider-Man', 2014),
#  (None, 'The Avenging Spider-Man', 2015),
#  ('Drake Bell', 'Contest of the Champions: Part 3', 2015),
#  ('Drake Bell', 'The Spider-Verse: Part 4', 2015),
#  ('Drake Bell', 'Attack of the Synthezoids', 2015),
#  (None, 'Marvel Knights: Spider-Man', 2015),
#  ('Drake Bell', 'Ant-Man', 2015),
#  ('Drake Bell', 'Spidey, I Blew Up the Dinosaur', 2015),
#  (None, 'Web of the Spider-Man', 2015),
#  ('Drake Bell', 'The Spider-Verse: Part 1', 2015),
#  ('Drake Bell', 'The Spider-Verse: Part 2', 2015),
#  ('Drake Bell', 'Burrito Run', 2015),
#  ('Aaron Schoenke', 'Spider-Man vs. Darth Maul', 2015),
#  ('Drake Bell', 'Contest of the Champions: Part 4', 2015),
#  ('Drake Bell', 'SHIELD Academy', 2015),
#  ('Drake Bell', 'The Spider-Verse: Part 3', 2015),
#  ('Drake Bell', 'The Revenge of Arnim Zola', 2015),
#  ('Drake Bell', 'Contest of the Champions: Part 1', 2015),
#  ('Drake Bell', 'Contest of the Champions: Part 2', 2015),
#  (None, 'GHETTO SPIDER-MAN!', 2015),
#  ('Drake Bell', 'Inhumanity', 2015),
#  ('Drake Bell', 'Rampaging Rhino', 2015),
#  (None, 'Super Café: And the Reboot Goes To...', 2015),
#  (None, 'Once Bitten: A Spider-Man Story', 2016),
#  ('Drake Bell', 'Return to the Spider-Verse: Part 4', 2016),
#  ('Drake Bell', 'Return to the Spider-Verse: Part 2', 2016),
#  (None, 'Spider-Man: Vengeance', 2016),
#  ('Cole Howard', 'Marvel Video Comics', 2016),
#  ('Drake Bell', 'The New Sinister 6: Part 2', 2016),
#  ('Drake Bell', 'Force of Nature', 2016),
#  ('Drake Bell', 'The Symbiote Saga: Part 1', 2016),
#  ('Drake Bell', 'Return to the Spider-Verse: Part 1', 2016),
#  ('Drake Bell', 'Double Agent Venom', 2016),
#  ('Drake Bell', 'The Spider Slayers: Part 1', 2016),
#  (None, 'Spider-Man: Balance Act', 2016),
#  ('Drake Bell', 'Iron Vulture', 2016),
#  ('Drake Bell', 'The Moon Knight Before Christmas', 2016),
#  ('Drake Bell', 'Miles from Home', 2016),
#  ('Drake Bell', 'Strange Little Halloween', 2016),
#  ('Drake Bell', 'Beached', 2016),
#  ('Drake Bell', 'Agent Web', 2016),
#  ('Drake Bell', 'The Spider Slayers: Part 3', 2016),
#  ('Drake Bell', 'The Spider Slayers: Part 2', 2016),
#  ('Drake Bell', 'The Symbiote Saga: Part 2', 2016),
#  ('Drake Bell', 'The Symbiote Saga: Part 3', 2016),
#  ('Drake Bell', 'Lizards', 2016),
#  ('Drake Bell', 'The New Sinister 6: Part 1', 2016),
#  ('Drake Bell', 'Hydra Attacks: Part 2', 2016),
#  ('Drake Bell', 'Return to the Spider-Verse: Part 3', 2016),
#  ('Drake Bell', 'Hydra Attacks: Part 1', 2016),
#  ('Drake Bell', 'Anti-Venom', 2016),
#  ('Robbie Daymond', 'Sandman', 2017),
#  ('Robbie Daymond', 'Symbiotic Relationship', 2017),
#  ('Drake Bell', 'Graduation Day: Part 2', 2017),
#  ('Robbie Daymond', 'Horizon High: Part One', 2017),
#  ('Tom Holland', 'Spider-Man: Homecoming', 2017),
#  ('Robbie Daymond', 'Stark Expo', 2017),
#  ('Robbie Daymond', 'Halloween Moon', 2017),
#  ('Robbie Daymond', 'A Day in the Life', 2017),
#  ('Sean Chiplock', 'The Origin of Spider-Man', 2017),
#  (None, 'The Amazing Spider-Man 2 (2014)', 2017),
#  ('Cole Howard', 'Marvel Super Hero Adventures', 2017),
#  ('Robbie Daymond', 'Venom', 2017),
#  ('Robbie Daymond', "Kraven's Amazing Hunt", 2017),
#  ('Robbie Daymond', 'Osborn Academy', 2017),
#  ('Robbie Daymond', 'Spider-Man on Ice', 2017),
#  ('Robbie Daymond', 'Screwball Live', 2017),
#  ('Robbie Daymond', 'Horizon High: Part Two', 2017),
#  ('Drake Bell', 'Graduation Day: Part 1', 2017),
#  (None, 'The Amazing Spider-man Movies', 2017),
#  ('Robbie Daymond', 'Origins', 2017),
#  (None, 'How Spider-Man Homecoming Should Have Ended', 2017),
#  ('Robbie Daymond', 'Spider-Man', 2017),
#  ('Robbie Daymond', 'Party Animals', 2017),
#  (None, "Spider-Man Forgets About Aunt May's Milk", 2017),
#  ('Robbie Daymond', 'Ultimate Spider-Man', 2017),
#  ('Robbie Daymond', 'The Living Brain', 2018),
#  ('Robbie Daymond', 'The Hobgoblin: Part One', 2018),
#  (None, "CF Picture's Spider-Man", 2018),
#  ('Doug Walker', 'The League of Extraordinary Gentlemen', 2018),
#  ('Robbie Daymond', 'Spider-Island: Part One', 2018),
#  ('Robbie Daymond', 'The Rise of Doc Ock: Part Three', 2018),
#  ('Robbie Daymond', 'Take Two', 2018),
#  ('Robbie Daymond', 'How I Thwipped My Summer Vacation', 2018),
#  ('Robbie Daymond', 'Spider-Island: Part Five', 2018),
#  ('Robbie Daymond', 'The Rise of Doc Ock: Part Four', 2018),
#  ('Robbie Daymond', 'Rise Above It All', 2018),
#  ('Robbie Daymond', "Dead Man's Party", 2018),
#  (None, 'The Ultimate LEGO Spider-Man (BMCU)', 2018),
#  (None, 'The Ultimate LEGO Spider-Man (BMCU)', 2018),
#  ('Robbie Daymond', 'Spider-Island: Part Two', 2018),
#  ('Robbie Daymond', 'Between an Ock and a Hard Place', 2018),
#  ('Robbie Daymond', 'Venom Returns', 2018),
#  ('Robbie Daymond', 'School of Hard Knocks', 2018),
#  ('Robbie Daymond', 'Bring on the Bad Guys: Part Four', 2018),
#  ('Robbie Daymond', 'Bring on the Bad Guys: Part Three', 2018),
#  (None, 'The Marvelous Spider-Man 3: Empire of Blood', 2018),
#  ('Robbie Daymond', 'Spider-Island: Part Four', 2018),
#  ('Robbie Daymond', 'The Rise of Doc Ock: Part One', 2018),
#  ('Robbie Daymond', 'The Hobgoblin: Part Two', 2018),
#  ('Robbie Daymond', 'Brain Drain', 2018),
#  ('Robbie Daymond', 'Bring on the Bad Guys: Part Two', 2018),
#  ('Robbie Daymond', 'Spider-Island: Part Three', 2018),
#  (None, 'How Infinity War Should Have Ended', 2018),
#  ('Robbie Daymond', 'The Rise of Doc Ock: Part Two', 2018),
#  ('Robbie Daymond', 'Bring on the Bad Guys: Part One', 2018),
#  ('Robbie Daymond', 'Goblin War Part One', 2019),
#  ('Robbie Daymond', 'Goblin War Part Four', 2019),
#  (None, "Marvel's Spider-Man", 2019),
#  ('Robbie Daymond', 'Brand New Day', 2019),
#  ('Tom Holland', 'Spider-Man: Far from Home', 2019),
#  (None, 'Avengers: Infinity War Demastered', 2019),
#  ('Robbie Daymond', 'Goblin War Part Three', 2019),
#  ('Robbie Daymond', 'The Cellar', 2019),
#  (None, 'Spider-Man vs Mysterio: Far From Home', 2019),
#  (None, 'How Spider-Man Into the Spider-Verse Should Have Ended', 2019),
#  ('Robbie Daymond', 'Goblin War Part Two', 2019),
#  ('Robbie Daymond', 'The Road to Goblin War', 2019),
#  (None, "CF Picture's Spider-Man: Dissension", 2019),
#  ('Robbie Daymond', 'Vibranium Curtain: Part Two', 2019),
#  (None, 'Watch Movie Free Online', 2019),
#  (None, 'Spider-Man: Identity', 2019),
#  (None, 'Spider-Man: Excelsior in Purgatory', 2020),
#  (None, 'Marvel 616', 2020),
#  ('Robbie Daymond', 'Web of Venom', 2020),
#  ('Robbie Daymond', 'Generations', 2020),
#  (None, 'SPIDER-MAN PRANK IN REAL LIFE ON FRIENDS!!', 2020),
#  (None, 'Japanese Spider-Man', 2020),
#  ('Doug Walker', 'The Amazing Spider-Man 2', 2020),
#  ('Robbie Daymond', 'Maximum Venom', 2020),
#  ('Robbie Daymond', 'Vengeance of Venom', 2020),
#  ('Robbie Daymond', 'Spider-Man Unmasked', 2020),
#  ('Robbie Daymond', 'Amazing Friends', 2020),
#  (None, 'Avengers: Legacy', 2020),
#  ('Tom Holland', 'Spider-Man: No Way Home', 2021),
#  (None, 'The LJN Library', 2021),
#  (None, 'Spider-Man 4 Fan Film', 2021),
#  (None, 'She Caught Me Kissing Her Best Friend', 2021),
#  (None, 'Fear and Loathing in Vegas Stakes', 2021),
#  (None, 'The Spider-Man 2', 2021)]

# %% [markdown]
# #### 3 - List and count the top 10 people who have appeared the most in movies directed by Wes Anderson.

# %%
# %%sql
#
# DESCRIBE Directors
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('name_id', 'varchar(255)', 'NO', '', None, '')]

# %%
# %%sql
#
# CREATE VIEW wes AS
# SELECT Directors.title_id
# FROM Directors
# LEFT JOIN Names_ ON Directors.name_id = Names_.name_id
# WHERE Names_.name_ = "Wes Anderson"
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# SELECT *
# FROM wes
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('tt0115734',),
#  ('tt0128445',),
#  ('tt0265666',),
#  ('tt0362270',),
#  ('tt0432283',),
#  ('tt0838221',),
#  ('tt1748122',),
#  ('tt2278388',),
#  ('tt5104604',),
#  ('tt8847712',)]

# %%
# %%sql
#
# SELECT COUNT(*) AS count, Names_.name_
# FROM Had_role
# LEFT JOIN wes ON Had_role.title_id = wes.title_id
# LEFT JOIN Names_ ON Had_role.name_id = Names_.name_id
# GROUP BY Names_.name_
# ORDER BY count DESC
# Out:
#  * mysql+mysqlconnector://root:***@db
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', '\nSELECT COUNT(*) AS count, Names_.name_\nFROM Had_role\nLEFT JOIN wes ON Had_role.title_id = wes.title_id\nLEFT JOIN Names_ ON Had_role.name_id = Names_.name_id \nGROUP BY Names_.name_\nORDER BY count DESC \n')
#
# File /usr/local/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /usr/local/lib/python3.11/site-packages/sql/magic.py:219, in SqlMagic.execute(self, line, cell, local_ns)
#     216     return
#     218 try:
# --> 219     result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     221     if (
#     222         result is not None
#     223         and not isinstance(result, str)
#    (...)
#     226         # Instead of returning values, set variables directly in the
#     227         # user's namespace. Variable names given by column names
#     229         if self.autopandas:
#
# File /usr/local/lib/python3.11/site-packages/sql/run.py:370, in run(conn, sql, config, user_namespace)
#     368 else:
#     369     txt = sqlalchemy.sql.text(statement)
# --> 370     result = conn.internal_connection.execute(txt, user_namespace)
#     371 _commit(conn=conn, config=config)
#     372 if result and config.feedback:
#
# File /usr/local/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1408, in Connection.execute(self, statement, parameters, execution_options)
#    1406     raise exc.ObjectNotExecutableError(statement) from err
#    1407 else:
# -> 1408     return meth(
#    1409         self,
#    1410         distilled_parameters,
#    1411         execution_options or NO_OPTIONS,
#    1412     )
#
# File /usr/local/lib/python3.11/site-packages/sqlalchemy/sql/elements.py:513, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     511     if TYPE_CHECKING:
#     512         assert isinstance(self, Executable)
# --> 513     return connection._execute_clauseelement(
#     514         self, distilled_params, execution_options
#     515     )
#     516 else:
#     517     raise exc.ObjectNotExecutableError(self)
#
# File /usr/local/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1630, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1618 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1619     "compiled_cache", self.engine._compiled_cache
#    1620 )
#    1622 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1623     dialect=dialect,
#    1624     compiled_cache=compiled_cache,
#    (...)
#    1628     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1629 )
# -> 1630 ret = self._execute_context(
#    1631     dialect,
#    1632     dialect.execution_ctx_cls._init_compiled,
#    1633     compiled_sql,
#    1634     distilled_parameters,
#    1635     execution_options,
#    1636     compiled_sql,
#    1637     distilled_parameters,
#    1638     elem,
#    1639     extracted_params,
#    1640     cache_hit=cache_hit,
#    1641 )
#    1642 if has_events:
#    1643     self.dispatch.after_execute(
#    1644         self,
#    1645         elem,
#    (...)
#    1649         ret,
#    1650     )
#
# File /usr/local/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1839, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1834     return self._exec_insertmany_context(
#    1835         dialect,
#    1836         context,
#    1837     )
#    1838 else:
# -> 1839     return self._exec_single_context(
#    1840         dialect, context, statement, parameters
#    1841     )
#
# File /usr/local/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1979, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1976     result = context._setup_result_proxy()
#    1978 except BaseException as e:
# -> 1979     self._handle_dbapi_exception(
#    1980         e, str_statement, effective_parameters, cursor, context
#    1981     )
#    1983 return result
#
# File /usr/local/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2338, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2336     else:
#    2337         assert exc_info[1] is not None
# -> 2338         raise exc_info[1].with_traceback(exc_info[2])
#    2339 finally:
#    2340     del self._reentrant_error
#
# File /usr/local/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1960, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1958                 break
#    1959     if not evt_handled:
# -> 1960         self.dialect.do_execute(
#    1961             cursor, str_statement, effective_parameters, context
#    1962         )
#    1964 if self._has_events or self.engine._has_events:
#    1965     self.dispatch.after_cursor_execute(
#    1966         self,
#    1967         cursor,
#    (...)
#    1971         context.executemany,
#    1972     )
#
# File /usr/local/lib/python3.11/site-packages/sqlalchemy/engine/default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# File /usr/local/lib/python3.11/site-packages/mysql/connector/cursor_cext.py:374, in CMySQLCursor.execute(self, operation, params, multi)
#     369             raise ProgrammingError(
#     370                 "Not all parameters were used in the SQL statement"
#     371             )
#     373 try:
# --> 374     result = self._cnx.cmd_query(
#     375         stmt,
#     376         raw=self._raw,
#     377         buffered=self._buffered,
#     378         raw_as_string=self._raw_as_string,
#     379     )
#     380 except MySQLInterfaceError as err:
#     381     raise get_mysql_exception(
#     382         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     383     ) from err
#
# File /usr/local/lib/python3.11/site-packages/mysql/connector/opentelemetry/context_propagation.py:74, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      72 """Context propagation decorator."""
#      73 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 74     return method(cnx, *args, **kwargs)
#      76 current_span = trace.get_current_span()
#      77 tp_header = None
#
# File /usr/local/lib/python3.11/site-packages/mysql/connector/connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     659     if not isinstance(query, bytes):
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#     669     raise get_mysql_exception(
#     670         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     671     ) from err
#
# KeyboardInterrupt:

# %%
# %%sql
#
# DESCRIBE Names_
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('name_id', 'varchar(255)', 'NO', '', None, ''),
#  ('name_', 'varchar(255)', 'NO', '', None, ''),
#  ('birth_year', 'smallint', 'YES', '', None, ''),
#  ('death_year', 'smallint', 'YES', '', None, '')]

# %%
# %%sql
#
# DESCRIBE Directors
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('name_id', 'varchar(255)', 'NO', '', None, '')]

# %%
# %%sql
#
# DESCRIBE Had_role
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('name_id', 'varchar(255)', 'NO', '', None, ''),
#  ('role_', 'text', 'NO', '', None, '')]

# %%
# %%sql
#
# SELECT name_id
# FROM Names_
# WHERE name_ = "Wes Anderson"
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('nm0027572',)]

# %%
# %%sql
#
# SELECT H.name_id, N.name_
# FROM Had_role H
# INNER JOIN Names_ N ON N.name_id = H.name_id
# LIMIT 5
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('nm0000212', 'Meg Ryan'),
#  ('nm0000123', 'George Clooney'),
#  ('nm0000221', 'Charlie Sheen'),
#  ('nm0000214', 'Mia Sara'),
#  ('nm0000281', 'Scott Baio')]

# %%
# %%sql
#
# SELECT *
# FROM Names_
# LIMIT 5
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('nm0000002', 'Lauren Bacall', 1924, 2014),
#  ('nm0000003', 'Brigitte Bardot', 1934, None),
#  ('nm0000005', 'Ingmar Bergman', 1918, 2007),
#  ('nm0000008', 'Marlon Brando', 1924, 2004),
#  ('nm0000013', 'Doris Day', 1922, 2019)]

# %% [markdown]
# We use: <br>
# <br>
# WHERE (Had_role.title_id IN ( SELECT Directors.title_id ... <br>
# <br>
# because with that syntax we're saying to only consider the rows in the table that we have up to this point ( i.e. Had_role and Names_ joined together) where Had_role.title_id = Directors.title_id , where Directors.title_id has to satisfy the condition we're giving after in the code (i.e: <br>
# <br>
# INNER JOIN Names_ ON Names_.name_id = Directors.name_id WHERE ( Names_.name_ LIKE "Wes Anderson") .

# %%
# %%sql
#
# SELECT Had_role.name_id, Names_.name_
# FROM Had_role
# INNER JOIN Names_ ON Names_.name_id = Had_role.name_id
# WHERE (Had_role.title_id IN (
#         SELECT Directors.title_id
#         FROM Directors
#         INNER JOIN Names_ ON Names_.name_id = Directors.name_id
#         WHERE ( Names_.name_ LIKE "Wes Anderson")
#               )
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 39 rows affected.
# [('nm0000123', 'George Clooney'),
#  ('nm0000146', 'Ralph Fiennes'),
#  ('nm0000195', 'Bill Murray'),
#  ('nm0000195', 'Bill Murray'),
#  ('nm0000195', 'Bill Murray'),
#  ('nm0000195', 'Bill Murray'),
#  ('nm0000246', 'Bruce Willis'),
#  ('nm0000432', 'Gene Hackman'),
#  ('nm0000569', 'Gwyneth Paltrow'),
#  ('nm0000658', 'Meryl Streep'),
#  ('nm0000719', 'F. Murray Abraham'),
#  ('nm0000837', 'Bob Balaban'),
#  ('nm0000949', 'Cate Blanchett'),
#  ('nm0001025', 'Seymour Cassel'),
#  ('nm0001125', 'Benicio Del Toro'),
#  ('nm0001378', 'Anjelica Huston'),
#  ('nm0001378', 'Anjelica Huston'),
#  ('nm0001570', 'Edward Norton'),
#  ('nm0001774', 'Ben Stiller'),
#  ('nm0004778', 'Adrien Brody'),
#  ('nm0004778', 'Adrien Brody'),
#  ('nm0004778', 'Adrien Brody'),
#  ('nm0005403', 'Jason Schwartzman'),
#  ('nm0005403', 'Jason Schwartzman'),
#  ('nm0005403', 'Jason Schwartzman'),
#  ('nm0005561', 'Luke Wilson'),
#  ('nm0005562', 'Owen Wilson'),
#  ('nm0005562', 'Owen Wilson'),
#  ('nm0005562', 'Owen Wilson'),
#  ('nm0023832', 'Mathieu Amalric'),
#  ('nm0186505', 'Bryan Cranston'),
#  ('nm0235684', 'Ned Dowd'),
#  ('nm0288800', 'Shea Fowler'),
#  ('nm0842770', 'Tilda Swinton'),
#  ('nm0931404', 'Olivia Williams'),
#  ('nm2244205', 'Léa Seydoux'),
#  ('nm2496312', 'Amara Karan'),
#  ('nm4442068', 'Jared Gilman'),
#  ('nm4442319', 'Kara Hayward')]

# %%
# %%sql
#
# SELECT Names_.name_, COUNT(*) AS Apparences
# FROM Had_role
# INNER JOIN Names_ ON Names_.name_id = Had_role.name_id
# WHERE (Had_role.title_id IN (
#         SELECT Directors.title_id
#         FROM Directors
#         INNER JOIN Names_ ON Names_.name_id = Directors.name_id
#         WHERE ( Names_.name_ LIKE "Wes Anderson")
#               )
# )
# GROUP BY Names_.name_
# ORDER BY Apparences DESC
# LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('Bill Murray', 4),
#  ('Owen Wilson', 3),
#  ('Jason Schwartzman', 3),
#  ('Adrien Brody', 3),
#  ('Anjelica Huston', 2),
#  ('Ralph Fiennes', 1),
#  ('Kara Hayward', 1),
#  ('Gene Hackman', 1),
#  ('Gwyneth Paltrow', 1),
#  ('F. Murray Abraham', 1)]

# %% [markdown]
# ### Is IMDB only about movies?
#
# 1. Check the number of different media types contained in the database
# 2. Plot a histogram summarizing the number of titles per media type
# 3. Find the name and rating of the oldest videogame stored in the database

# %% [markdown]
# #### 1 - Check the number of different media types contained in the database

# %%
# %%sql
#
# SELECT *
# FROM Titles
# LIMIT 5
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('tt0011216', 'movie', 'Spanish Fiesta', 2019, 67),
#  ('tt0015724', 'movie', 'Dama de noche', 1993, 102),
#  ('tt0035423', 'movie', 'Kate & Leopold', 2001, 118),
#  ('tt0059325', 'movie', "Born in '45", 1990, 100),
#  ('tt0059900', 'movie', 'Wenn du groß bist, lieber Adam', 1990, 78)]

# %%
# %%sql
#
# SELECT DISTINCT title_type, COUNT(*) AS nTitles
# FROM Titles
# GROUP BY title_type
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('movie', 239353),
#  ('tvEpisode', 708598),
#  ('tvSeries', 59424),
#  ('tvMiniSeries', 11963),
#  ('videoGame', 257)]

# %% [markdown]
# #### 2 - Plot a histogram summarizing the number of titles per media type

# %%
res = %sql SELECT DISTINCT title_type, COUNT(*) AS nTitles FROM Titles GROUP BY title_type;

res.bar()
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# <BarContainer object of 5 artists>

# %% [markdown]
# #### 3 - Find the name and rating of the oldest videogame stored in the database

# %%
# %%sql
#
# SHOW TABLES
# Out:
#  * mysql+mysqlconnector://root:***@db
# 7 rows affected.
# [('Directors',),
#  ('Episode_belongs_to',),
#  ('Had_role',),
#  ('Names_',),
#  ('Title_genres',),
#  ('Title_ratings',),
#  ('Titles',)]

# %%
# %%sql
#
# SELECT *
# FROM Titles
# LIMIT 5
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('tt0011216', 'movie', 'Spanish Fiesta', 2019, 67),
#  ('tt0015724', 'movie', 'Dama de noche', 1993, 102),
#  ('tt0035423', 'movie', 'Kate & Leopold', 2001, 118),
#  ('tt0059325', 'movie', "Born in '45", 1990, 100),
#  ('tt0059900', 'movie', 'Wenn du groß bist, lieber Adam', 1990, 78)]

# %%
# %%sql
#
# SELECT *
# FROM Title_ratings
# LIMIT 5
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('tt0011216', 6.9, 30),
#  ('tt0015724', 6.2, 25),
#  ('tt0035423', 6.4, 82922),
#  ('tt0059325', 6.5, 240),
#  ('tt0059900', 6.7, 34)]

# %%
# %%sql
#
# SELECT primary_title, start_year, average_rating
# FROM Titles
# INNER JOIN Title_ratings ON Titles.title_id = Title_ratings.title_id
# WHERE Titles.title_type = "videoGame"
# AND Titles.start_year != "None"
# ORDER BY start_year ASC
# LIMIT 1
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('Lord of the Rings', 1990, 6.9)]

# %% [markdown]
# ### Identify interesting outliers
#
# 1. List the names of all movies whose titles begin with "The" and have a runtime between 3 and 4 hours.
# 2. What actor had the most roles as 'Self'?
# 3. Identify what TV series had more than 1,000 episodes, and identify in what year it was aired the first- and last-episode

# %% [markdown]
# #### 1 - List the names of all movies whose titles begin with "The" and have a runtime between 3 and 4 hours.

# %%
# %%sql
#
# SELECT primary_title, runtime_minutes*60 AS Runtime
# FROM Titles
# WHERE primary_title LIKE "The%"
# AND runtime_minutes BETWEEN 180 AND 240

# %% [markdown]
# #### 2 - What actor had the most roles as 'Self'?

# %%
# %%sql
#
# DESCRIBE Had_role
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('name_id', 'varchar(255)', 'NO', '', None, ''),
#  ('role_', 'text', 'NO', '', None, '')]

# %%
# %%sql
#
# SELECT name_, COUNT(*) AS nRoles
# FROM Names_
# INNER JOIN Had_role ON Had_role.name_id = Names_.name_id
# WHERE role_ = "Self"
# GROUP BY Names_.name_
# ORDER BY nRoles DESC
# LIMIT 1
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('Scott Morrison', 3197)]

# %% [markdown]
# #### 3 - Identify what TV series had more than 1,000 episodes, and identify in what year it was aired the first- and last-episode

# %%
# %%sql
#
# SHOW TABLES
# Out:
#  * mysql+mysqlconnector://root:***@db
# 7 rows affected.
# [('Directors',),
#  ('Episode_belongs_to',),
#  ('Had_role',),
#  ('Names_',),
#  ('Title_genres',),
#  ('Title_ratings',),
#  ('Titles',)]

# %%
# %%sql
#
# DESCRIBE Episode_belongs_to
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('episode_title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('parent_tv_show_title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('season_number', 'int', 'YES', '', None, ''),
#  ('episode_number', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# DESCRIBE Title_ratings
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('average_rating', 'float', 'YES', '', None, ''),
#  ('num_votes', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# SELECT primary_title, average_rating, num_votes
# FROM Titles
# INNER JOIN Title_ratings ON Title_ratings.title_id = Titles.title_id
# WHERE title_type = "movie"
# HAVING num_votes > 10000
# ORDER BY average_rating DESC
# LIMIT 10
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('The Shawshank Redemption', 9.3, 2545609),
#  ('Jai Bhim', 9.3, 174547),
#  ('Soorarai Pottru', 9.1, 107425),
#  ('Mirror Game', 9.1, 25604),
#  ('CM101MMXI Fundamentals', 9.1, 45666),
#  ('#Home', 9.0, 11756),
#  ('The Dark Knight', 9.0, 2495907),
#  ('David Attenborough: A Life on Our Planet', 9.0, 30686),
#  ('Toma', 8.9, 10167),
#  ("Schindler's List", 8.9, 1299398)]

# %%
# %%sql
#
# SELECT primary_title, AVG(start_year), COUNT(*) AS nEpisodes
# FROM Titles
# INNER JOIN Episode_belongs_to Ep ON Titles.title_id = Ep.parent_tv_show_title_id
# GROUP BY primary_title
# HAVING nEpisodes > 1000
# ORDER BY nEpisodes DESC
# LIMIT 10
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('Charlie Rose', Decimal('1991.0000'), 9884),
#  ('Gute Zeiten, schlechte Zeiten', Decimal('1992.0000'), 7455),
#  ('Judge Judy', Decimal('1996.0000'), 7282),
#  ('Unter uns', Decimal('1994.0000'), 6803),
#  ('Late Show with David Letterman', Decimal('1993.0000'), 6691),
#  ('Goede tijden, slechte tijden', Decimal('1990.0000'), 6550),
#  ('Young Hearts', Decimal('1995.0000'), 6247),
#  ('DAS!', Decimal('1991.0000'), 5433),
#  ("L'invité", Decimal('2000.0000'), 5273),
#  ('Volle Kanne', Decimal('1999.0000'), 5111)]

# %% [markdown]
# Soluzione di fede:

# %%
# %%sql
#
# CREATE VIEW subquery AS
# SELECT MAX(Titles.start_year) AS LastEpisode, MIN(Titles.start_year) AS FirstEpisode, Episode_belongs_to.parent_tv_show_title_id
#     FROM Titles
#     RIGHT JOIN Episode_belongs_to ON Titles.title_id = Episode_belongs_to.episode_title_id
#     WHERE Episode_belongs_to.parent_tv_show_title_id IN (SELECT parent_tv_show_title_id
#                                                         FROM Episode_belongs_to
#                                                         GROUP BY parent_tv_show_title_id
#                                                         HAVING COUNT(1) > 1000
#                                                         ORDER BY COUNT(1) DESC)
#     GROUP BY Episode_belongs_to.parent_tv_show_title_id
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# SELECT subquery.LastEpisode AS LastEpisode, subquery.FirstEpisode AS FirstEpisode, Titles.primary_title
# FROM subquery
# JOIN Titles ON subquery.parent_tv_show_title_id = Titles.title_id
# Out:
#  * mysql+mysqlconnector://root:***@db
# 308 rows affected.
# [(2020, 1990, 'Goede tijden, slechte tijden'),
#  (2021, 1995, 'Hollyoaks'),
#  (2014, 2011, 'Chelsea Lately'),
#  (2018, 2018, 'Mornings with Maria Bartiromo'),
#  (2020, 2008, 'Fox Report with Jon Scott'),
#  (1998, 1998, 'Telefé noticias'),
#  (None, None, 'The Five'),
#  (2015, 1994, 'Late Show with David Letterman'),
#  (2015, 1994, 'Los desayunos de TVE'),
#  (2018, 2018, 'Varney & Company'),
#  (None, None, 'Our Crazy Family'),
#  (2004, 1995, 'Informativos Telecinco'),
#  (2016, 2006, 'Ulice'),
#  (2018, 2018, 'New Day'),
#  (2021, 2014, 'Late Night with Seth Meyers'),
#  (2018, 2010, 'Ordinace v ruzové zahrade 2'),
#  (None, None, 'Aadade Aadharam'),
#  (2008, 2000, 'Kyunki Saas Bhi Kabhi Bahu Thi'),
#  (2017, 2006, 'Pardon the Interruption'),
#  (2000, 1995, 'Telecupón'),
#  (2021, 2000, 'Holby City'),
#  (2001, 1997, 'Zlotopolscy'),
#  (None, None, 'Telefé noticias a las 19'),
#  (2007, 1998, 'Saber vivir'),
#  (2020, 1996, 'Eisenbahn-Romantik'),
#  (2016, 2012, 'Jôhô Presenter Tokudane!'),
#  (2009, 2009, 'Che tempo che fa'),
#  (2020, 2007, 'Anderson Cooper 360°'),
#  (2019, 2019, 'Vanambadi'),
#  (None, None, 'Beni Affet'),
#  (2019, 2003, 'The Ellen DeGeneres Show'),
#  (2006, 2000, 'Passions'),
#  (None, None, 'Cheez TV'),
#  (1997, 1994, 'Causa común'),
#  (None, None, 'Magal'),
#  (None, None, 'Kalyana Parisu'),
#  (2016, 2013, 'Drzavni Posao'),
#  (None, None, 'Shakti: Astitva Ke Ehsaas Ki'),
#  (None, None, 'Making Money with Charles Payne'),
#  (2018, 2016, 'Trish Regan Primetime'),
#  (2011, 1992, 'Marienhof'),
#  (2010, 2010, 'Tinsel'),
#  (2022, 2015, 'Ang probinsyano'),
#  (None, None, 'Mangala Gowri Maduve'),
#  (2021, 2011, "Let's Make a Deal"),
#  (2021, 2015, 'Kumkum Bhagya'),
#  (2013, 2011, 'Piers Morgan Live'),
#  (2020, 2007, 'DAS!'),
#  (2017, 2013, 'The Real'),
#  (2016, 2009, 'Markus Lanz'),
#  (2022, 2017, 'The Story with Martha MacCallum'),
#  (2021, 2009, 'Yeh Rishta Kya Kehlata Hai'),
#  (2016, 2006, 'On the Record w/ Brit Hume'),
#  (2020, 2012, 'Special Report with Bret Baier'),
#  (2022, 1995, 'Dateline NBC'),
#  (2017, 2000, 'The View'),
#  (2015, 1996, 'Detective Conan'),
#  (2014, 2007, 'TMZ on TV'),
#  (None, None, 'Bom Dia & Cia'),
#  (2019, 2013, 'Auf Streife'),
#  (2017, 1992, 'Charlie Rose'),
#  (2022, 2010, 'Access Hollywood'),
#  (2016, 2016, 'Good Day L.A.'),
#  (2021, 2015, 'Blind Wave'),
#  (2022, 2010, 'Paul Murray Live'),
#  (2021, 1993, 'WWE Raw'),
#  (2019, 2015, 'The Evening Edit'),
#  (None, None, 'Buenos días a todos'),
#  (2022, 2019, 'ESPN First Take'),
#  (None, None, 'Bueréré'),
#  (2018, 2012, 'Erin Burnett OutFront'),
#  (2020, 1995, 'Thuis'),
#  (None, None, 'Wowowee'),
#  (2014, 2012, 'Actors Entertainment'),
#  (None, None, 'Kumkum: Ek Pyara Sa Bandhan'),
#  (2012, 2004, 'Morangos com Açúcar'),
#  (None, None, 'The Alan Titchmarsh Show'),
#  (2013, 1992, 'The Tonight Show with Jay Leno'),
#  (2019, 2009, 'Rachael Ray'),
#  (None, None, 'Azhagi'),
#  (2021, 2008, 'Taarak Mehta Ka Ooltah Chashmah'),
#  (2016, 2012, 'Red Eye w/Tom Shillue'),
#  (None, None, 'Sasural Simar Ka'),
#  (2005, 2005, 'Arrayán'),
#  (None, None, 'The Rachel Maddow Show'),
#  (2012, 2010, 'Saath Nibhana Saathiya'),
#  (None, None, 'Uppum Mulakum'),
#  (None, None, 'Lords of the Air'),
#  (2021, 2013, 'Fox and Friends'),
#  (2019, 2012, 'Fox Business Tonight'),
#  (None, None, 'Alpha Forum'),
#  (None, None, 'Savdhaan India: Crime Alert'),
#  (2021, 1996, 'The Daily Show'),
#  (None, None, 'Maa....Tomay Chara Ghum Ashena'),
#  (None, None, 'Bhabi Ji Ghar Par Hai'),
#  (None, None, 'Kumkuma Puvvu'),
#  (2018, 2013, 'Dish Nation'),
#  (2021, 2016, 'Tujhyat Jeev Rangala'),
#  (2017, 2012, 'Pudhcha Paaul'),
#  (2015, 2007, 'Hardball with Chris Matthews'),
#  (None, None, 'Kasthuri'),
#  (2021, 2009, 'The Project'),
#  (2022, 2012, 'Good Mythical Morning'),
#  (2001, 2001, 'Esther'),
#  (None, None, 'Nadhaswaram'),
#  (2021, 2010, 'Conan'),
#  (None, None, 'Child Bride'),
#  (2015, 2005, 'The Late Late Show with Craig Ferguson'),
#  (2015, 2006, 'AM - Antes del mediodía'),
#  (2021, 2012, 'Home & Family'),
#  (2017, 1994, 'Die Fallers - Eine Schwarzwaldfamilie'),
#  (2013, 2006, 'Love in Difficult Times'),
#  (None, None, 'Vem vet mest?'),
#  (2014, 2004, 'Pasapalabra'),
#  (2017, 2016, 'Morning Joe'),
#  (2015, 2013, 'The Wendy Williams Show'),
#  (2020, 2018, 'At This Hour with Kate Bolduan'),
#  (None, None, 'Gente que busca gente'),
#  (None, None, 'Kahaani Ghar Ghar Kii'),
#  (None, None, 'Woh Rehne Waali Mehlon Ki'),
#  (2021, 2015, 'The Late Show with Stephen Colbert'),
#  (2021, 2010, 'Watch What Happens Live with Andy Cohen'),
#  (None, None, 'Chandralekha'),
#  (None, None, 'The Noite com Danilo Gentili'),
#  (2002, 2001, 'The Late Late Show with Craig Kilborn'),
#  (2002, 2002, 'Virginie'),
#  (None, None, 'Jenny Jones'),
#  (2020, 2013, 'Democracy Now!'),
#  (None, None, 'Kkusum'),
#  (2018, 2007, 'Rote Rosen'),
#  (2021, 2020, 'Fútbol Total'),
#  (2018, 2018, 'Porta a Porta'),
#  (2020, 2020, 'Dlaczego ja?'),
#  (None, None, 'The Ingraham Angle'),
#  (2012, 1998, 'Unter uns'),
#  (None, None, 'Kalimera zoi'),
#  (2021, 2009, 'Hannity'),
#  (2016, 1999, 'Hotel Cæsar'),
#  (2018, 2006, 'Zibb'),
#  (2002, 1997, 'Al salir de clase'),
#  (None, None, 'Celebrity Page'),
#  (2017, 1996, 'The Factor'),
#  (None, None, 'I lampsi'),
#  (None, None, 'Vivere'),
#  (2018, 2005, 'Breakfast'),
#  (2021, 1992, 'Familie'),
#  (2017, 2006, 'Tavis Smiley'),
#  (None, None, 'Divorce Court'),
#  (2018, 2008, 'The Jerry Springer Show'),
#  (None, None, 'Saber y ganar'),
#  (None, None, 'Thamarai'),
#  (None, None, 'Ilavarasi'),
#  (None, None, 'Mundhanai Mudichu'),
#  (2019, 2015, 'After the Bell'),
#  (2020, 1992, 'Gute Zeiten, schlechte Zeiten'),
#  (2006, 1994, 'Antena 3 noticias'),
#  (None, None, 'El secreto de Puente Viejo'),
#  (2017, 2004, 'The Wright Stuff'),
#  (2020, 2007, 'Loose Women'),
#  (2013, 2000, 'M jak milosc'),
#  (None, None, 'Niedrig und Kuhnt - Kommissare ermitteln'),
#  (2016, 2011, "The Last Word with Lawrence O'Donnell"),
#  (None, None, 'Ricki Lake'),
#  (2019, 2019, 'Alles was zählt'),
#  (None, None, 'Ukryta prawda'),
#  (2000, 1995, 'Chiquititas'),
#  (2001, 2001, 'Howard Stern'),
#  (2000, 2000, 'Abhalmaya'),
#  (None, None, 'Volle Kanne'),
#  (2021, 2014, 'Studio 10'),
#  (None, None, 'Karuthamuthu'),
#  (2021, 1999, 'WWE Smackdown!'),
#  (2007, 1997, "Late Night with Conan O'Brien"),
#  (None, None, 'Fox and Friends First'),
#  (None, None, 'Suhani Si Ek Ladki'),
#  (None, None, 'Avaghachi Sansaar'),
#  (2018, 2015, 'Shepard Smith Reporting'),
#  (2021, 2015, 'The Late Late Show with James Corden'),
#  (None, None, 'Khabarnaak'),
#  (2004, 2003, 'Caméra café'),
#  (2022, 2018, 'Le dessous des cartes'),
#  (2020, 2004, 'Plus belle la vie'),
#  (2006, 2006, 'The Tyra Banks Show'),
#  (2021, 2019, 'Outnumbered'),
#  (None, None, 'Maury'),
#  (2002, 1998, 'Club Megatrix'),
#  (None, None, 'Udaan'),
#  (2017, 2011, 'Mad Money w/ Jim Cramer'),
#  (2007, 2007, 'Barwy szczescia'),
#  (2015, 2013, 'Baal Veer'),
#  (2007, 2000, 'TV total'),
#  (2018, 2006, 'Your World w/Neil Cavuto'),
#  (None, None, 'Opera Van Java'),
#  (2018, 1996, 'Young Hearts'),
#  (2021, 2017, 'No Agenda'),
#  (2017, 2012, 'Happening Now'),
#  (None, None, 'Samo zycie'),
#  (2005, 2005, 'Corazón de...'),
#  (2020, 2020, 'Quotidien'),
#  (None, None, 'Generations'),
#  (None, None, 'The Beat with Ari Melber'),
#  (None, None, 'Worldwide Exchange'),
#  (2018, 2007, "L'invité"),
#  (2021, 2003, 'Jimmy Kimmel Live!'),
#  (None, None, 'La 2 noticias'),
#  (2003, 2003, 'Flog It!'),
#  (2021, 2010, 'Scènes de ménages'),
#  (2010, 2005, 'Jóban rosszban'),
#  (2013, 1992, 'Horror Kung-Fu Theatre'),
#  (None, None, '3000 Whys of Blue Cat'),
#  (None, None, 'Priyamanaval'),
#  (2011, 2004, 'Pierwsza milosc'),
#  (2022, 2017, 'Tomorrow Is Ours'),
#  (None, None, 'Prince Mackaroo'),
#  (None, None, 'Vamsam'),
#  (None, None, 'Thirumathi Selvam'),
#  (2022, 2014, 'The Talk'),
#  (None, None, 'NHK News 9'),
#  (None, None, 'Kundali Bhagya'),
#  (2018, 1998, 'Barátok közt'),
#  (2016, 2005, 'Le grand journal de Canal+'),
#  (2020, 2015, 'Good Morning Britain'),
#  (None, None, 'Maragatha Veenai'),
#  (None, None, 'F.I.R.'),
#  (2018, 2004, 'Last Call with Carson Daly'),
#  (None, None, 'Leeza'),
#  (2007, 2003, 'Kasautii Zindagii Kay'),
#  (2018, 2016, 'Kennedy Live'),
#  (2022, 2020, 'Tucker Carlson Tonight'),
#  (2011, 2006, 'Attack of the Show!'),
#  (2017, 2006, 'The One Show'),
#  (2019, 2016, 'The Claman Countdown'),
#  (2020, 2011, 'Lorraine'),
#  (2016, 2014, 'Judge Judy'),
#  (2020, 2014, 'De wereld draait door'),
#  (None, None, 'News Watch 9'),
#  (2021, 2017, 'Fox News @ Night'),
#  (2009, 2007, 'Spangas'),
#  (2020, 2016, 'Pointless'),
#  (None, None, 'Muddulakshmi'),
#  (2006, 1998, 'La mirada crítica'),
#  (2022, 2018, 'Skip and Shannon: Undisputed'),
#  (None, None, 'Durva'),
#  (None, None, 'Lenßen & Partner'),
#  (2020, 1997, 'Klan'),
#  (2020, 2020, 'De fútbol se habla así'),
#  (None, None, 'The News on CNBC'),
#  (2022, 2008, 'Sled'),
#  (2022, 2015, 'Auf Streife - Die Spezialisten'),
#  (2013, 2005, 'The Insider'),
#  (None, None, 'Crónicas marcianas'),
#  (2018, 2015, 'Cavuto on Business'),
#  (None, None, 'Anandham'),
#  (None, None, 'Seven Sharp'),
#  (2022, 2014, 'Evening Urgant'),
#  (2010, 2009, 'Late Night with Jimmy Fallon'),
#  (2014, 2005, 'The Colbert Report'),
#  (2021, 2009, 'Strictly Come Dancing: It Takes Two'),
#  (2012, 2012, 'Giggle and Hoot'),
#  (2002, 1998, 'Hollywood Squares'),
#  (2022, 2022, 'Phoenix Runde'),
#  (2019, 2009, "America's Newsroom"),
#  (2022, 2012, 'The Bolt Report'),
#  (2022, 2009, 'Extra with Billy Bush'),
#  (2018, 2006, 'Storm of Love'),
#  (None, None, 'Scandal!'),
#  (2021, 2010, 'Puoli seitsemän'),
#  (2014, 2014, 'The Chew'),
#  (None, None, 'Politically Incorrect'),
#  (None, None, 'Valli'),
#  (None, None, 'Ugunsgreks'),
#  (2017, 2011, 'CBS Evening News with Scott Pelley'),
#  (2010, 2010, 'Deniz Yildizi'),
#  (None, None, 'Uttaran'),
#  (2020, 2002, 'Who Wants to Be a Millionaire'),
#  (2021, 2014, 'The Tonight Show Starring Jimmy Fallon'),
#  (2018, 2007, 'Você na TV!'),
#  (None, None, 'Athipookal'),
#  (None, None, 'Bargain Hunt'),
#  (2015, 1995, 'Verbotene Liebe'),
#  (2020, 2003, 'Homes Under the Hammer'),
#  (None, None, 'Access Daily'),
#  (2021, 1997, 'Pokémon'),
#  (2021, 1999, 'One Piece'),
#  (None, None, 'Good Morning America Weekend Edition'),
#  (2020, 2012, 'Maalaala Mo Kaya'),
#  (2016, 2016, 'Thé ou café'),
#  (2014, 2009, 'Pavitra Rishta'),
#  (2003, 1995, 'Die Harald Schmidt Show'),
#  (2015, 2008, 'Dahoam is Dahoam'),
#  (2019, 2013, 'CBS This Morning'),
#  (2018, 2018, 'Yeh Hai Mohabbatein'),
#  (2020, 2012, 'Trailers from Hell'),
#  (1998, 1998, "The Rosie O'Donnell Show"),
#  (2004, 2003, 'Camera Café'),
#  (2006, 2006, 'W11. Wydzial sledczy'),
#  (2001, 1997, 'Port Charles'),
#  (2018, 1998, 'C.I.D.'),
#  (2019, 2019, 'The Steve Wilkos Show'),
#  (None, None, 'Cavuto: Coast to Coast'),
#  (2020, 2000, 'Doctors'),
#  (2004, 2004, 'Richard & Judy'),
#  (2014, 2012, 'CNBC Squawk Box'),
#  (2021, 2001, 'Secret Lives'),
#  (2015, 2012, 'Shortland Street'),
#  (2005, 2005, 'The Jeremy Kyle Show'),
#  (2013, 2012, 'Nancy Grace'),
#  (2017, 2010, 'Mike & Mike')]

# %%
# %%sql
#
# SELECT subquery.LastEpisode AS LastEpisode, subquery.FirstEpisode AS FirstEpisode, Titles.primary_title
# FROM(SELECT MAX(Titles.start_year) AS LastEpisode, MIN(Titles.start_year) AS FirstEpisode, Episode_belongs_to.parent_tv_show_title_id
#     FROM Titles
#     JOIN Episode_belongs_to ON Titles.title_id = Episode_belongs_to.episode_title_id
#     WHERE Episode_belongs_to.parent_tv_show_title_id IN (SELECT parent_tv_show_title_id
#                                                         FROM Episode_belongs_to
#                                                         GROUP BY parent_tv_show_title_id
#                                                         HAVING COUNT(1) > 1000
#                                                         ORDER BY COUNT(1) DESC)
#     GROUP BY Episode_belongs_to.parent_tv_show_title_id) AS subquery
# JOIN Titles ON subquery.parent_tv_show_title_id = Titles.title_id
# Out:
#  * mysql+mysqlconnector://root:***@db
# 218 rows affected.
# [(2020, 1990, 'Goede tijden, slechte tijden'),
#  (2021, 1995, 'Hollyoaks'),
#  (2014, 2011, 'Chelsea Lately'),
#  (2018, 2018, 'Mornings with Maria Bartiromo'),
#  (2020, 2008, 'Fox Report with Jon Scott'),
#  (1998, 1998, 'Telefé noticias'),
#  (2015, 1994, 'Late Show with David Letterman'),
#  (2015, 1994, 'Los desayunos de TVE'),
#  (2018, 2018, 'Varney & Company'),
#  (2004, 1995, 'Informativos Telecinco'),
#  (2016, 2006, 'Ulice'),
#  (2018, 2018, 'New Day'),
#  (2021, 2014, 'Late Night with Seth Meyers'),
#  (2018, 2010, 'Ordinace v ruzové zahrade 2'),
#  (2008, 2000, 'Kyunki Saas Bhi Kabhi Bahu Thi'),
#  (2000, 1995, 'Telecupón'),
#  (2017, 2006, 'Pardon the Interruption'),
#  (2021, 2000, 'Holby City'),
#  (2001, 1997, 'Zlotopolscy'),
#  (2007, 1998, 'Saber vivir'),
#  (2020, 1996, 'Eisenbahn-Romantik'),
#  (2016, 2012, 'Jôhô Presenter Tokudane!'),
#  (2009, 2009, 'Che tempo che fa'),
#  (2020, 2007, 'Anderson Cooper 360°'),
#  (2019, 2019, 'Vanambadi'),
#  (2006, 2000, 'Passions'),
#  (2019, 2003, 'The Ellen DeGeneres Show'),
#  (1997, 1994, 'Causa común'),
#  (2016, 2013, 'Drzavni Posao'),
#  (2018, 2016, 'Trish Regan Primetime'),
#  (2011, 1992, 'Marienhof'),
#  (2010, 2010, 'Tinsel'),
#  (2022, 2015, 'Ang probinsyano'),
#  (2021, 2011, "Let's Make a Deal"),
#  (2021, 2015, 'Kumkum Bhagya'),
#  (2013, 2011, 'Piers Morgan Live'),
#  (2020, 2007, 'DAS!'),
#  (2017, 2013, 'The Real'),
#  (2016, 2009, 'Markus Lanz'),
#  (2022, 2017, 'The Story with Martha MacCallum'),
#  (2021, 2009, 'Yeh Rishta Kya Kehlata Hai'),
#  (2016, 2006, 'On the Record w/ Brit Hume'),
#  (2020, 2012, 'Special Report with Bret Baier'),
#  (2022, 1995, 'Dateline NBC'),
#  (2015, 1996, 'Detective Conan'),
#  (2017, 2000, 'The View'),
#  (2014, 2007, 'TMZ on TV'),
#  (2019, 2013, 'Auf Streife'),
#  (2017, 1992, 'Charlie Rose'),
#  (2022, 2010, 'Access Hollywood'),
#  (2016, 2016, 'Good Day L.A.'),
#  (2021, 2015, 'Blind Wave'),
#  (2022, 2010, 'Paul Murray Live'),
#  (2021, 1993, 'WWE Raw'),
#  (2019, 2015, 'The Evening Edit'),
#  (2022, 2019, 'ESPN First Take'),
#  (2018, 2012, 'Erin Burnett OutFront'),
#  (2020, 1995, 'Thuis'),
#  (2014, 2012, 'Actors Entertainment'),
#  (2012, 2004, 'Morangos com Açúcar'),
#  (2013, 1992, 'The Tonight Show with Jay Leno'),
#  (2019, 2009, 'Rachael Ray'),
#  (2021, 2008, 'Taarak Mehta Ka Ooltah Chashmah'),
#  (2016, 2012, 'Red Eye w/Tom Shillue'),
#  (None, None, 'Sasural Simar Ka'),
#  (2005, 2005, 'Arrayán'),
#  (2012, 2010, 'Saath Nibhana Saathiya'),
#  (2021, 2013, 'Fox and Friends'),
#  (2019, 2012, 'Fox Business Tonight'),
#  (2021, 1996, 'The Daily Show'),
#  (2018, 2013, 'Dish Nation'),
#  (2021, 2016, 'Tujhyat Jeev Rangala'),
#  (2017, 2012, 'Pudhcha Paaul'),
#  (2015, 2007, 'Hardball with Chris Matthews'),
#  (2021, 2009, 'The Project'),
#  (2022, 2012, 'Good Mythical Morning'),
#  (2001, 2001, 'Esther'),
#  (2021, 2010, 'Conan'),
#  (2015, 2005, 'The Late Late Show with Craig Ferguson'),
#  (2015, 2006, 'AM - Antes del mediodía'),
#  (2021, 2012, 'Home & Family'),
#  (2017, 1994, 'Die Fallers - Eine Schwarzwaldfamilie'),
#  (2013, 2006, 'Love in Difficult Times'),
#  (2014, 2004, 'Pasapalabra'),
#  (2017, 2016, 'Morning Joe'),
#  (2015, 2013, 'The Wendy Williams Show'),
#  (2020, 2018, 'At This Hour with Kate Bolduan'),
#  (2021, 2015, 'The Late Show with Stephen Colbert'),
#  (2021, 2010, 'Watch What Happens Live with Andy Cohen'),
#  (2002, 2001, 'The Late Late Show with Craig Kilborn'),
#  (2002, 2002, 'Virginie'),
#  (None, None, 'Kkusum'),
#  (2020, 2013, 'Democracy Now!'),
#  (2018, 2007, 'Rote Rosen'),
#  (2021, 2020, 'Fútbol Total'),
#  (2018, 2018, 'Porta a Porta'),
#  (2020, 2020, 'Dlaczego ja?'),
#  (2012, 1998, 'Unter uns'),
#  (2021, 2009, 'Hannity'),
#  (2016, 1999, 'Hotel Cæsar'),
#  (2018, 2006, 'Zibb'),
#  (2002, 1997, 'Al salir de clase'),
#  (2017, 1996, 'The Factor'),
#  (2018, 2005, 'Breakfast'),
#  (2021, 1992, 'Familie'),
#  (2017, 2006, 'Tavis Smiley'),
#  (2018, 2008, 'The Jerry Springer Show'),
#  (2019, 2015, 'After the Bell'),
#  (2020, 1992, 'Gute Zeiten, schlechte Zeiten'),
#  (2006, 1994, 'Antena 3 noticias'),
#  (2017, 2004, 'The Wright Stuff'),
#  (2020, 2007, 'Loose Women'),
#  (2013, 2000, 'M jak milosc'),
#  (2016, 2011, "The Last Word with Lawrence O'Donnell"),
#  (2019, 2019, 'Alles was zählt'),
#  (2000, 1995, 'Chiquititas'),
#  (2001, 2001, 'Howard Stern'),
#  (2000, 2000, 'Abhalmaya'),
#  (2021, 2014, 'Studio 10'),
#  (2021, 1999, 'WWE Smackdown!'),
#  (2007, 1997, "Late Night with Conan O'Brien"),
#  (2018, 2015, 'Shepard Smith Reporting'),
#  (2021, 2015, 'The Late Late Show with James Corden'),
#  (None, None, 'Khabarnaak'),
#  (2004, 2003, 'Caméra café'),
#  (2022, 2018, 'Le dessous des cartes'),
#  (2020, 2004, 'Plus belle la vie'),
#  (2006, 2006, 'The Tyra Banks Show'),
#  (2021, 2019, 'Outnumbered'),
#  (2002, 1998, 'Club Megatrix'),
#  (2017, 2011, 'Mad Money w/ Jim Cramer'),
#  (2007, 2007, 'Barwy szczescia'),
#  (2015, 2013, 'Baal Veer'),
#  (2007, 2000, 'TV total'),
#  (2018, 2006, 'Your World w/Neil Cavuto'),
#  (2018, 1996, 'Young Hearts'),
#  (2021, 2017, 'No Agenda'),
#  (2017, 2012, 'Happening Now'),
#  (2005, 2005, 'Corazón de...'),
#  (2020, 2020, 'Quotidien'),
#  (2018, 2007, "L'invité"),
#  (2021, 2003, 'Jimmy Kimmel Live!'),
#  (2003, 2003, 'Flog It!'),
#  (2021, 2010, 'Scènes de ménages'),
#  (2010, 2005, 'Jóban rosszban'),
#  (2013, 1992, 'Horror Kung-Fu Theatre'),
#  (2011, 2004, 'Pierwsza milosc'),
#  (2022, 2017, 'Tomorrow Is Ours'),
#  (2022, 2014, 'The Talk'),
#  (2018, 1998, 'Barátok közt'),
#  (2016, 2005, 'Le grand journal de Canal+'),
#  (2020, 2015, 'Good Morning Britain'),
#  (2018, 2004, 'Last Call with Carson Daly'),
#  (2007, 2003, 'Kasautii Zindagii Kay'),
#  (2018, 2016, 'Kennedy Live'),
#  (2022, 2020, 'Tucker Carlson Tonight'),
#  (2011, 2006, 'Attack of the Show!'),
#  (2017, 2006, 'The One Show'),
#  (2019, 2016, 'The Claman Countdown'),
#  (2020, 2011, 'Lorraine'),
#  (2016, 2014, 'Judge Judy'),
#  (2020, 2014, 'De wereld draait door'),
#  (2021, 2017, 'Fox News @ Night'),
#  (2009, 2007, 'Spangas'),
#  (2020, 2016, 'Pointless'),
#  (2006, 1998, 'La mirada crítica'),
#  (2022, 2018, 'Skip and Shannon: Undisputed'),
#  (None, None, 'Durva'),
#  (2020, 1997, 'Klan'),
#  (2020, 2020, 'De fútbol se habla así'),
#  (2022, 2008, 'Sled'),
#  (2022, 2015, 'Auf Streife - Die Spezialisten'),
#  (2013, 2005, 'The Insider'),
#  (2018, 2015, 'Cavuto on Business'),
#  (2022, 2014, 'Evening Urgant'),
#  (2010, 2009, 'Late Night with Jimmy Fallon'),
#  (2014, 2005, 'The Colbert Report'),
#  (2021, 2009, 'Strictly Come Dancing: It Takes Two'),
#  (2012, 2012, 'Giggle and Hoot'),
#  (2002, 1998, 'Hollywood Squares'),
#  (2022, 2022, 'Phoenix Runde'),
#  (2019, 2009, "America's Newsroom"),
#  (2022, 2012, 'The Bolt Report'),
#  (2022, 2009, 'Extra with Billy Bush'),
#  (2018, 2006, 'Storm of Love'),
#  (2021, 2010, 'Puoli seitsemän'),
#  (2014, 2014, 'The Chew'),
#  (2017, 2011, 'CBS Evening News with Scott Pelley'),
#  (2010, 2010, 'Deniz Yildizi'),
#  (2020, 2002, 'Who Wants to Be a Millionaire'),
#  (2021, 2014, 'The Tonight Show Starring Jimmy Fallon'),
#  (2018, 2007, 'Você na TV!'),
#  (2015, 1995, 'Verbotene Liebe'),
#  (2020, 2003, 'Homes Under the Hammer'),
#  (2021, 1997, 'Pokémon'),
#  (2021, 1999, 'One Piece'),
#  (2020, 2012, 'Maalaala Mo Kaya'),
#  (2016, 2016, 'Thé ou café'),
#  (2014, 2009, 'Pavitra Rishta'),
#  (2003, 1995, 'Die Harald Schmidt Show'),
#  (2015, 2008, 'Dahoam is Dahoam'),
#  (2019, 2013, 'CBS This Morning'),
#  (2018, 2018, 'Yeh Hai Mohabbatein'),
#  (2020, 2012, 'Trailers from Hell'),
#  (1998, 1998, "The Rosie O'Donnell Show"),
#  (2004, 2003, 'Camera Café'),
#  (2006, 2006, 'W11. Wydzial sledczy'),
#  (2001, 1997, 'Port Charles'),
#  (2018, 1998, 'C.I.D.'),
#  (2019, 2019, 'The Steve Wilkos Show'),
#  (2020, 2000, 'Doctors'),
#  (2004, 2004, 'Richard & Judy'),
#  (2014, 2012, 'CNBC Squawk Box'),
#  (2021, 2001, 'Secret Lives'),
#  (2015, 2012, 'Shortland Street'),
#  (2005, 2005, 'The Jeremy Kyle Show'),
#  (2013, 2012, 'Nancy Grace'),
#  (2017, 2010, 'Mike & Mike')]

# %% [markdown]
# ### It's all about the ratings
#
# 1. Group all movies by decade and plot their overall rating distribution trend. Limit the query to the movies with at least 1000 ratings.
# 2. Plot the average rating of each episode of "Games of Thrones". Group by season and compute the average and standard deviation for each season
# 3. Plot the total number of movies produced per year, divided by genre (Action, Comedy, Drama, Thriller, Fantasy), and the yearly rating average per genre

# %% [markdown]
# #### 1 - Group all movies by decade and plot their overall rating distribution trend. Limit the query to the movies with at least 1000 ratings.

# %%
# %%sql
#
# DESCRIBE Title_ratings
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('average_rating', 'float', 'YES', '', None, ''),
#  ('num_votes', 'int', 'YES', '', None, '')]

# %% [markdown]
# As it's checked by the query below, there are no titles with num_votes > 1000 prior of 1990.

# %%
# %%sql
#
# SELECT primary_title, start_year
# FROM Titles T
# INNER JOIN Title_ratings R ON T.title_id = R.title_id
# WHERE start_year < 1990 AND num_votes > 1000
# LIMIT 10
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# SELECT FLOOR(T.start_year/10)*10 AS Decade, AVG(R.average_rating) AS Rating
# FROM Titles T
# INNER JOIN Title_ratings R ON T.title_id = R.title_id
# WHERE num_votes > 1000 AND start_year != "None"
# GROUP BY Decade
# ORDER BY Decade DESC
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(2020, 7.131400774229496),
#  (2010, 7.160595173501715),
#  (2000, 6.974676088702646),
#  (1990, 6.927333051610376)]

# %%
res = %sql SELECT FLOOR(T.start_year/10)*10 AS Decade, AVG(R.average_rating) AS Rating FROM Titles T \
INNER JOIN Title_ratings R ON T.title_id = R.title_id \
WHERE num_votes > 1000 AND start_year != "None" \
GROUP BY Decade \
ORDER BY Decade DESC;

res.bar()
plt.yticks(np.arange(10))
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# ([<matplotlib.axis.YTick at 0x7f7f197e7d90>,
#   <matplotlib.axis.YTick at 0x7f7f218cd9d0>,
#   <matplotlib.axis.YTick at 0x7f7f0c36bd90>,
#   <matplotlib.axis.YTick at 0x7f7f21924a50>,
#   <matplotlib.axis.YTick at 0x7f7f21926bd0>,
#   <matplotlib.axis.YTick at 0x7f7f2192ced0>,
#   <matplotlib.axis.YTick at 0x7f7f2192eed0>,
#   <matplotlib.axis.YTick at 0x7f7f2192c6d0>,
#   <matplotlib.axis.YTick at 0x7f7f21939650>,
#   <matplotlib.axis.YTick at 0x7f7f2193b810>],
#  [Text(0, 0, '0'),
#   Text(0, 1, '1'),
#   Text(0, 2, '2'),
#   Text(0, 3, '3'),
#   Text(0, 4, '4'),
#   Text(0, 5, '5'),
#   Text(0, 6, '6'),
#   Text(0, 7, '7'),
#   Text(0, 8, '8'),
#   Text(0, 9, '9')])

# %% [markdown]
# #### 2 - Plot the average rating of each episode of "Games of Thrones". Group by season and compute the average and standard deviation for each season.

# %%
# %%sql
#
# DESCRIBE Episode_belongs_to
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('episode_title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('parent_tv_show_title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('season_number', 'int', 'YES', '', None, ''),
#  ('episode_number', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# SELECT average_rating AS Rating, episode_number, season_number
# FROM Episode_belongs_to E
# INNER JOIN Title_ratings R ON R.title_id = E.episode_title_id
# INNER JOIN Titles T ON T.title_id = E.parent_tv_show_title_id
# WHERE primary_title = "Game of Thrones"
# ORDER BY season_number, episode_number ASC
# Out:
#  * mysql+mysqlconnector://root:***@db
# 73 rows affected.
# [(9.1, 1, 1),
#  (8.8, 2, 1),
#  (8.7, 3, 1),
#  (8.8, 4, 1),
#  (9.1, 5, 1),
#  (9.2, 6, 1),
#  (9.2, 7, 1),
#  (9.0, 8, 1),
#  (9.6, 9, 1),
#  (9.5, 10, 1),
#  (8.8, 1, 2),
#  (8.5, 2, 2),
#  (8.8, 3, 2),
#  (8.8, 4, 2),
#  (8.8, 5, 2),
#  (9.1, 6, 2),
#  (8.9, 7, 2),
#  (8.8, 8, 2),
#  (9.7, 9, 2),
#  (9.4, 10, 2),
#  (8.8, 1, 3),
#  (8.6, 2, 3),
#  (8.9, 3, 3),
#  (9.6, 4, 3),
#  (9.0, 5, 3),
#  (8.8, 6, 3),
#  (8.7, 7, 3),
#  (9.0, 8, 3),
#  (9.9, 9, 3),
#  (9.2, 10, 3),
#  (9.1, 1, 4),
#  (9.7, 2, 4),
#  (8.9, 3, 4),
#  (8.8, 4, 4),
#  (8.8, 5, 4),
#  (9.7, 6, 4),
#  (9.1, 7, 4),
#  (9.7, 8, 4),
#  (9.6, 9, 4),
#  (9.7, 10, 4),
#  (8.5, 1, 5),
#  (8.5, 2, 5),
#  (8.5, 3, 5),
#  (8.7, 4, 5),
#  (8.6, 5, 5),
#  (8.0, 6, 5),
#  (9.0, 7, 5),
#  (9.9, 8, 5),
#  (9.5, 9, 5),
#  (9.1, 10, 5),
#  (8.5, 1, 6),
#  (9.4, 2, 6),
#  (8.7, 3, 6),
#  (9.1, 4, 6),
#  (9.7, 5, 6),
#  (8.4, 6, 6),
#  (8.6, 7, 6),
#  (8.4, 8, 6),
#  (9.9, 9, 6),
#  (9.9, 10, 6),
#  (8.6, 1, 7),
#  (8.9, 2, 7),
#  (9.2, 3, 7),
#  (9.8, 4, 7),
#  (8.8, 5, 7),
#  (9.0, 6, 7),
#  (9.4, 7, 7),
#  (7.5, 1, 8),
#  (7.8, 2, 8),
#  (7.4, 3, 8),
#  (5.4, 4, 8),
#  (5.9, 5, 8),
#  (4.0, 6, 8)]

# %%
res = %sql SELECT episode_number, average_rating AS Rating \
FROM Episode_belongs_to E \
INNER JOIN Title_ratings R ON R.title_id = E.episode_title_id \
INNER JOIN Titles T ON T.title_id = E.parent_tv_show_title_id \
WHERE primary_title = "Game of Thrones" \
ORDER BY season_number, episode_number ASC;

plt.figure(figsize=(20,6))
res.bar()
# Out:
#  * mysql+mysqlconnector://root:***@db
# 73 rows affected.
# <BarContainer object of 73 artists>

# %%
# %%sql
#
# SELECT season_number, AVG(average_rating) AS AvgRating, STDDEV(average_rating) AS Std
# FROM Episode_belongs_to E
# INNER JOIN Title_ratings R ON R.title_id = E.episode_title_id
# INNER JOIN Titles T ON T.title_id = E.parent_tv_show_title_id
# WHERE primary_title = "Game of Thrones"
# GROUP BY season_number
# ORDER BY season_number ASC;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 8 rows affected.
# [(1, 9.100000095367431, 0.279284841851893),
#  (2, 8.960000038146973, 0.3322648385598139),
#  (3, 9.05, 0.3905124105321288),
#  (4, 9.310000038146972, 0.3832752574106418),
#  (5, 8.830000019073486, 0.5273518051323894),
#  (6, 9.05999984741211, 0.588557477116479),
#  (7, 9.099999972752162, 0.37416567313687327),
#  (8, 6.333333412806193, 1.3634107864471021)]

# %%
res = %sql SELECT season_number, AVG(average_rating) AS AvgRating\
FROM Episode_belongs_to E \
INNER JOIN Title_ratings R ON R.title_id = E.episode_title_id \
INNER JOIN Titles T ON T.title_id = E.parent_tv_show_title_id \
WHERE primary_title = "Game of Thrones" \
GROUP BY season_number \
ORDER BY season_number ASC;

res.bar()
plt.yticks(np.arange(10))
# Out:
#  * mysql+mysqlconnector://root:***@db
# 8 rows affected.
# ([<matplotlib.axis.YTick at 0x7f7f48847c10>,
#   <matplotlib.axis.YTick at 0x7f7f4866f310>,
#   <matplotlib.axis.YTick at 0x7f7f486581d0>,
#   <matplotlib.axis.YTick at 0x7f7f484fb090>,
#   <matplotlib.axis.YTick at 0x7f7f48504810>,
#   <matplotlib.axis.YTick at 0x7f7f48506a50>,
#   <matplotlib.axis.YTick at 0x7f7f48508c10>,
#   <matplotlib.axis.YTick at 0x7f7f4850acd0>,
#   <matplotlib.axis.YTick at 0x7f7f4850ce10>,
#   <matplotlib.axis.YTick at 0x7f7f484f9490>],
#  [Text(0, 0, '0'),
#   Text(0, 1, '1'),
#   Text(0, 2, '2'),
#   Text(0, 3, '3'),
#   Text(0, 4, '4'),
#   Text(0, 5, '5'),
#   Text(0, 6, '6'),
#   Text(0, 7, '7'),
#   Text(0, 8, '8'),
#   Text(0, 9, '9')])

# %% [markdown]
# #### 3 - Plot the total number of movies produced per year, divided by genre (Action, Comedy, Drama, Thriller, Fantasy), and the yearly rating average per genre

# %%
# %%sql
#
# DESCRIBE Title_genres
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('genre', 'varchar(255)', 'NO', '', None, '')]

# %%
# %%sql
#
# SELECT COUNT(T.title_id) AS nTitles, start_year, AVG(average_rating), genre
# FROM Titles T
# INNER JOIN Title_genres G ON G.title_id = T.title_id
# INNER JOIN Title_ratings R ON R.title_id = T.title_id
# WHERE genre IN ("Action","Comedy","Drama","Thriller","Fantasy")
# GROUP BY start_year, genre
# ORDER BY start_year DESC
# Out:
#  * mysql+mysqlconnector://root:***@db
# 169 rows affected.
# [(184, 2022, 7.654891300460567, 'Action'),
#  (422, 2022, 7.104502372267122, 'Comedy'),
#  (615, 2022, 7.324390244677784, 'Drama'),
#  (67, 2022, 7.347761221786044, 'Fantasy'),
#  (155, 2022, 6.880645158213953, 'Thriller'),
#  (2507, 2021, 7.090546476160999, 'Action'),
#  (5002, 2021, 7.071711318796036, 'Comedy'),
#  (7346, 2021, 7.166212910613344, 'Drama'),
#  (883, 2021, 7.3231030659389384, 'Fantasy'),
#  (1516, 2021, 6.532453837605454, 'Thriller'),
#  (2762, 2020, 6.954091248565787, 'Action'),
#  (6783, 2020, 6.963541212114246, 'Comedy'),
#  (8412, 2020, 7.062256307897826, 'Drama'),
#  (1237, 2020, 7.210266787579875, 'Fantasy'),
#  (1783, 2020, 6.45945036718836, 'Thriller'),
#  (4080, 2019, 7.199142166621545, 'Action'),
#  (8571, 2019, 6.995846469779789, 'Comedy'),
#  (10573, 2019, 7.0945427164746855, 'Drama'),
#  (1245, 2019, 7.156224912333201, 'Fantasy'),
#  (1832, 2019, 6.336899567834675, 'Thriller'),
#  (4133, 2018, 7.157246556865831, 'Action'),
#  (9269, 2018, 6.963955127353073, 'Comedy'),
#  (10681, 2018, 7.131233040173283, 'Drama'),
#  (1279, 2018, 7.272400330807475, 'Fantasy'),
#  (1931, 2018, 6.428016578453554, 'Thriller'),
#  (4057, 2017, 7.246339668245012, 'Action'),
#  (9265, 2017, 7.072487868287405, 'Comedy'),
#  (10632, 2017, 7.180370587415494, 'Drama'),
#  (1556, 2017, 7.451863761273019, 'Fantasy'),
#  (1855, 2017, 6.369110518131616, 'Thriller'),
#  (3934, 2016, 7.207905455658626, 'Action'),
#  (9792, 2016, 7.0986826074327904, 'Comedy'),
#  (10415, 2016, 7.227844467772009, 'Drama'),
#  (1433, 2016, 7.337613414570075, 'Fantasy'),
#  (1605, 2016, 6.209283491458477, 'Thriller'),
#  (3799, 2015, 7.314003700926355, 'Action'),
#  (9176, 2015, 7.183162609948318, 'Comedy'),
#  (10138, 2015, 7.22709609006937, 'Drama'),
#  (1298, 2015, 7.413174126107814, 'Fantasy'),
#  (1651, 2015, 6.366989717347776, 'Thriller'),
#  (3571, 2014, 7.307728947327271, 'Action'),
#  (8618, 2014, 7.1840798403885335, 'Comedy'),
#  (8994, 2014, 7.208450092072749, 'Drama'),
#  (1166, 2014, 7.350686112869256, 'Fantasy'),
#  (1470, 2014, 6.30863946449189, 'Thriller'),
#  (3327, 2013, 7.239735509921453, 'Action'),
#  (8206, 2013, 7.128296377279397, 'Comedy'),
#  (8772, 2013, 7.171910636334239, 'Drama'),
#  (926, 2013, 7.168034581592222, 'Fantasy'),
#  (1404, 2013, 6.239387468140349, 'Thriller'),
#  (3127, 2012, 7.215286224765979, 'Action'),
#  (7739, 2012, 7.08192274021785, 'Comedy'),
#  (7910, 2012, 7.174690276512455, 'Drama'),
#  (1111, 2012, 7.384338450152846, 'Fantasy'),
#  (1148, 2012, 6.283101054122639, 'Thriller'),
#  (2975, 2011, 7.223327739098493, 'Action'),
#  (7157, 2011, 7.0592007904691005, 'Comedy'),
#  (7381, 2011, 7.072442770456496, 'Drama'),
#  (1043, 2011, 7.309012481944559, 'Fantasy'),
#  (1032, 2011, 6.294573649070983, 'Thriller'),
#  (2701, 2010, 7.111329155248962, 'Action'),
#  (5919, 2010, 6.990251745600055, 'Comedy'),
#  (6967, 2010, 7.097760888995306, 'Drama'),
#  (755, 2010, 7.280794709565623, 'Fantasy'),
#  (911, 2010, 6.063885847247654, 'Thriller'),
#  (2444, 2009, 7.142389540293798, 'Action'),
#  (5565, 2009, 6.884222829009859, 'Comedy'),
#  (6866, 2009, 7.044596572954315, 'Drama'),
#  (730, 2009, 7.2089041251025785, 'Fantasy'),
#  (833, 2009, 6.0909964069455755, 'Thriller'),
#  (2232, 2008, 7.092786757268786, 'Action'),
#  (4749, 2008, 6.788734481168511, 'Comedy'),
#  (6140, 2008, 7.016612386412263, 'Drama'),
#  (588, 2008, 7.105782318277424, 'Fantasy'),
#  (682, 2008, 6.10102639729676, 'Thriller'),
#  (2038, 2007, 7.127870478445227, 'Action'),
#  (4874, 2007, 6.965839154024715, 'Comedy'),
#  (5798, 2007, 7.058882382706389, 'Drama'),
#  (665, 2007, 7.2759398489070115, 'Fantasy'),
#  (574, 2007, 5.918466894261098, 'Thriller'),
#  (1950, 2006, 7.019076933860779, 'Action'),
#  (4751, 2006, 6.978615039149176, 'Comedy'),
#  (5335, 2006, 7.081761959209103, 'Drama'),
#  (852, 2006, 7.127112685374811, 'Fantasy'),
#  (592, 2006, 6.000337835099246, 'Thriller'),
#  (1933, 2005, 7.140196595115484, 'Action'),
#  (4267, 2005, 6.969439901762498, 'Comedy'),
#  (4939, 2005, 7.083316474169414, 'Drama'),
#  (657, 2005, 7.225875195121475, 'Fantasy'),
#  (430, 2005, 6.033953487873077, 'Thriller'),
#  (1899, 2004, 7.099368097281192, 'Action'),
#  (3661, 2004, 6.868697084028582, 'Comedy'),
#  (4189, 2004, 7.058223930285124, 'Drama'),
#  (346, 2004, 6.922832377384164, 'Fantasy'),
#  (402, 2004, 6.031094530328589, 'Thriller'),
#  (2040, 2003, 7.111274518043387, 'Action'),
#  (3360, 2003, 6.8432738201604, 'Comedy'),
#  (3975, 2003, 7.017886797317169, 'Drama'),
#  (383, 2003, 7.027676254588692, 'Fantasy'),
#  (358, 2003, 5.8689944038178, 'Thriller'),
#  (1942, 2002, 6.985530382327267, 'Action'),
#  (3206, 2002, 6.853555846719986, 'Comedy'),
#  (4075, 2002, 7.020417189481068, 'Drama'),
#  (401, 2002, 6.7940149545074995, 'Fantasy'),
#  (329, 2002, 5.983282678395419, 'Thriller'),
#  (1828, 2001, 7.023577694167715, 'Action'),
#  (2919, 2001, 6.93545735584787, 'Comedy'),
#  (3602, 2001, 7.008467524863163, 'Drama'),
#  (466, 2001, 6.879184553039944, 'Fantasy'),
#  (331, 2001, 5.6036253767791475, 'Thriller'),
#  (1760, 2000, 6.9434659244661985, 'Action'),
#  (2780, 2000, 6.864640294133331, 'Comedy'),
#  (3413, 2000, 6.947612081145458, 'Drama'),
#  (426, 2000, 6.926056338587837, 'Fantasy'),
#  (356, 2000, 5.786235953314921, 'Thriller'),
#  (1602, 1999, 6.930898882178927, 'Action'),
#  (3141, 1999, 6.7859598902599405, 'Comedy'),
#  (3551, 1999, 6.888031549199941, 'Drama'),
#  (466, 1999, 6.856223178523805, 'Fantasy'),
#  (356, 1999, 5.843820214271545, 'Thriller'),
#  (1550, 1998, 6.860903233866538, 'Action'),
#  (2849, 1998, 6.899368208054703, 'Comedy'),
#  (3076, 1998, 6.894310807840722, 'Drama'),
#  (516, 1998, 6.521899228410203, 'Fantasy'),
#  (331, 1998, 5.940181267585639, 'Thriller'),
#  (1494, 1997, 6.787483274856884, 'Action'),
#  (2885, 1997, 6.914835360930326, 'Comedy'),
#  (2982, 1997, 6.864855807471963, 'Drama'),
#  (524, 1997, 6.55877864406309, 'Fantasy'),
#  (334, 1997, 5.8559880278067675, 'Thriller'),
#  (1336, 1996, 6.802170666748892, 'Action'),
#  (2512, 1996, 6.9524283515894485, 'Comedy'),
#  (2867, 1996, 6.935228468526063, 'Drama'),
#  (344, 1996, 7.053779091252837, 'Fantasy'),
#  (302, 1996, 5.707615892618697, 'Thriller'),
#  (1409, 1995, 6.858552168581484, 'Action'),
#  (2243, 1995, 7.004012494070212, 'Comedy'),
#  (2750, 1995, 6.9093454673506995, 'Drama'),
#  (257, 1995, 7.121011691334647, 'Fantasy'),
#  (297, 1995, 5.617845140322291, 'Thriller'),
#  (1327, 1994, 6.764807851582249, 'Action'),
#  (2348, 1994, 7.01763204105668, 'Comedy'),
#  (2605, 1994, 6.9494817817050984, 'Drama'),
#  (245, 1994, 7.0244898095422865, 'Fantasy'),
#  (252, 1994, 5.489285699904911, 'Thriller'),
#  (1075, 1993, 6.651813951758451, 'Action'),
#  (2086, 1993, 7.036721009993256, 'Comedy'),
#  (2357, 1993, 6.926431906845391, 'Drama'),
#  (202, 1993, 6.93168317091347, 'Fantasy'),
#  (241, 1993, 5.503734430336853, 'Thriller'),
#  (871, 1992, 6.623191743439018, 'Action'),
#  (2212, 1992, 6.9844936874525025, 'Comedy'),
#  (2070, 1992, 6.890048322009579, 'Drama'),
#  (250, 1992, 6.960800016403199, 'Fantasy'),
#  (214, 1992, 5.624299063860813, 'Thriller'),
#  (906, 1991, 6.53620309729713, 'Action'),
#  (2120, 1991, 6.971179260172934, 'Comedy'),
#  (2233, 1991, 6.859337222987208, 'Drama'),
#  (258, 1991, 6.636434113332467, 'Fantasy'),
#  (194, 1991, 5.617525764347351, 'Thriller'),
#  (852, 1990, 6.419953052706561, 'Action'),
#  (2057, 1990, 6.936266414390123, 'Comedy'),
#  (2256, 1990, 6.901019510383724, 'Drama'),
#  (243, 1990, 6.6588477244592985, 'Fantasy'),
#  (215, 1990, 5.652093027913293, 'Thriller'),
#  (15, None, 6.739999930063884, 'Action'),
#  (18, None, 6.072222219573127, 'Comedy'),
#  (17, None, 7.794117675108068, 'Drama'),
#  (2, None, 7.900000095367432, 'Fantasy')]

# %%
res = %sql SELECT start_year, COUNT(T.title_id) AS nTitles  \
FROM Titles T \
INNER JOIN Title_genres G ON G.title_id = T.title_id \
INNER JOIN Title_ratings R ON R.title_id = T.title_id \
WHERE genre IN ("Action","Comedy","Drama","Thriller","Fantasy") \
GROUP BY start_year, genre \
ORDER BY start_year DESC;

res.bar()
# Out:
#  * mysql+mysqlconnector://root:***@db
# 169 rows affected.
# <BarContainer object of 169 artists>
